# %% [markdown]
# # Advanced Retrieval with LangChain
#
# In the following notebook, we'll explore various methods of advanced retrieval using LangChain!
#
# We'll touch on:
#
# - Naive Retrieval
# - Best-Matching 25 (BM25)
# - Multi-Query Retrieval
# - Parent-Document Retrieval
# - Contextual Compression (a.k.a. Rerank)
# - Ensemble Retrieval
# - Semantic chunking
#
# We'll also discuss how these methods impact performance on our set of documents with a simple RAG chain.
#
# There will be two breakout rooms:
#
# - 🤝 Breakout Room Part #1
#   - Task 1: Getting Dependencies!
#   - Task 2: Data Collection and Preparation
#   - Task 3: Setting Up QDrant!
#   - Task 4-10: Retrieval Strategies
# - 🤝 Breakout Room Part #2
#   - Activity: Evaluate with Ragas

# %% [markdown]
# # 🤝 Breakout Room Part #1

# %% [markdown]
# ## Task 1: Getting Dependencies!
#
# We're going to need a few specific LangChain community packages, like OpenAI (for our [LLM](https://platform.openai.com/docs/models) and [Embedding Model](https://platform.openai.com/docs/guides/embeddings)) and Cohere (for our [Reranker](https://cohere.com/rerank)).
#
# > You do not need to run the following cells if you are running this notebook locally.

# %%
# !pip install -qU langchain langchain-openai langchain-cohere rank_bm25
# Out:
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# We're also going to be leveraging [Qdrant's](https://qdrant.tech/documentation/frameworks/langchain/) (pronounced "Quadrant") VectorDB in "memory" mode (so we can leverage it locally in our colab environment).

# %%
# !pip install -qU qdrant-client
# Out:
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# We'll also provide our OpenAI key, as well as our Cohere API key.

# %%
import os
import getpass

os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter your OpenAI API Key:")

# %%
os.environ["COHERE_API_KEY"] = getpass.getpass("Cohere API Key:")

# %% [markdown]
# ## Task 2: Data Collection and Preparation
#
# We'll be using some reviews from the 4 movies in the John Wick franchise today to explore the different retrieval strategies.
#
# These were obtained from IMDB, and are available in the [AIM Data Repository](https://github.com/AI-Maker-Space/DataRepository).

# %% [markdown]
# ### Data Collection
#
# We can simply `wget` these from GitHub.
#
# You could use any review data you wanted in this step - just be careful to make sure your metadata is aligned with your choice.

# %%
# !wget https://raw.githubusercontent.com/AI-Maker-Space/DataRepository/main/jw1.csv -O john_wick_1.csv
# !wget https://raw.githubusercontent.com/AI-Maker-Space/DataRepository/main/jw2.csv -O john_wick_2.csv
# !wget https://raw.githubusercontent.com/AI-Maker-Space/DataRepository/main/jw3.csv -O john_wick_3.csv
# !wget https://raw.githubusercontent.com/AI-Maker-Space/DataRepository/main/jw4.csv -O john_wick_4.csv
# Out:
# --2025-02-28 11:40:29--  https://raw.githubusercontent.com/AI-Maker-Space/DataRepository/main/jw1.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8001::154, 2606:50c0:8002::154, 2606:50c0:8003::154, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8001::154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19628 (19K) [text/plain]
# Saving to: ‘john_wick_1.csv’
#
# john_wick_1.csv     100%[===================>]  19.17K  --.-KB/s    in 0.001s
#
# 2025-02-28 11:40:29 (18.6 MB/s) - ‘john_wick_1.csv’ saved [19628/19628]
#
# --2025-02-28 11:40:29--  https://raw.githubusercontent.com/AI-Maker-Space/DataRepository/main/jw2.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8001::154, 2606:50c0:8002::154, 2606:50c0:8003::154, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8001::154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14747 (14K) [text/plain]
# Saving to: ‘john_wick_2.csv’
#
# john_wick_2.csv     100%[===================>]  14.40K  --.-KB/s    in 0s
#
# 2025-02-28 11:40:29 (46.1 MB/s) - ‘john_wick_2.csv’ saved [14747/14747]
#
# --2025-02-28 11:40:30--  https://raw.githubusercontent.com/AI-Maker-Space/DataRepository/main/jw3.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8001::154, 2606:50c0:8002::154, 2606:50c0:8003::154, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8001::154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13888 (14K) [text/plain]
# Saving to: ‘john_wick_3.csv’
#
# john_wick_3.csv     100%[===================>]  13.56K  --.-KB/s    in 0s
#
# 2025-02-28 11:40:30 (33.4 MB/s) - ‘john_wick_3.csv’ saved [13888/13888]
#
# --2025-02-28 11:40:30--  https://raw.githubusercontent.com/AI-Maker-Space/DataRepository/main/jw4.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8001::154, 2606:50c0:8002::154, 2606:50c0:8003::154, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8001::154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15109 (15K) [text/plain]
# Saving to: ‘john_wick_4.csv’
#
# john_wick_4.csv     100%[===================>]  14.75K  --.-KB/s    in 0s
#
# 2025-02-28 11:40:30 (38.2 MB/s) - ‘john_wick_4.csv’ saved [15109/15109]

# %% [markdown]
# ### Data Preparation
#
# We want to make sure all our documents have the relevant metadata for the various retrieval strategies we're going to be applying today.
#
# - Self-Query: Wants as much metadata as we can provide
# - Time-weighted: Wants temporal data
#
# > NOTE: While we're creating a temporal relationship based on when these movies came out for illustrative purposes, it needs to be clear that the "time-weighting" in the Time-weighted Retriever is based on when the document was *accessed* last - not when it was created.

# %%
from langchain_community.document_loaders.csv_loader import CSVLoader
from datetime import datetime, timedelta

documents = []

for i in range(1, 5):
  loader = CSVLoader(
      file_path=f"john_wick_{i}.csv",
      metadata_columns=["Review_Date", "Review_Title", "Review_Url", "Author", "Rating"]
  )

  movie_docs = loader.load()
  for doc in movie_docs:

    # Add the "Movie Title" (John Wick 1, 2, ...)
    doc.metadata["Movie_Title"] = f"John Wick {i}"

    # convert "Rating" to an `int`, if no rating is provided - assume 0 rating
    doc.metadata["Rating"] = int(doc.metadata["Rating"]) if doc.metadata["Rating"] else 0

    # newer movies have a more recent "last_accessed_at"
    doc.metadata["last_accessed_at"] = datetime.now() - timedelta(days=4-i)

  documents.extend(movie_docs)

# %% [markdown]
# Let's look at an example document to see if everything worked as expected!

# %%
documents[0]
# Out:
# Document(metadata={'source': 'john_wick_1.csv', 'row': 0, 'Review_Date': '6 May 2015', 'Review_Title': ' Kinetic, concise, and stylish; John Wick kicks ass.\n', 'Review_Url': '/review/rw3233896/?ref_=tt_urv', 'Author': 'lnvicta', 'Rating': 8, 'Movie_Title': 'John Wick 1', 'last_accessed_at': datetime.datetime(2025, 2, 25, 11, 40, 31, 292319)}, page_content=": 0\nReview: The best way I can describe John Wick is to picture Taken but instead of Liam Neeson it's Keanu Reeves and instead of his daughter it's his dog. That's essentially the plot of the movie. John Wick (Reeves) is out to seek revenge on the people who took something he loved from him. It's a beautifully simple premise for an action movie - when action movies get convoluted, they get bad i.e. A Good Day to Die Hard. John Wick gives the viewers what they want: Awesome action, stylish stunts, kinetic chaos, and a relatable hero to tie it all together. John Wick succeeds in its simplicity.")

# %% [markdown]
# ## Task 3: Setting up QDrant!
#
# Now that we have our documents, let's create a QDrant VectorStore with the collection name "JohnWick".
#
# We'll leverage OpenAI's [`text-embedding-3-small`](https://openai.com/blog/new-embedding-models-and-api-updates) because it's a very powerful (and low-cost) embedding model.
#
# > NOTE: We'll be creating additional vectorstores where necessary, but this pattern is still extremely useful.

# %%
from langchain_community.vectorstores import Qdrant
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

vectorstore = Qdrant.from_documents(
    documents,
    embeddings,
    location=":memory:",
    collection_name="JohnWick"
)

# %% [markdown]
# ## Task 4: Naive RAG Chain
#
# Since we're focusing on the "R" in RAG today - we'll create our Retriever first.

# %% [markdown]
# ### R - Retrieval
#
# This naive retriever will simply look at each review as a document, and use cosine-similarity to fetch the 10 most relevant documents.
#
# > NOTE: We're choosing `10` as our `k` here to provide enough documents for our reranking process later

# %%
naive_retriever = vectorstore.as_retriever(search_kwargs={"k" : 10})

# %% [markdown]
# ### A - Augmented
#
# We're going to go with a standard prompt for our simple RAG chain today! Nothing fancy here, we want this to mostly be about the Retrieval process.

# %%
from langchain_core.prompts import ChatPromptTemplate

RAG_TEMPLATE = """\
You are a helpful and kind assistant. Use the context provided below to answer the question.

If you do not know the answer, or are unsure, say you don't know.

Query:
{question}

Context:
{context}
"""

rag_prompt = ChatPromptTemplate.from_template(RAG_TEMPLATE)

# %% [markdown]
# ### G - Generation
#
# We're going to leverage `gpt-3.5-turbo` as our LLM today, as - again - we want this to largely be about the Retrieval process.

# %%
from langchain_openai import ChatOpenAI

chat_model = ChatOpenAI()

# %% [markdown]
# ### LCEL RAG Chain
#
# We're going to use LCEL to construct our chain.
#
# > NOTE: This chain will be exactly the same across the various examples with the exception of our Retriever!

# %%
from langchain_core.runnables import RunnablePassthrough
from operator import itemgetter
from langchain_core.output_parsers import StrOutputParser

naive_retrieval_chain = (
    # INVOKE CHAIN WITH: {"question" : "<<SOME USER QUESTION>>"}
    # "question" : populated by getting the value of the "question" key
    # "context"  : populated by getting the value of the "question" key and chaining it into the base_retriever
    {"context": itemgetter("question") | naive_retriever, "question": itemgetter("question")}
    # "context"  : is assigned to a RunnablePassthrough object (will not be called or considered in the next step)
    #              by getting the value of the "context" key from the previous step
    | RunnablePassthrough.assign(context=itemgetter("context"))
    # "response" : the "context" and "question" values are used to format our prompt object and then piped
    #              into the LLM and stored in a key called "response"
    # "context"  : populated by getting the value of the "context" key from the previous step
    | {"response": rag_prompt | chat_model, "context": itemgetter("context")}
)

# %% [markdown]
# Let's see how this simple chain does on a few different prompts.
#
# > NOTE: You might think that we've cherry picked prompts that showcase the individual skill of each of the retrieval strategies - you'd be correct!

# %%
naive_retrieval_chain.invoke({"question" : "Did people generally like John Wick?"})["response"].content
# Out:
# "Based on the reviews provided, it seems that people generally liked John Wick. The reviews praised the action sequences, Keanu Reeves' performance, the style of the movie, and the overall experience. So, yes, people generally liked John Wick."

# %%
naive_retrieval_chain.invoke({"question" : "Do any reviews have a rating of 10? If so - can I have the URLs to those reviews?"})["response"].content
# Out:
# 'Yes, there is a review with a rating of 10. Here is the URL to that review:\n- \'/review/rw4854296/?ref_=tt_urv\' ("A Masterpiece & Brilliant Sequel")'

# %%
naive_retrieval_chain.invoke({"question" : "What happened in John Wick?"})["response"].content
# Out:
# 'In "John Wick," the protagonist, an ex-hit-man, comes out of retirement to seek vengeance against the gangsters who killed his dog and took everything from him, leading to plenty of violent action, shootouts, and breathtaking fights. His pursuit of revenge sets off a chain of events that brings him into conflict with various criminal elements, ultimately leading to a series of intense and brutal confrontations.'

# %% [markdown]
# Overall, this is not bad! Let's see if we can make it better!

# %% [markdown]
# ## Task 5: Best-Matching 25 (BM25) Retriever
#
# Taking a step back in time - [BM25](https://www.nowpublishers.com/article/Details/INR-019) is based on [Bag-Of-Words](https://en.wikipedia.org/wiki/Bag-of-words_model) which is a sparse representation of text.
#
# In essence, it's a way to compare how similar two pieces of text are based on the words they both contain.
#
# This retriever is very straightforward to set-up! Let's see it happen down below!

# %%
from langchain_community.retrievers import BM25Retriever

bm25_retriever = BM25Retriever.from_documents(documents)

# %% [markdown]
# We'll construct the same chain - only changing the retriever.

# %%
bm25_retrieval_chain = (
    {"context": itemgetter("question") | bm25_retriever, "question": itemgetter("question")}
    | RunnablePassthrough.assign(context=itemgetter("context"))
    | {"response": rag_prompt | chat_model, "context": itemgetter("context")}
)

# %% [markdown]
# Let's look at the responses!

# %%
bm25_retrieval_chain.invoke({"question" : "Did people generally like John Wick?"})["response"].content
# Out:
# 'It seems like opinions on John Wick vary. Some people really enjoyed the action and style of the movie, while others found it dull and lacking substance. Overall, it seems that the reception of John Wick is mixed.'

# %%
bm25_retrieval_chain.invoke({"question" : "Do any reviews have a rating of 10? If so - can I have the URLs to those reviews?"})["response"].content
# Out:
# 'There are no reviews with a rating of 10 for the movie "John Wick 4."'

# %%
bm25_retrieval_chain.invoke({"question" : "What happened in John Wick?"})["response"].content
# Out:
# 'In John Wick, the main character, John Wick, is a retired hitman seeking vengeance for the killing of his dog, which was a last gift from his deceased wife. This sets off a series of intense action sequences as Wick takes on numerous assassins who come after him. The movie is known for its well-choreographed action scenes and compelling storyline.'

# %% [markdown]
# It's not clear that this is better or worse - but the `I don't know` isn't great!

# %% [markdown]
# ## Task 6: Contextual Compression (Using Reranking)
#
# Contextual Compression is a fairly straightforward idea: We want to "compress" our retrieved context into just the most useful bits.
#
# There are a few ways we can achieve this - but we're going to look at a specific example called reranking.
#
# The basic idea here is this:
#
# - We retrieve lots of documents that are very likely related to our query vector
# - We "compress" those documents into a smaller set of *more* related documents using a reranking algorithm.
#
# We'll be leveraging Cohere's Rerank model for our reranker today!
#
# All we need to do is the following:
#
# - Create a basic retriever
# - Create a compressor (reranker, in this case)
#
# That's it!
#
# Let's see it in the code below!

# %%
from langchain.retrievers.contextual_compression import ContextualCompressionRetriever
from langchain_cohere import CohereRerank

compressor = CohereRerank(model="rerank-english-v3.0")
compression_retriever = ContextualCompressionRetriever(
    base_compressor=compressor, base_retriever=naive_retriever
)

# %% [markdown]
# Let's create our chain again, and see how this does!

# %%
contextual_compression_retrieval_chain = (
    {"context": itemgetter("question") | compression_retriever, "question": itemgetter("question")}
    | RunnablePassthrough.assign(context=itemgetter("context"))
    | {"response": rag_prompt | chat_model, "context": itemgetter("context")}
)

# %%
contextual_compression_retrieval_chain.invoke({"question" : "Did people generally like John Wick?"})["response"].content
# Out:
# 'Yes, people generally liked John Wick.'

# %%
contextual_compression_retrieval_chain.invoke({"question" : "Do any reviews have a rating of 10? If so - can I have the URLs to those reviews?"})["response"].content
# Out:
# 'Yes, there is a review with a rating of 10 for the movie "John Wick 3". Here is the URL to that review: \'/review/rw4854296/?ref_=tt_urv\'.'

# %%
contextual_compression_retrieval_chain.invoke({"question" : "What happened in John Wick?"})["response"].content
# Out:
# "In John Wick 2, after resolving his issues with the Russian mafia, John Wick is forced back into action when mobster Santino D'Antonio asks him to kill his sister in Rome. When Wick accomplishes the task, Santino puts a seven-million dollar contract on him, leading to professional killers coming after him. Wick promises to kill Santino in retaliation."

# %% [markdown]
# We'll need to rely on something like Ragas to help us get a better sense of how this is performing overall - but it "feels" better!

# %% [markdown]
# ## Task 7: Multi-Query Retriever
#
# Typically in RAG we have a single query - the one provided by the user.
#
# What if we had....more than one query!
#
# In essence, a Multi-Query Retriever works by:
#
# 1. Taking the original user query and creating `n` number of new user queries using an LLM.
# 2. Retrieving documents for each query.
# 3. Using all unique retrieved documents as context
#
# So, how is it to set-up? Not bad! Let's see it down below!

# %%
from langchain.retrievers.multi_query import MultiQueryRetriever

multi_query_retriever = MultiQueryRetriever.from_llm(
    retriever=naive_retriever, llm=chat_model
)

# %%
multi_query_retrieval_chain = (
    {"context": itemgetter("question") | multi_query_retriever, "question": itemgetter("question")}
    | RunnablePassthrough.assign(context=itemgetter("context"))
    | {"response": rag_prompt | chat_model, "context": itemgetter("context")}
)

# %%
multi_query_retrieval_chain.invoke({"question" : "Did people generally like John Wick?"})["response"].content
# Out:
# 'Yes, people generally liked John Wick based on the reviews provided in the context.'

# %%
multi_query_retrieval_chain.invoke({"question" : "Do any reviews have a rating of 10? If so - can I have the URLs to those reviews?"})["response"].content
# Out:
# 'Yes, there is one review with a rating of 10 for the movie "John Wick 3". Here is the URL to that review: \'/review/rw4854296/?ref_=tt_urv\''

# %%
multi_query_retrieval_chain.invoke({"question" : "What happened in John Wick?"})["response"].content
# Out:
# 'In John Wick, Keanu Reeves plays the character of John Wick, a retired assassin who comes out of retirement to seek revenge when his dog is killed and his car is stolen. He goes on a rampage, killing many individuals while being hunted by assassins. The story involves various locations such as Italy, Canada, and Manhattan, with lots of action and carnage.'

# %% [markdown]
# ## Task 8: Parent Document Retriever
#
# A "small-to-big" strategy - the Parent Document Retriever works based on a simple strategy:
#
# 1. Each un-split "document" will be designated as a "parent document" (You could use larger chunks of document as well, but our data format allows us to consider the overall document as the parent chunk)
# 2. Store those "parent documents" in a memory store (not a VectorStore)
# 3. We will chunk each of those documents into smaller documents, and associate them with their respective parents, and store those in a VectorStore. We'll call those "child chunks".
# 4. When we query our Retriever, we will do a similarity search comparing our query vector to the "child chunks".
# 5. Instead of returning the "child chunks", we'll return their associated "parent chunks".
#
# Okay, maybe that was a few steps - but the basic idea is this:
#
# - Search for small documents
# - Return big documents
#
# The intuition is that we're likely to find the most relevant information by limiting the amount of semantic information that is encoded in each embedding vector - but we're likely to miss relevant surrounding context if we only use that information.
#
# Let's start by creating our "parent documents" and defining a `RecursiveCharacterTextSplitter`.

# %%
from langchain.retrievers import ParentDocumentRetriever
from langchain.storage import InMemoryStore
from langchain_text_splitters import RecursiveCharacterTextSplitter
from qdrant_client import QdrantClient, models

parent_docs = documents
child_splitter = RecursiveCharacterTextSplitter(chunk_size=200)

# %% [markdown]
# We'll need to set up a new QDrant vectorstore - and we'll use another useful pattern to do so!
#
# > NOTE: We are manually defining our embedding dimension, you'll need to change this if you're using a different embedding model.

# %%
client = QdrantClient(location=":memory:")

client.create_collection(
    collection_name="full_documents",
    vectors_config=models.VectorParams(size=1536, distance=models.Distance.COSINE)
)

parent_document_vectorstore = Qdrant(
    collection_name="full_documents", embeddings=OpenAIEmbeddings(model="text-embedding-3-small"), client=client
)
# Out:
# /var/folders/y_/z74vbjzj55j3pwdjqvqc9llm0000gn/T/ipykernel_45088/3574430551.py:8: LangChainDeprecationWarning: The class `Qdrant` was deprecated in LangChain 0.0.37 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-qdrant package and should be used instead. To use it run `pip install -U :class:`~langchain-qdrant` and import as `from :class:`~langchain_qdrant import Qdrant``.
#   parent_document_vectorstore = Qdrant(

# %% [markdown]
# Now we can create our `InMemoryStore` that will hold our "parent documents" - and build our retriever!

# %%
store = InMemoryStore()

parent_document_retriever = ParentDocumentRetriever(
    vectorstore = parent_document_vectorstore,
    docstore=store,
    child_splitter=child_splitter,
)

# %% [markdown]
# By default, this is empty as we haven't added any documents - let's add some now!

# %%
parent_document_retriever.add_documents(parent_docs, ids=None)

# %% [markdown]
# We'll create the same chain we did before - but substitute our new `parent_document_retriever`.

# %%
parent_document_retrieval_chain = (
    {"context": itemgetter("question") | parent_document_retriever, "question": itemgetter("question")}
    | RunnablePassthrough.assign(context=itemgetter("context"))
    | {"response": rag_prompt | chat_model, "context": itemgetter("context")}
)

# %% [markdown]
# Let's give it a whirl!

# %%
parent_document_retrieval_chain.invoke({"question" : "Did people generally like John Wick?"})["response"].content
# Out:
# "People's opinions about John Wick are divided. Some love the series and appreciate the action and excitement it offers, while others find it nonsensical and boring. It seems that there is a range of views on whether people generally like John Wick."

# %%
parent_document_retrieval_chain.invoke({"question" : "Do any reviews have a rating of 10? If so - can I have the URLs to those reviews?"})["response"].content
# Out:
# 'Yes, there is a review with a rating of 10. The review of "John Wick 3" by user \'ymyuseda\' has a rating of 10. The URL to that review is \'/review/rw4854296/?ref_=tt_urv\'.'

# %%
parent_document_retrieval_chain.invoke({"question" : "What happened in John Wick?"})["response"].content
# Out:
# "In John Wick, the main character, played by Keanu Reeves, is a retired assassin who comes out of retirement when someone kills his dog. In the sequel, John Wick 2, his car is stolen which leads to a lot of carnage. John is then called on to pay off an old debt by helping to take over the Assassin's Guild by traveling to Italy, Canada, and Manhattan and killing many assassins along the way."

# %% [markdown]
# Overall, the performance *seems* largely the same. We can leverage a tool like [Ragas]() to more effectively answer the question about the performance.

# %% [markdown]
# ## Task 9: Ensemble Retriever
#
# In brief, an Ensemble Retriever simply takes 2, or more, retrievers and combines their retrieved documents based on a rank-fusion algorithm.
#
# In this case - we're using the [Reciprocal Rank Fusion](https://plg.uwaterloo.ca/~gvcormac/cormacksigir09-rrf.pdf) algorithm.
#
# Setting it up is as easy as providing a list of our desired retrievers - and the weights for each retriever.

# %%
from langchain.retrievers import EnsembleRetriever

retriever_list = [bm25_retriever, naive_retriever, parent_document_retriever, compression_retriever, multi_query_retriever]
equal_weighting = [1/len(retriever_list)] * len(retriever_list)

ensemble_retriever = EnsembleRetriever(
    retrievers=retriever_list, weights=equal_weighting
)

# %% [markdown]
# We'll pack *all* of these retrievers together in an ensemble.

# %%
ensemble_retrieval_chain = (
    {"context": itemgetter("question") | ensemble_retriever, "question": itemgetter("question")}
    | RunnablePassthrough.assign(context=itemgetter("context"))
    | {"response": rag_prompt | chat_model, "context": itemgetter("context")}
)

# %% [markdown]
# Let's look at our results!

# %%
ensemble_retrieval_chain.invoke({"question" : "Did people generally like John Wick?"})["response"].content
# Out:
# "Based on the reviews provided, it seems that people generally liked John Wick. The movie received positive reviews praising the action sequences, Keanu Reeves' performance, and the overall entertainment factor of the film."

# %%
ensemble_retrieval_chain.invoke({"question" : "Do any reviews have a rating of 10? If so - can I have the URLs to those reviews?"})["response"].content
# Out:
# 'Yes, there is one review with a rating of 10. The URL to that review is /review/rw4854296/?ref_=tt_urv.'

# %%
ensemble_retrieval_chain.invoke({"question" : "What happened in John Wick?"})["response"].content
# Out:
# 'In John Wick, an ex-hitman comes out of retirement to seek vengeance on the gangsters who killed his dog and took everything from him. With a price on his head, John Wick unleashes a maelstrom of destruction against those who try to stop him, making him a target of hitmen and bounty hunters. The story is filled with violent action, shootouts, and gripping fights.'

# %% [markdown]
# ## Task 10: Semantic Chunking
#
# While this is not a retrieval method - it *is* an effective way of increasing retrieval performance on corpora that have clean semantic breaks in them.
#
# Essentially, Semantic Chunking is implemented by:
#
# 1. Embedding all sentences in the corpus.
# 2. Combining or splitting sequences of sentences based on their semantic similarity based on a number of [possible thresholding methods](https://python.langchain.com/docs/how_to/semantic-chunker/):
#   - `percentile`
#   - `standard_deviation`
#   - `interquartile`
#   - `gradient`
# 3. Each sequence of related sentences is kept as a document!
#
# Let's see how to implement this!
#
# > NOTE: You do not need to run this cell if you're running this locally

# %%
# !pip install -qU langchain_experimental
# Out:
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# We'll use the `percentile` thresholding method for this example which will:
#
# Calculate all distances between sentences, and then break apart sequences of setences that exceed a given percentile among all distances.

# %%
from langchain_experimental.text_splitter import SemanticChunker

semantic_chunker = SemanticChunker(
    embeddings,
    breakpoint_threshold_type="percentile"
)

# %% [markdown]
# Now we can split our documents.

# %%
semantic_documents = semantic_chunker.split_documents(documents)

# %% [markdown]
# Let's create a new vector store.

# %%
semantic_vectorstore = Qdrant.from_documents(
    semantic_documents,
    embeddings,
    location=":memory:",
    collection_name="JohnWickSemantic"
)

# %% [markdown]
# We'll use naive retrieval for this example.

# %%
semantic_retriever = semantic_vectorstore.as_retriever(search_kwargs={"k" : 10})

# %% [markdown]
# Finally we can create our classic chain!

# %%
semantic_retrieval_chain = (
    {"context": itemgetter("question") | semantic_retriever, "question": itemgetter("question")}
    | RunnablePassthrough.assign(context=itemgetter("context"))
    | {"response": rag_prompt | chat_model, "context": itemgetter("context")}
)

# %% [markdown]
# And view the results!

# %%
semantic_retrieval_chain.invoke({"question" : "Did people generally like John Wick?"})["response"].content
# Out:
# 'People generally liked John Wick based on the reviews provided.'

# %%
semantic_retrieval_chain.invoke({"question" : "Do any reviews have a rating of 10? If so - can I have the URLs to those reviews?"})["response"].content
# Out:
# "Yes, there is a review with a rating of 10. Here is the URL to that review: '/review/rw4854296/?ref_=tt_urv'"

# %%
semantic_retrieval_chain.invoke({"question" : "What happened in John Wick?"})["response"].content
# Out:
# 'In "John Wick," the main character seeks revenge on the people who killed his dog and took everything from him. He is an ex-hitman who comes out of retirement to track down the gangsters responsible.'

# %% [markdown]
# # 🤝 Breakout Room Part #2

# %% [markdown]
# #### 🏗️ Activity #1
#
# Your task is to evaluate the various Retriever methods against eachother.
#
# You are expected to:
#
# 1. Create a "golden dataset"
#  - Use Synthetic Data Generation (powered by Ragas, or otherwise) to create this dataset
# 2. Evaluate each retriever with *retriever specific* Ragas metrics
#  - Semantic Chunking is not considered a retriever method and will not be required for marks, but you may find it useful to do a "semantic chunking on" vs. "semantic chunking off" comparision between them
# 3. Compile these in a list and write a small paragraph about which is best for this particular data and why.
#
# Your analysis should factor in:
#   - Cost
#   - Latency
#   - Performance
#
# > NOTE: This is **NOT** required to be completed in class. Please spend time in your breakout rooms creating a plan before moving on to writing code.

# %% [markdown]
# ##### HINTS:
#
# - LangSmith provides detailed information about latency and cost.

# %%
from ragas.llms import LangchainLLMWrapper
from ragas.embeddings import LangchainEmbeddingsWrapper
from langchain_openai import ChatOpenAI
from langchain_openai import OpenAIEmbeddings
generator_llm = LangchainLLMWrapper(ChatOpenAI(model="gpt-4o"))
generator_embeddings = LangchainEmbeddingsWrapper(OpenAIEmbeddings())

# %%
from ragas.testset import TestsetGenerator

generator = TestsetGenerator(llm=generator_llm, embedding_model=generator_embeddings)
dataset = generator.generate_with_langchain_docs(documents, testset_size=10)
# Out:
# Applying SummaryExtractor:   0%|          | 0/44 [00:00<?, ?it/s]
# Applying CustomNodeFilter:   0%|          | 0/100 [00:00<?, ?it/s]
# Node 6a0b4d98-8ab6-4e19-b4de-8507c7bedc75 does not have a summary. Skipping filtering.
# Node 9e5f4eb2-b439-4b7f-b495-6adf5a368906 does not have a summary. Skipping filtering.
# Node 9571afff-9e2f-4be2-bb55-2e9b03c1dfa7 does not have a summary. Skipping filtering.
# Node 11542b14-0b87-437c-8707-c0b2929a87c9 does not have a summary. Skipping filtering.
# Node 8e5296a6-9eb9-4a13-830b-72e38836de4a does not have a summary. Skipping filtering.
# Node aecbb8ca-12e8-4789-9c81-82c4a85dd6c7 does not have a summary. Skipping filtering.
# Node d6a24950-e017-42b4-b0a7-9b2b2838221f does not have a summary. Skipping filtering.
# Node 3a0c534a-2ae9-406d-8ce6-8ed6f12733a7 does not have a summary. Skipping filtering.
# Node 474a6780-c1f3-4864-96ec-a2b38985f663 does not have a summary. Skipping filtering.
# Node e485b07c-d045-41ac-8808-bb22139dcb8a does not have a summary. Skipping filtering.
# Node 8e6b3216-1ad0-4750-b9cc-fc991ed309b1 does not have a summary. Skipping filtering.
# Node a488805e-78fd-4dfa-81a2-3334a502c655 does not have a summary. Skipping filtering.
# Node 1e05d333-2ecc-478a-988a-f9c8fbf4c793 does not have a summary. Skipping filtering.
# Node 97b73898-f219-4d7a-87a2-efc1e41d278a does not have a summary. Skipping filtering.
# Node 05bb2220-f056-4918-86c3-15adf99f66f2 does not have a summary. Skipping filtering.
# Node 941e3d52-cedd-45fd-9608-ae8382b671e0 does not have a summary. Skipping filtering.
# Node 473e403e-1dfa-4c77-b0ae-f327f575d46c does not have a summary. Skipping filtering.
# Node 49fe1183-52e1-4e10-b4ac-ecc09a004d7a does not have a summary. Skipping filtering.
# Node 0ce3bbbc-06ce-4adc-b3c0-d1376c5a3aa5 does not have a summary. Skipping filtering.
# Node 39a8a168-a382-4648-be7e-ed8575df1dab does not have a summary. Skipping filtering.
# Node 31c9137f-02f7-49b3-bfa5-58f64220b3e9 does not have a summary. Skipping filtering.
# Node f7b1c279-1293-4f42-92da-002eb24aff2c does not have a summary. Skipping filtering.
# Node 0f5a93e6-3ef7-4975-a807-5720aec9c1c9 does not have a summary. Skipping filtering.
# Node 9f669e85-e475-4f7c-900f-35214c7846df does not have a summary. Skipping filtering.
# Node 22bea865-8551-440c-a114-953377b8c88b does not have a summary. Skipping filtering.
# Node 7c6b08a5-2f61-4ab8-b0ca-fb175351d86a does not have a summary. Skipping filtering.
# Node f1a219df-0a13-4be0-98f2-ebf46c2d9432 does not have a summary. Skipping filtering.
# Node fc78b4eb-1018-49c5-b71d-8cd151ecf73c does not have a summary. Skipping filtering.
# Node 83de5465-8a5c-4898-8206-3a121d81dc40 does not have a summary. Skipping filtering.
# Node 987fbc95-4029-4f4d-9159-edf4a28c4f3e does not have a summary. Skipping filtering.
# Node 6bbb888c-d2b5-40f9-be6d-6a099502e4db does not have a summary. Skipping filtering.
# Node 41a7c6cb-8e75-4d65-818a-57011f2b67ce does not have a summary. Skipping filtering.
# Node b4d8c806-0cbc-46c3-9588-5ede265c609f does not have a summary. Skipping filtering.
# Node f582af9f-e9a3-4af2-b588-b07692fb5dd9 does not have a summary. Skipping filtering.
# Node a21921eb-4469-4456-86ca-61c3a2e77122 does not have a summary. Skipping filtering.
# Node 77e2788b-e12e-4136-9a8e-eb959de58e7b does not have a summary. Skipping filtering.
# Node 7e0cc741-d80f-405a-ad41-c1e0e89a5bf7 does not have a summary. Skipping filtering.
# Node 7e0696c8-555d-4360-bf0d-e23c36264edc does not have a summary. Skipping filtering.
# Node 2de3f728-0bcd-4fd3-b1ef-003397e6b94b does not have a summary. Skipping filtering.
# Node 94e1d414-aa76-4fe8-a4fc-1b7cfadaee2e does not have a summary. Skipping filtering.
# Node 5c2ea71a-ef7e-4f58-9137-5e113e5faac4 does not have a summary. Skipping filtering.
# Node 9ba9a7ee-1467-4873-ab78-4cae28e6ea5e does not have a summary. Skipping filtering.
# Node 7ec089c1-381d-48d3-bce1-438b07234ef4 does not have a summary. Skipping filtering.
# Node 4d6d82e3-9c81-4a9e-94de-41fb4a894181 does not have a summary. Skipping filtering.
# Node 639f47de-91c5-4045-a0f2-9f3d909ceee1 does not have a summary. Skipping filtering.
# Node 1d22a1c4-8709-421c-ab97-4c884ee76526 does not have a summary. Skipping filtering.
# Node 4ae04039-83c1-4a25-a884-55f10572f4f9 does not have a summary. Skipping filtering.
# Node 5b52d68b-3387-4b43-999a-ee367f9b74cd does not have a summary. Skipping filtering.
# Node 62781f76-96ac-49c6-84fa-1c6170d1ce1f does not have a summary. Skipping filtering.
# Node 5252765e-f9a7-4b12-92af-64f9762ebcc5 does not have a summary. Skipping filtering.
# Node 9e39e36e-4125-4c89-a9b2-ea03345acd20 does not have a summary. Skipping filtering.
# Node c1500482-2c70-41d4-9847-126f2cf91dc3 does not have a summary. Skipping filtering.
# Node 2f6f0c0e-5d5d-4338-8e3f-1806e3a95deb does not have a summary. Skipping filtering.
# Node b76868f1-698f-4428-8dba-8fd01f6d22db does not have a summary. Skipping filtering.
# Node ece81254-8381-453c-be3f-88634f547cf2 does not have a summary. Skipping filtering.
# Node 377c04af-5b48-4ef8-8a50-52986439a76c does not have a summary. Skipping filtering.
# Applying [EmbeddingExtractor, ThemesExtractor, NERExtractor]:   0%|          | 0/244 [00:00<?, ?it/s]
# Applying OverlapScoreBuilder:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating personas:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating Scenarios:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating Samples:   0%|          | 0/10 [00:00<?, ?it/s]

# %%
import time
from ragas import evaluate, RunConfig
from ragas.llms import LangchainLLMWrapper
from ragas.metrics import LLMContextRecall, Faithfulness, FactualCorrectness, ResponseRelevancy, ContextEntityRecall, NoiseSensitivity
from ragas import EvaluationDataset

from ragas import EvaluationDataset

def get_variable_name(var, scope):
    for name, value in scope.items():
        if value is var:
            return name
    return None

def evaluate_one_chain(dataset, the_chain):
    start_time = time.perf_counter()

    for test_row in dataset:
        response = the_chain.invoke({"question" : test_row.eval_sample.user_input})
        print("response", response)
        print("response[response]", response["response"].content)
        test_row.eval_sample.response = response["response"].content
        test_row.eval_sample.retrieved_contexts = [context.page_content for context in response["context"]]

    evaluation_dataset = EvaluationDataset.from_pandas(dataset.to_pandas())
    evaluator_llm = LangchainLLMWrapper(ChatOpenAI(model="gpt-4o"))
    custom_run_config = RunConfig(timeout=360)

    result = evaluate(
        dataset=evaluation_dataset,
        metrics=[LLMContextRecall(), Faithfulness(), FactualCorrectness(), ResponseRelevancy(), ContextEntityRecall(), NoiseSensitivity()],
        llm=evaluator_llm,
        run_config=custom_run_config
    )
    end_time = time.perf_counter()
    print(get_variable_name(the_chain, globals()), end_time - start_time)
    return result

# %%
result_multi_query_retrieval = evaluate_one_chain(dataset, multi_query_retrieval_chain)
# Out:
# response {'response': AIMessage(content="I don't know.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 6, 'prompt_tokens': 4657, 'total_tokens': 4663, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-2e9b53fa-0aeb-46c8-b28a-064e7e8b8141-0', usage_metadata={'input_tokens': 4657, 'output_tokens': 6, 'total_tokens': 4663, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_2.csv', 'row': 19, 'Review_Date': '29 November 2020', 'Review_Title': ' John Wick Kills A Lot Of People\n', 'Review_Url': '/review/rw6320115/?ref_=tt_urv', 'Author': 'boblipton', 'Rating': 5, 'Movie_Title': 'John Wick 2', 'last_accessed_at': '2025-02-26T11:40:31.292549', '_id': 'c6a990d6fb27499096a867702c0bdfaf', '_collection_name': 'JohnWick'}, page_content=": 19\nReview: If you've seen the first John Wick movie, you know that Keanu Reeves is John Wick, a retired assassin who comes out of retirement when someone kills his dog. In this one, which begins a week later, matters are still reverberating, and some one has stolen his car, which calls for a lot of carnage. That settled, John is called on to pay off an old debt by helping Ian McShane take over the Assassin's Guild by flying around to Italy, Canada and Manhattan and killing what seems like hundreds of assassins."), Document(metadata={'source': 'john_wick_2.csv', 'row': 20, 'Review_Date': '28 May 2017', 'Review_Title': ' A New Franchise is Born\n', 'Review_Url': '/review/rw3718180/?ref_=tt_urv', 'Author': 'claudio_carvalho', 'Rating': 8, 'Movie_Title': 'John Wick 2', 'last_accessed_at': '2025-02-26T11:40:31.292549', '_id': '14e4e01f095c4b559b49399bfd92e08f', '_collection_name': 'JohnWick'}, page_content=": 20\nReview: After resolving his issues with the Russian mafia, John Wick (Keanu Reeves) returns home. But soon the mobster Santino D'Antonio (Riccardo Scamarcio) visits him to show Wick's marker and tells that he needs to help. John Wicks refuses since he is retired and Santino blows-up his house. John Wick meets the owner of the Continental hotel in New York City, Winston (Ian McShane), and he tells that Wick cannot violate the Mafia rules and shall honor the marker. Santino asks John Wick to kill his sister Gianna D'Antonio (Claudia Gerini) in Rome so that he can sit on the High Table of the criminal organizations. When John Wicks accomplishes his assignment, Santino puts a seven-million dollar contract on him attracting professional killers from everywhere. But Wick promises to kill Santino that is not protected by his marker anymore."), Document(metadata={'source': 'john_wick_1.csv', 'row': 0, 'Review_Date': '6 May 2015', 'Review_Title': ' Kinetic, concise, and stylish; John Wick kicks ass.\n', 'Review_Url': '/review/rw3233896/?ref_=tt_urv', 'Author': 'lnvicta', 'Rating': 8, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292319', '_id': 'e1a0f158b67f4d4681b444e63f512cb9', '_collection_name': 'JohnWick'}, page_content=": 0\nReview: The best way I can describe John Wick is to picture Taken but instead of Liam Neeson it's Keanu Reeves and instead of his daughter it's his dog. That's essentially the plot of the movie. John Wick (Reeves) is out to seek revenge on the people who took something he loved from him. It's a beautifully simple premise for an action movie - when action movies get convoluted, they get bad i.e. A Good Day to Die Hard. John Wick gives the viewers what they want: Awesome action, stylish stunts, kinetic chaos, and a relatable hero to tie it all together. John Wick succeeds in its simplicity."), Document(metadata={'source': 'john_wick_1.cs ...
# response[response] I don't know.
# response {'response': AIMessage(content='The reception of the John Wick franchise, particularly with the release of the fourth installment, seems to be overwhelmingly positive. Reviewers have praised the film for its action sequences, creativity, and the continuation of the beloved franchise. Critics have highlighted the expert choreography, the infusion of creativity, and the improvement on previous installments. Overall, it appears that the reception of John Wick 4 has been very favorable based on the reviews provided.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 88, 'prompt_tokens': 3249, 'total_tokens': 3337, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-2b6f416f-822e-4bb4-ab95-7ddafc7ee6a6-0', usage_metadata={'input_tokens': 3249, 'output_tokens': 88, 'total_tokens': 3337, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_4.csv', 'row': 18, 'Review_Date': '17 March 2023', 'Review_Title': ' Not Just The Best John Wick, But Possibly One Of The Best Action Movies Ever\n', 'Review_Url': '/review/rw8935367/?ref_=tt_urv', 'Author': 'cadillac20', 'Rating': 10, 'Movie_Title': 'John Wick 4', 'last_accessed_at': '2025-02-28T11:40:31.292929', '_id': 'fb6da2a08531428d890d90e797894e1f', '_collection_name': 'JohnWick'}, page_content=": 18\nReview: Ever since the original John Wick, the franchise has set a standard of what action in Hollywood should be. Thanks to Chad Stahelski and Keanu Reeve's knowledge of the technical aspects of shooting action, they've been able to deliver expertly choreographed, shot, and edited action films that are now the go to as examples of great action filmmaking. And so, the expectations for the fourth film were fairly high, especially as it became more apparent this was not only the culmination of everything before it, but a whopping 169 minutes long. Rest assured, however, that it delivers in spades. Everything we have come to know and love is here, but with an infusion of creativity like we haven't seen from the franchise yet."), Document(metadata={'source': 'john_wick_4.csv', 'row': 20, 'Review_Date': '23 March 2023', 'Review_Title': ' THIS is how you justify a 3 hour runtime\n', 'Review_Url': '/review/rw8946038/?ref_=tt_urv', 'Author': 'jtindahouse', 'Rating': 9, 'Movie_Title': 'John Wick 4', 'last_accessed_at': '2025-02-28T11:40:31.292931', '_id': '2b2772db123f4ba4bff10cc8c5e610a2', '_collection_name': 'JohnWick'}, page_content=": 20\nReview: In a world where movie sequels seem to be loathed even before they are released, the 'John Wick' series has remained remarkably consistent and well received. In fact all three of the first films have the same IMDb rating of 7.4/10 and I noticed recently that I gave them all the same rating of 8/10. Incredibly, I think 'John Wick: Chapter 4' is the best the series has to offer. This movie was a wild ride."), Document(metadata={'source': 'john_wick_1.csv', 'row': 2, 'Review_Date': '5 May 2023', 'Review_Title': " You don't mess with another person's dog. It's as simple as that!\n", 'Review_Url': '/review/rw9033669/?ref_=tt_urv', 'Author': 'Coventry', 'Rating': 5, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292335', '_id': '45f2fd8ae7b944aab11b4712418de73c', '_collection_name': 'JohnWick'}, page_content=': 2\nReview: With the fourth installment scoring immensely at the cinemas as I\'m submitting this review, and after three previous films that are apparently loved by everyone else in the world, I thought perhaps it would be time for me check out "John Wick".'), Document(metadata={'source': 'john_wick_4.csv', 'r ...
# response[response] The reception of the John Wick franchise, particularly with the release of the fourth installment, seems to be overwhelmingly positive. Reviewers have praised the film for its action sequences, creativity, and the continuation of the beloved franchise. Critics have highlighted the expert choreography, the infusion of creativity, and the improvement on previous installments. Overall, it appears that the reception of John Wick 4 has been very favorable based on the reviews provided.
# response {'response': AIMessage(content="Chad Stahelski's direction in the John Wick films contributes to their uniqueness by showcasing real virtuoso action sequences and well-made choreographies. Unlike many action movies today, Stahelski's direction avoids quick-cuts or shaky cameras, allowing the audience to see clearly what's going on in the action scenes. This emphasis on fluid, well-executed action sets the John Wick films apart in the action genre.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 87, 'prompt_tokens': 4447, 'total_tokens': 4534, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-87810a2e-c43b-48f7-9ea6-8baa6814d5ef-0', usage_metadata={'input_tokens': 4447, 'output_tokens': 87, 'total_tokens': 4534, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_1.csv', 'row': 3, 'Review_Date': '28 September 2018', 'Review_Title': ' Keanu gets pissed and shoots people in the face for 101 minutes*\n', 'Review_Url': '/review/rw4366368/?ref_=tt_urv', 'Author': 'Kitsfi', 'Rating': 8, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292336', '_id': 'bbef47586c9142cb9757e322fc560993', '_collection_name': 'JohnWick'}, page_content=': 3\nReview: John wick has a very simple revenge story. It can be summarized as "Keanu gets angry and shoots bad guys" but what makes it special? Directed by Chad Stahelski who\'s a stunt specialist boy does it show because the main selling point in the film are some real virtuoso action sequences, well made choreographies. Unlike today\'s action movies, it doesn\'t use quick-cuts or shaky cameras actually see what\'s going on.'), Document(metadata={'source': 'john_wick_4.csv', 'row': 18, 'Review_Date': '17 March 2023', 'Review_Title': ' Not Just The Best John Wick, But Possibly One Of The Best Action Movies Ever\n', 'Review_Url': '/review/rw8935367/?ref_=tt_urv', 'Author': 'cadillac20', 'Rating': 10, 'Movie_Title': 'John Wick 4', 'last_accessed_at': '2025-02-28T11:40:31.292929', '_id': 'fb6da2a08531428d890d90e797894e1f', '_collection_name': 'JohnWick'}, page_content=": 18\nReview: Ever since the original John Wick, the franchise has set a standard of what action in Hollywood should be. Thanks to Chad Stahelski and Keanu Reeve's knowledge of the technical aspects of shooting action, they've been able to deliver expertly choreographed, shot, and edited action films that are now the go to as examples of great action filmmaking. And so, the expectations for the fourth film were fairly high, especially as it became more apparent this was not only the culmination of everything before it, but a whopping 169 minutes long. Rest assured, however, that it delivers in spades. Everything we have come to know and love is here, but with an infusion of creativity like we haven't seen from the franchise yet."), Document(metadata={'source': 'john_wick_3.csv', 'row': 5, 'Review_Date': '17 July 2019', 'Review_Title': ' The magic is gone\n', 'Review_Url': '/review/rw4999970/?ref_=tt_urv', 'Author': 'soundoflight', 'Rating': 5, 'Movie_Title': 'John Wick 3', 'last_accessed_at': '2025-02-27T11:40:31.292734', '_id': 'c6cdfe27a2d54fd8b1d997018572469b', '_collection_name': 'JohnWick'}, page_content=': 5\nReview: The first John Wick film was special because it broke a mold of sorts. It went against certain action film conventions - the hero was not a muscle bound hulk like a Schwarzenegger or Stallone, the action was super fast paced, the plot was basic and straighforward, but introduced some unique elements, and there was something a bit unique and stylish about the film. John Wic ...
# response[response] Chad Stahelski's direction in the John Wick films contributes to their uniqueness by showcasing real virtuoso action sequences and well-made choreographies. Unlike many action movies today, Stahelski's direction avoids quick-cuts or shaky cameras, allowing the audience to see clearly what's going on in the action scenes. This emphasis on fluid, well-executed action sets the John Wick films apart in the action genre.
# response {'response': AIMessage(content='John Wick goes after the Russian mobsters because they killed his dog, beat him senseless, destroyed his stuff, and stole his car. This act of violence and betrayal leads John Wick to seek vengeance against the Russian mobsters.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 47, 'prompt_tokens': 4085, 'total_tokens': 4132, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-0e0eb3c4-776a-4c64-8913-521637a9446a-0', usage_metadata={'input_tokens': 4085, 'output_tokens': 47, 'total_tokens': 4132, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_1.csv', 'row': 18, 'Review_Date': '10 September 2019', 'Review_Title': ' Probably NOT a film to watch with your kids or mother.\n', 'Review_Url': '/review/rw5112990/?ref_=tt_urv', 'Author': 'planktonrules', 'Rating': 7, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292348', '_id': '1499620ac8b34aa7a289671959c34fd1', '_collection_name': 'JohnWick'}, page_content=": 18\nReview: When the story begins, John (Keanu Reeves) has just lost his wife. After her death, he's a bit lost but tries to rebuild his life. One day, he's getting gas and a young Russian-American punk notices Wick's classic car...and tries to buy it off him. But Wick isn't interested and declines. Soon, the punk arrives at Wick's home with some goons where they surprise him--beating him senseless, destroying his stuff, killing his dog and stealing his car! This is when you then learn that Wick is a super-assassin....and the punk chose the wrong guy to attack. The jerk's father is a big-time Russian mobster....and it's a contest to see who will win...the mobster and his gang or Wick on his own. Considering there are (so far) two MORE John Wick films, it pretty much seems certain who will win this battle."), Document(metadata={'source': 'john_wick_2.csv', 'row': 20, 'Review_Date': '28 May 2017', 'Review_Title': ' A New Franchise is Born\n', 'Review_Url': '/review/rw3718180/?ref_=tt_urv', 'Author': 'claudio_carvalho', 'Rating': 8, 'Movie_Title': 'John Wick 2', 'last_accessed_at': '2025-02-26T11:40:31.292549', '_id': '14e4e01f095c4b559b49399bfd92e08f', '_collection_name': 'JohnWick'}, page_content=": 20\nReview: After resolving his issues with the Russian mafia, John Wick (Keanu Reeves) returns home. But soon the mobster Santino D'Antonio (Riccardo Scamarcio) visits him to show Wick's marker and tells that he needs to help. John Wicks refuses since he is retired and Santino blows-up his house. John Wick meets the owner of the Continental hotel in New York City, Winston (Ian McShane), and he tells that Wick cannot violate the Mafia rules and shall honor the marker. Santino asks John Wick to kill his sister Gianna D'Antonio (Claudia Gerini) in Rome so that he can sit on the High Table of the criminal organizations. When John Wicks accomplishes his assignment, Santino puts a seven-million dollar contract on him attracting professional killers from everywhere. But Wick promises to kill Santino that is not protected by his marker anymore."), Document(metadata={'source': 'john_wick_1.csv', 'row': 5, 'Review_Date': '23 March 2023', 'Review_Title': ' Violent and gripping story with plenty of unstopped action , shootouts and breathtaking fights\n', 'Review_Url': '/review/rw8945545/?ref_=tt_urv', 'Author': 'ma-cortes', 'Rating': 7, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292338', '_id': '5c16d3bf25b64afdb3e2a3f3c6f1d4cc', '_collection_name': 'JohnWick'}, page_content=": 5\nReview: Ultra-violent first entry with lots of kill ...
# response[response] John Wick goes after the Russian mobsters because they killed his dog, beat him senseless, destroyed his stuff, and stole his car. This act of violence and betrayal leads John Wick to seek vengeance against the Russian mobsters.
# response {'response': AIMessage(content="In the first John Wick movie, John Wick is mad because the gangsters killed his dog and took everything from him. This act of violence against his beloved dog and the memory of his wife's death drives him to seek vengeance against those responsible.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 50, 'prompt_tokens': 4497, 'total_tokens': 4547, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-71178f1d-bbfa-41eb-89be-5ec9e864db2d-0', usage_metadata={'input_tokens': 4497, 'output_tokens': 50, 'total_tokens': 4547, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_1.csv', 'row': 5, 'Review_Date': '23 March 2023', 'Review_Title': ' Violent and gripping story with plenty of unstopped action , shootouts and breathtaking fights\n', 'Review_Url': '/review/rw8945545/?ref_=tt_urv', 'Author': 'ma-cortes', 'Rating': 7, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292338', '_id': '5c16d3bf25b64afdb3e2a3f3c6f1d4cc', '_collection_name': 'JohnWick'}, page_content=": 5\nReview: Ultra-violent first entry with lots of killings, thrills , noisy action , suspense , and crossfire . In this original John Wick (2014) , an ex-hit-man comes out of retirement to track down the gangsters that killed his dog and took everything from him . With the untimely death of his beloved wife still bitter in his mouth he seeks for vengeance . But when an arrogant Russian mob prince and hoodlums steal his car and kill his dog , they are fully aware of his lethal capacity. The Bogeyman will find himself dragged into an impossible task as every killer in the business dreams of cornering the legendary Wick who now has an enormous price on his head . In this first installment John Wick , blind with revenge, and for his salvation John will immediately unleash a carefully orchestrated maelstrom of destruction against those attempt to chase him and with a price tag on his head, as he is the target of hit men : an army of bounty-hunting killers on his trail and a murderer woman everywhere . The legendary hitman will be forced to unearth his meticulously concealed identity and to carry out a relentless vendetta . Now, only blood can quench the boogeyman's thirst for retribution . Don't Set Him Off! . John Wick isn't the Boogeyman... He's the guy you send to kill the doomed Boogeyman. Revenge is all he has left. You want peace, prepare for war . Don't Hunt What You Can't Kill. Tick Tock, Mr. Wick. Everyone Is Waiting. For John Wick . Every Action Has Consequences. This Friday, Wick is Back . Its the World Vs. Wick. Every Action Has Consequences."), Document(metadata={'source': 'john_wick_1.csv', 'row': 18, 'Review_Date': '10 September 2019', 'Review_Title': ' Probably NOT a film to watch with your kids or mother.\n', 'Review_Url': '/review/rw5112990/?ref_=tt_urv', 'Author': 'planktonrules', 'Rating': 7, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292348', '_id': '1499620ac8b34aa7a289671959c34fd1', '_collection_name': 'JohnWick'}, page_content=": 18\nReview: When the story begins, John (Keanu Reeves) has just lost his wife. After her death, he's a bit lost but tries to rebuild his life. One day, he's getting gas and a young Russian-American punk notices Wick's classic car...and tries to buy it off him. But Wick isn't interested and declines. Soon, the punk arrives at Wick's home with some goons where they surprise him--beating him senseless, destroying his stuff, killing his dog and stealing his car! This is when you then learn that Wick is a super-assassin....a ...
# response[response] In the first John Wick movie, John Wick is mad because the gangsters killed his dog and took everything from him. This act of violence against his beloved dog and the memory of his wife's death drives him to seek vengeance against those responsible.
# response {'response': AIMessage(content="'John Wick: Chapter 2' stands out among American action films for its relentless violence, slick action sequences, and the sheer brilliance in its set design and camera work. The movie delivers on the action front and sets the bar high in terms of pure escapist entertainment. Additionally, the film maintains the elements that made its predecessor successful while expanding the story and delivery of hard-core action. Ultimately, the film is praised for its professionalism in delivering intense action and violence.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 95, 'prompt_tokens': 4560, 'total_tokens': 4655, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-391a182c-1421-4e0a-9364-1c6055fd83e4-0', usage_metadata={'input_tokens': 4560, 'output_tokens': 95, 'total_tokens': 4655, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_2.csv', 'row': 9, 'Review_Date': '22 July 2017', 'Review_Title': ' A disappointing sequel for the most part\n', 'Review_Url': '/review/rw3760991/?ref_=tt_urv', 'Author': 'Horst_In_Translation', 'Rating': 4, 'Movie_Title': 'John Wick 2', 'last_accessed_at': '2025-02-26T11:40:31.292541', '_id': '5ea64efd95dd415d88fb72960a633636', '_collection_name': 'JohnWick'}, page_content=': 9\nReview: "John Wick: Chapter 2" is an American movie from this year (2017). Experienced visual effects artist Stahelski and Kolstad returned from the very first Wick film to work on the script/direction here too, so the premise with regard to people working behind the camera is there. And in front of the camera we see familiar faces again, people that survived the film, like most of all Keanu Reeves playing the central character. This is a really long film at over 2 hours and at this runtime, it is considerably longer than the first. And there is a lot other stuff different compared to the original. Most has to do with the fun component. I think the first film was a great fun watch from start to finish while offering emotion nonetheless and also delivering in the crime and drama genres. And action too, but I don\'t care too much about that. This genre is also basically the only one where this new movie delivers as the first 30 minutes are truly packed with action. It gets less afterward, but there is no denying that it was still all about the action and nothing else.'), Document(metadata={'source': 'john_wick_2.csv', 'row': 16, 'Review_Date': '9 February 2017', 'Review_Title': ' Kick-ass, entertaining and relentless throughout. This is what every sequel should aspire to be.\n', 'Review_Url': '/review/rw3636884/?ref_=tt_urv', 'Author': 'trublu215', 'Rating': 5, 'Movie_Title': 'John Wick 2', 'last_accessed_at': '2025-02-26T11:40:31.292546', '_id': '3b935f6ed310465b801954cade3ce370', '_collection_name': 'JohnWick'}, page_content=": 16\nReview: John Wick Chapter 2 pits Keanu Reeves' titular character against the mean and nefarious of the criminal underworld. Once again, Reeves proves that he is a force to be reckoned with in this ridiculous, over-the-top sequel that is every bit as fun as the original. These types of films are rarely known for their artistic value but John Wick: Chapter 2 sets the bar pretty high, not only in its action, but in it's set design and camera work. This is pure escapist entertainment and couldn't have come at a better time. Those wanting to take a break from watching the Oscar nominees, this film is exactly what you're looking for."), Document(metadata={'source': 'john_wick_1.csv', 'row': 20, 'Review_Date': '22 October 2014', 'Review_Title': '  ...
# response[response] 'John Wick: Chapter 2' stands out among American action films for its relentless violence, slick action sequences, and the sheer brilliance in its set design and camera work. The movie delivers on the action front and sets the bar high in terms of pure escapist entertainment. Additionally, the film maintains the elements that made its predecessor successful while expanding the story and delivery of hard-core action. Ultimately, the film is praised for its professionalism in delivering intense action and violence.
# response {'response': AIMessage(content="According to reviews, John Wick: Chapter 4 improves upon John Wick: Chapter 3 - Parabellum by delivering expertly choreographed, shot, and edited action sequences, solidifying Keanu Reeves as the greatest martial arts action star of all time, and infusing creativity that hasn't been seen before in the franchise.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 69, 'prompt_tokens': 3323, 'total_tokens': 3392, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-6ab99e66-7ca1-46f4-a748-bacba6bb77f6-0', usage_metadata={'input_tokens': 3323, 'output_tokens': 69, 'total_tokens': 3392, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_4.csv', 'row': 19, 'Review_Date': '17 March 2023', 'Review_Title': ' The Best John Wick Sequel\n', 'Review_Url': '/review/rw8935117/?ref_=tt_urv', 'Author': 'tkdlifemagazine', 'Rating': 9, 'Movie_Title': 'John Wick 4', 'last_accessed_at': '2025-02-28T11:40:31.292930', '_id': '9d49fc87e57645e0b304d3f1bb6446bf', '_collection_name': 'JohnWick'}, page_content=": 19\nReview: John Wick: Chapter 4 picks up where Chapter 3: Parabellum left off. As has been the tradition in the sequels to this beloved martial arts action franchise the action starts from the very inception of the film's opening, and lasts until the curtain falls. JW4 is no exception to that rule. What it does do is improve on the prior installment, and solidify Keanu Reeves as the greatest martial arts action star of all time. If you don't accept that notion, then you must accept the fact that it solidifies Reeves and Director, Chad Stahelski, as the greatest martial arts action pairing of modern times."), Document(metadata={'source': 'john_wick_3.csv', 'row': 24, 'Review_Date': '17 May 2019', 'Review_Title': ' Makes John Wick a superb trilogy\n', 'Review_Url': '/review/rw4860603/?ref_=tt_urv', 'Author': 'masonsaul', 'Rating': 10, 'Movie_Title': 'John Wick 3', 'last_accessed_at': '2025-02-27T11:40:31.292750', '_id': '6daad8494ac4440a9b12f739582a5326', '_collection_name': 'JohnWick'}, page_content=": 24\nReview: John Wick: Chapter 3 - Parabellum is quite literally about consequences, dealing with the fallout of John's actions at the end of the previous film and sending him on an even bigger odyssey of violence that continues to explore this world of assassination and deliver beautifully clean action sequences."), Document(metadata={'source': 'john_wick_3.csv', 'row': 13, 'Review_Date': '15 May 2019', 'Review_Title': ' Pure, delirious joy in the form of yet another exhilarating thriller\n', 'Review_Url': '/review/rw4855261/?ref_=tt_urv', 'Author': 'themadmovieman', 'Rating': 8, 'Movie_Title': 'John Wick 3', 'last_accessed_at': '2025-02-27T11:40:31.292740', '_id': 'f7a59724573a437d9a0a50eae0487a6b', '_collection_name': 'JohnWick'}, page_content=": 13\nReview: Following on from two deliriously entertaining, visually gorgeous and blissfully simplistic thrillers, John Wick: Chapter 3 - Parabellum keeps up the franchise's unique appeal in stunning fashion. Complete with electrifying action, beautiful cinematography, a pulsating score and a great sense of humour, the film is pretty much as purely joyful as action thrillers get, and proves two hours of brilliant entertainment."), Document(metadata={'source': 'john_wick_3.csv', 'row': 0, 'Review_Date': '22 September 2019', 'Review_Title': ' Enjoyably choreographed, but the lack of consequence combined with the global scale robs it of urgency and means it outstays its welcome a bit\n', 'Review_Url': '/review/rw5136960/?ref_=tt_urv', 'Author': 'bob ...
# response[response] According to reviews, John Wick: Chapter 4 improves upon John Wick: Chapter 3 - Parabellum by delivering expertly choreographed, shot, and edited action sequences, solidifying Keanu Reeves as the greatest martial arts action star of all time, and infusing creativity that hasn't been seen before in the franchise.
# response {'response': AIMessage(content="The John Wick franchise has set a standard for Hollywood action films by delivering expertly choreographed, shot, and edited action sequences that are examples of great action filmmaking. Compared to other American action flicks, John Wick stands out for having a strong screenplay and minimal use of CGI, focusing more on practical effects and realistic action. The franchise's attention to detail and focus on technical aspects set it apart from many contemporary action films that rely heavily on CGI and have subpar screenplays.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 98, 'prompt_tokens': 5088, 'total_tokens': 5186, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-a9a378e0-f8ff-4a51-b557-d54d520d41a7-0', usage_metadata={'input_tokens': 5088, 'output_tokens': 98, 'total_tokens': 5186, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_4.csv', 'row': 10, 'Review_Date': '22 March 2023', 'Review_Title': ' How Can Anyone Choose to Watch Marvel Over This?\n', 'Review_Url': '/review/rw8944843/?ref_=tt_urv', 'Author': 'lovemichaeljordan', 'Rating': 8, 'Movie_Title': 'John Wick 4', 'last_accessed_at': '2025-02-28T11:40:31.292923', '_id': 'b66f76b8e43648f59089c83623a0c5c1', '_collection_name': 'JohnWick'}, page_content=": 10\nReview: Most American action flicks released these days have poor screenplays and overuse computer-generated imagery. The John Wick franchise is one of the few exceptions, along with Mission Impossible. These franchises keep getting better with every entry. Hollywood can make action masterpieces, but Marvel has greater demand, so that's what we get most of. It's a shame."), Document(metadata={'source': 'john_wick_3.csv', 'row': 5, 'Review_Date': '17 July 2019', 'Review_Title': ' The magic is gone\n', 'Review_Url': '/review/rw4999970/?ref_=tt_urv', 'Author': 'soundoflight', 'Rating': 5, 'Movie_Title': 'John Wick 3', 'last_accessed_at': '2025-02-27T11:40:31.292734', '_id': 'c6cdfe27a2d54fd8b1d997018572469b', '_collection_name': 'JohnWick'}, page_content=': 5\nReview: The first John Wick film was special because it broke a mold of sorts. It went against certain action film conventions - the hero was not a muscle bound hulk like a Schwarzenegger or Stallone, the action was super fast paced, the plot was basic and straighforward, but introduced some unique elements, and there was something a bit unique and stylish about the film. John Wick was cool.'), Document(metadata={'source': 'john_wick_4.csv', 'row': 18, 'Review_Date': '17 March 2023', 'Review_Title': ' Not Just The Best John Wick, But Possibly One Of The Best Action Movies Ever\n', 'Review_Url': '/review/rw8935367/?ref_=tt_urv', 'Author': 'cadillac20', 'Rating': 10, 'Movie_Title': 'John Wick 4', 'last_accessed_at': '2025-02-28T11:40:31.292929', '_id': 'fb6da2a08531428d890d90e797894e1f', '_collection_name': 'JohnWick'}, page_content=": 18\nReview: Ever since the original John Wick, the franchise has set a standard of what action in Hollywood should be. Thanks to Chad Stahelski and Keanu Reeve's knowledge of the technical aspects of shooting action, they've been able to deliver expertly choreographed, shot, and edited action films that are now the go to as examples of great action filmmaking. And so, the expectations for the fourth film were fairly high, especially as it became more apparent this was not only the culmination of everything before it, but a whopping 169 minutes long. Rest assured, however, that it delivers in spades. Everything we have come to know and love is here, but with an inf ...
# response[response] The John Wick franchise has set a standard for Hollywood action films by delivering expertly choreographed, shot, and edited action sequences that are examples of great action filmmaking. Compared to other American action flicks, John Wick stands out for having a strong screenplay and minimal use of CGI, focusing more on practical effects and realistic action. The franchise's attention to detail and focus on technical aspects set it apart from many contemporary action films that rely heavily on CGI and have subpar screenplays.
# response {'response': AIMessage(content="The reviews reflect positively on Keanu Reeves' portrayal in the John Wick franchise, particularly in terms of action choreography and character depth. Reviewers praised Reeves' performance as John Wick, highlighting his slickness, natural movement, and cool demeanor in action sequences. The choreography, direction, and execution of the action scenes were also highly appreciated, with the movies drawing praise for their kinetic, stylish, and well-made action sequences. Reeves' portrayal of the character was seen as a return to form for him in the action genre, with his performance adding depth to the character of John Wick. Overall, the reviews indicate that Keanu Reeves' portrayal in the John Wick franchise, along with the action choreography, received positive feedback from viewers.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 151, 'prompt_tokens': 4414, 'total_tokens': 4565, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-d4bfda21-b866-4541-9620-680e0974b6ba-0', usage_metadata={'input_tokens': 4414, 'output_tokens': 151, 'total_tokens': 4565, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_1.csv', 'row': 3, 'Review_Date': '28 September 2018', 'Review_Title': ' Keanu gets pissed and shoots people in the face for 101 minutes*\n', 'Review_Url': '/review/rw4366368/?ref_=tt_urv', 'Author': 'Kitsfi', 'Rating': 8, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292336', '_id': 'bbef47586c9142cb9757e322fc560993', '_collection_name': 'JohnWick'}, page_content=': 3\nReview: John wick has a very simple revenge story. It can be summarized as "Keanu gets angry and shoots bad guys" but what makes it special? Directed by Chad Stahelski who\'s a stunt specialist boy does it show because the main selling point in the film are some real virtuoso action sequences, well made choreographies. Unlike today\'s action movies, it doesn\'t use quick-cuts or shaky cameras actually see what\'s going on.'), Document(metadata={'source': 'john_wick_1.csv', 'row': 9, 'Review_Date': '20 October 2014', 'Review_Title': " The coolest action film you'll see all year\n", 'Review_Url': '/review/rw3107759/?ref_=tt_urv', 'Author': 'trublu215', 'Rating': 9, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292341', '_id': '2d6f65f3952a485588a13c19fdf9fdf0', '_collection_name': 'JohnWick'}, page_content=": 9\nReview: At first glance, John Wick sounds like a terrible film on paper but with the slickness of Keanu Reeves' performance as the titular character and the sheer brilliance in its action sequences, this marks the best action film of the year and one of the absolute best in the past decade. Following a brutal home invasion that leaves his beloved dog murdered by thugs from his past, John Wick vows revenge on the ones who have taken what he loves most. Like I said, on paper, this seems like a direct-to-DVD slopfest starring John Cena but as a film with Keanu Reeves as the lead, it marks the very welcomed return for Reeves to the genre. John Wick is insanely fun, violently brutal and an overall romp especially for those disappointed by The Expendables 3. John Wick is propelled by Tarantino-esque dialog mixed with the swagger of action stars from the 70s. Reeves literally emulates cool in this film and does it with such confidence, that we don't even doubt the character...even when he kills countless bad guys with extreme force in some utterly ridiculous and implausible situations. We don't doubt it for a minute. This is EXACTLY what you want out of an ...
# response[response] The reviews reflect positively on Keanu Reeves' portrayal in the John Wick franchise, particularly in terms of action choreography and character depth. Reviewers praised Reeves' performance as John Wick, highlighting his slickness, natural movement, and cool demeanor in action sequences. The choreography, direction, and execution of the action scenes were also highly appreciated, with the movies drawing praise for their kinetic, stylish, and well-made action sequences. Reeves' portrayal of the character was seen as a return to form for him in the action genre, with his performance adding depth to the character of John Wick. Overall, the reviews indicate that Keanu Reeves' portrayal in the John Wick franchise, along with the action choreography, received positive feedback from viewers.
# response {'response': AIMessage(content='Ian McShane is important in the John Wick movie because he plays the character Winston, the owner of the Continental hotel in New York City. He adds depth to the story by introducing rules and a criminal underworld that John Wick navigates. His character helps to create a sense of intrigue and mystery, making the movie more interesting by adding layers to the narrative and expanding the world in which the story takes place.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 83, 'prompt_tokens': 4366, 'total_tokens': 4449, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-a8b2673a-2e67-40f6-be6c-8b99bb433365-0', usage_metadata={'input_tokens': 4366, 'output_tokens': 83, 'total_tokens': 4449, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_2.csv', 'row': 19, 'Review_Date': '29 November 2020', 'Review_Title': ' John Wick Kills A Lot Of People\n', 'Review_Url': '/review/rw6320115/?ref_=tt_urv', 'Author': 'boblipton', 'Rating': 5, 'Movie_Title': 'John Wick 2', 'last_accessed_at': '2025-02-26T11:40:31.292549', '_id': 'c6a990d6fb27499096a867702c0bdfaf', '_collection_name': 'JohnWick'}, page_content=": 19\nReview: If you've seen the first John Wick movie, you know that Keanu Reeves is John Wick, a retired assassin who comes out of retirement when someone kills his dog. In this one, which begins a week later, matters are still reverberating, and some one has stolen his car, which calls for a lot of carnage. That settled, John is called on to pay off an old debt by helping Ian McShane take over the Assassin's Guild by flying around to Italy, Canada and Manhattan and killing what seems like hundreds of assassins."), Document(metadata={'source': 'john_wick_1.csv', 'row': 20, 'Review_Date': '22 October 2014', 'Review_Title': ' Smoothest action film to come around in a long time\n', 'Review_Url': '/review/rw3109271/?ref_=tt_urv', 'Author': 'IceSkateUpHill', 'Rating': 10, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292350', '_id': 'abf04bb7a461407a8de2219f2fc53b49', '_collection_name': 'JohnWick'}, page_content=": 20\nReview: John Wick is something special. It takes as much time setting up elaborate action sequences as it does the world with which it all takes place in. And what a world it is. It reminds me of Millers Crossing and it is cooler than any other recent attempt at noir. We are shown a criminal underworld where, if you are connected, many powerful people know who you are and show you respect. John Wick was connected but he got out. He is the rare killer who has found peace, and he is grateful for that peace. Some young kids steal that from him and he does what he does best, he wages a one man war against the Russian Mafia. It might sound like the film takes quite a leap but it all makes sense. The motives of John and the people who get in the way of his bullets are all very clear, even if it does come across as rather simple. That's the plot at it's most basic. Then there's the action. The film is directed by Reeve's stuntman from The Matrix, so this guy knows action. There are sequences that flow so smoothly it puts other action films and their quick cuts to shame. Keaunu moves so fluidly throughout the film and comes across as such a natural that the only disappointment is that we have not seen him like this before. Along the way are plenty of character actors, fans of The Matrix and The Wire will recognize a few people then there are more obvious ones like Ian McShane and Willem Dafoe. Everyone seems to be having a good time. That is anoth ...
# response[response] Ian McShane is important in the John Wick movie because he plays the character Winston, the owner of the Continental hotel in New York City. He adds depth to the story by introducing rules and a criminal underworld that John Wick navigates. His character helps to create a sense of intrigue and mystery, making the movie more interesting by adding layers to the narrative and expanding the world in which the story takes place.
# Evaluating:   0%|          | 0/60 [00:00<?, ?it/s]
# Exception raised in Job[2]: TypeError(ufunc 'invert' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe'')
# Exception raised in Job[29]: TimeoutError()
# Exception raised in Job[35]: TimeoutError()
# Exception raised in Job[47]: TimeoutError()
# Exception raised in Job[53]: TimeoutError()
# Exception raised in Job[59]: TimeoutError()
# multi_query_retrieval_chain 455.59587641700637

# %%
result_naive_retrieval = evaluate_one_chain(dataset, naive_retrieval_chain)
# Out:
# response {'response': AIMessage(content='Liam Neeson is not a character in the context of John Wick.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 3807, 'total_tokens': 3823, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-46296589-f1c7-4e90-87fb-60c5f3e4ca81-0', usage_metadata={'input_tokens': 3807, 'output_tokens': 16, 'total_tokens': 3823, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_1.csv', 'row': 0, 'Review_Date': '6 May 2015', 'Review_Title': ' Kinetic, concise, and stylish; John Wick kicks ass.\n', 'Review_Url': '/review/rw3233896/?ref_=tt_urv', 'Author': 'lnvicta', 'Rating': 8, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292319', '_id': 'e1a0f158b67f4d4681b444e63f512cb9', '_collection_name': 'JohnWick'}, page_content=": 0\nReview: The best way I can describe John Wick is to picture Taken but instead of Liam Neeson it's Keanu Reeves and instead of his daughter it's his dog. That's essentially the plot of the movie. John Wick (Reeves) is out to seek revenge on the people who took something he loved from him. It's a beautifully simple premise for an action movie - when action movies get convoluted, they get bad i.e. A Good Day to Die Hard. John Wick gives the viewers what they want: Awesome action, stylish stunts, kinetic chaos, and a relatable hero to tie it all together. John Wick succeeds in its simplicity."), Document(metadata={'source': 'john_wick_1.csv', 'row': 18, 'Review_Date': '10 September 2019', 'Review_Title': ' Probably NOT a film to watch with your kids or mother.\n', 'Review_Url': '/review/rw5112990/?ref_=tt_urv', 'Author': 'planktonrules', 'Rating': 7, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292348', '_id': '1499620ac8b34aa7a289671959c34fd1', '_collection_name': 'JohnWick'}, page_content=": 18\nReview: When the story begins, John (Keanu Reeves) has just lost his wife. After her death, he's a bit lost but tries to rebuild his life. One day, he's getting gas and a young Russian-American punk notices Wick's classic car...and tries to buy it off him. But Wick isn't interested and declines. Soon, the punk arrives at Wick's home with some goons where they surprise him--beating him senseless, destroying his stuff, killing his dog and stealing his car! This is when you then learn that Wick is a super-assassin....and the punk chose the wrong guy to attack. The jerk's father is a big-time Russian mobster....and it's a contest to see who will win...the mobster and his gang or Wick on his own. Considering there are (so far) two MORE John Wick films, it pretty much seems certain who will win this battle."), Document(metadata={'source': 'john_wick_2.csv', 'row': 19, 'Review_Date': '29 November 2020', 'Review_Title': ' John Wick Kills A Lot Of People\n', 'Review_Url': '/review/rw6320115/?ref_=tt_urv', 'Author': 'boblipton', 'Rating': 5, 'Movie_Title': 'John Wick 2', 'last_accessed_at': '2025-02-26T11:40:31.292549', '_id': 'c6a990d6fb27499096a867702c0bdfaf', '_collection_name': 'JohnWick'}, page_content=": 19\nReview: If you've seen the first John Wick movie, you know that Keanu Reeves is John Wick, a retired assassin who comes out of retirement when someone kills his dog. In this one, which begins a week later, matters are still reverberating, and some one has stolen his car, which calls for a lot of carnage. That settled, John is called on to pay off an old debt by helping Ian McShane take over the Assassin's Guild by flying around to Italy, Canada and Manhattan and killing what seems like hundreds of assassins ...
# response[response] Liam Neeson is not a character in the context of John Wick.
# response {'response': AIMessage(content="The reception of the John Wick franchise, particularly with the release of the fourth installment, has been extremely positive. Reviews highlight the expertly choreographed action scenes, Keanu Reeves' outstanding performance, and the creative infusion in the fourth film. It is considered one of the best action movies ever, maintaining the high standards set by the franchise.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 70, 'prompt_tokens': 3037, 'total_tokens': 3107, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-decacb3e-6bdc-4b1b-b07d-a7d6704f270b-0', usage_metadata={'input_tokens': 3037, 'output_tokens': 70, 'total_tokens': 3107, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_4.csv', 'row': 18, 'Review_Date': '17 March 2023', 'Review_Title': ' Not Just The Best John Wick, But Possibly One Of The Best Action Movies Ever\n', 'Review_Url': '/review/rw8935367/?ref_=tt_urv', 'Author': 'cadillac20', 'Rating': 10, 'Movie_Title': 'John Wick 4', 'last_accessed_at': '2025-02-28T11:40:31.292929', '_id': 'fb6da2a08531428d890d90e797894e1f', '_collection_name': 'JohnWick'}, page_content=": 18\nReview: Ever since the original John Wick, the franchise has set a standard of what action in Hollywood should be. Thanks to Chad Stahelski and Keanu Reeve's knowledge of the technical aspects of shooting action, they've been able to deliver expertly choreographed, shot, and edited action films that are now the go to as examples of great action filmmaking. And so, the expectations for the fourth film were fairly high, especially as it became more apparent this was not only the culmination of everything before it, but a whopping 169 minutes long. Rest assured, however, that it delivers in spades. Everything we have come to know and love is here, but with an infusion of creativity like we haven't seen from the franchise yet."), Document(metadata={'source': 'john_wick_4.csv', 'row': 19, 'Review_Date': '17 March 2023', 'Review_Title': ' The Best John Wick Sequel\n', 'Review_Url': '/review/rw8935117/?ref_=tt_urv', 'Author': 'tkdlifemagazine', 'Rating': 9, 'Movie_Title': 'John Wick 4', 'last_accessed_at': '2025-02-28T11:40:31.292930', '_id': '9d49fc87e57645e0b304d3f1bb6446bf', '_collection_name': 'JohnWick'}, page_content=": 19\nReview: John Wick: Chapter 4 picks up where Chapter 3: Parabellum left off. As has been the tradition in the sequels to this beloved martial arts action franchise the action starts from the very inception of the film's opening, and lasts until the curtain falls. JW4 is no exception to that rule. What it does do is improve on the prior installment, and solidify Keanu Reeves as the greatest martial arts action star of all time. If you don't accept that notion, then you must accept the fact that it solidifies Reeves and Director, Chad Stahelski, as the greatest martial arts action pairing of modern times."), Document(metadata={'source': 'john_wick_1.csv', 'row': 2, 'Review_Date': '5 May 2023', 'Review_Title': " You don't mess with another person's dog. It's as simple as that!\n", 'Review_Url': '/review/rw9033669/?ref_=tt_urv', 'Author': 'Coventry', 'Rating': 5, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292335', '_id': '45f2fd8ae7b944aab11b4712418de73c', '_collection_name': 'JohnWick'}, page_content=': 2\nReview: With the fourth installment scoring immensely at the cinemas as I\'m submitting this review, and after three previous films that are apparently loved by everyone else in the world, I thought perhaps it would be time for me  ...
# response[response] The reception of the John Wick franchise, particularly with the release of the fourth installment, has been extremely positive. Reviews highlight the expertly choreographed action scenes, Keanu Reeves' outstanding performance, and the creative infusion in the fourth film. It is considered one of the best action movies ever, maintaining the high standards set by the franchise.
# response {'response': AIMessage(content="Chad Stahelski's direction contributes to the uniqueness of the John Wick film by focusing on real virtuoso action sequences with well-made choreographies. Unlike many other action movies, there are no quick-cuts or shaky cameras, allowing the audience to clearly see and appreciate what is happening during the action sequences. Stahelski's background as a stunt specialist is evident in the fluidity and creativity of the action scenes, making them a standout feature of the film.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 97, 'prompt_tokens': 3522, 'total_tokens': 3619, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-9136d91f-5657-4fd9-ad5a-b48fe1bcd4b6-0', usage_metadata={'input_tokens': 3522, 'output_tokens': 97, 'total_tokens': 3619, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_1.csv', 'row': 3, 'Review_Date': '28 September 2018', 'Review_Title': ' Keanu gets pissed and shoots people in the face for 101 minutes*\n', 'Review_Url': '/review/rw4366368/?ref_=tt_urv', 'Author': 'Kitsfi', 'Rating': 8, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292336', '_id': 'bbef47586c9142cb9757e322fc560993', '_collection_name': 'JohnWick'}, page_content=': 3\nReview: John wick has a very simple revenge story. It can be summarized as "Keanu gets angry and shoots bad guys" but what makes it special? Directed by Chad Stahelski who\'s a stunt specialist boy does it show because the main selling point in the film are some real virtuoso action sequences, well made choreographies. Unlike today\'s action movies, it doesn\'t use quick-cuts or shaky cameras actually see what\'s going on.'), Document(metadata={'source': 'john_wick_4.csv', 'row': 18, 'Review_Date': '17 March 2023', 'Review_Title': ' Not Just The Best John Wick, But Possibly One Of The Best Action Movies Ever\n', 'Review_Url': '/review/rw8935367/?ref_=tt_urv', 'Author': 'cadillac20', 'Rating': 10, 'Movie_Title': 'John Wick 4', 'last_accessed_at': '2025-02-28T11:40:31.292929', '_id': 'fb6da2a08531428d890d90e797894e1f', '_collection_name': 'JohnWick'}, page_content=": 18\nReview: Ever since the original John Wick, the franchise has set a standard of what action in Hollywood should be. Thanks to Chad Stahelski and Keanu Reeve's knowledge of the technical aspects of shooting action, they've been able to deliver expertly choreographed, shot, and edited action films that are now the go to as examples of great action filmmaking. And so, the expectations for the fourth film were fairly high, especially as it became more apparent this was not only the culmination of everything before it, but a whopping 169 minutes long. Rest assured, however, that it delivers in spades. Everything we have come to know and love is here, but with an infusion of creativity like we haven't seen from the franchise yet."), Document(metadata={'source': 'john_wick_3.csv', 'row': 5, 'Review_Date': '17 July 2019', 'Review_Title': ' The magic is gone\n', 'Review_Url': '/review/rw4999970/?ref_=tt_urv', 'Author': 'soundoflight', 'Rating': 5, 'Movie_Title': 'John Wick 3', 'last_accessed_at': '2025-02-27T11:40:31.292734', '_id': 'c6cdfe27a2d54fd8b1d997018572469b', '_collection_name': 'JohnWick'}, page_content=': 5\nReview: The first John Wick film was special because it broke a mold of sorts. It went against certain action film conventions - the hero was not a muscle bound hulk like a Schwarzenegger or Stallone, the action was super fast paced, the plot was basic and straighforward, but introduced some unique elements, and there  ...
# response[response] Chad Stahelski's direction contributes to the uniqueness of the John Wick film by focusing on real virtuoso action sequences with well-made choreographies. Unlike many other action movies, there are no quick-cuts or shaky cameras, allowing the audience to clearly see and appreciate what is happening during the action sequences. Stahelski's background as a stunt specialist is evident in the fluidity and creativity of the action scenes, making them a standout feature of the film.
# response {'response': AIMessage(content='John Wick goes after Russian mobsters because they attacked him, beat him senseless, destroyed his belongings, killed his dog, and stole his car. This prompted John Wick to seek revenge on the Russian mobsters who wronged him.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 48, 'prompt_tokens': 3918, 'total_tokens': 3966, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-72a723d3-98a8-4475-bd2e-5539bc28c234-0', usage_metadata={'input_tokens': 3918, 'output_tokens': 48, 'total_tokens': 3966, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_1.csv', 'row': 18, 'Review_Date': '10 September 2019', 'Review_Title': ' Probably NOT a film to watch with your kids or mother.\n', 'Review_Url': '/review/rw5112990/?ref_=tt_urv', 'Author': 'planktonrules', 'Rating': 7, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292348', '_id': '1499620ac8b34aa7a289671959c34fd1', '_collection_name': 'JohnWick'}, page_content=": 18\nReview: When the story begins, John (Keanu Reeves) has just lost his wife. After her death, he's a bit lost but tries to rebuild his life. One day, he's getting gas and a young Russian-American punk notices Wick's classic car...and tries to buy it off him. But Wick isn't interested and declines. Soon, the punk arrives at Wick's home with some goons where they surprise him--beating him senseless, destroying his stuff, killing his dog and stealing his car! This is when you then learn that Wick is a super-assassin....and the punk chose the wrong guy to attack. The jerk's father is a big-time Russian mobster....and it's a contest to see who will win...the mobster and his gang or Wick on his own. Considering there are (so far) two MORE John Wick films, it pretty much seems certain who will win this battle."), Document(metadata={'source': 'john_wick_2.csv', 'row': 20, 'Review_Date': '28 May 2017', 'Review_Title': ' A New Franchise is Born\n', 'Review_Url': '/review/rw3718180/?ref_=tt_urv', 'Author': 'claudio_carvalho', 'Rating': 8, 'Movie_Title': 'John Wick 2', 'last_accessed_at': '2025-02-26T11:40:31.292549', '_id': '14e4e01f095c4b559b49399bfd92e08f', '_collection_name': 'JohnWick'}, page_content=": 20\nReview: After resolving his issues with the Russian mafia, John Wick (Keanu Reeves) returns home. But soon the mobster Santino D'Antonio (Riccardo Scamarcio) visits him to show Wick's marker and tells that he needs to help. John Wicks refuses since he is retired and Santino blows-up his house. John Wick meets the owner of the Continental hotel in New York City, Winston (Ian McShane), and he tells that Wick cannot violate the Mafia rules and shall honor the marker. Santino asks John Wick to kill his sister Gianna D'Antonio (Claudia Gerini) in Rome so that he can sit on the High Table of the criminal organizations. When John Wicks accomplishes his assignment, Santino puts a seven-million dollar contract on him attracting professional killers from everywhere. But Wick promises to kill Santino that is not protected by his marker anymore."), Document(metadata={'source': 'john_wick_1.csv', 'row': 5, 'Review_Date': '23 March 2023', 'Review_Title': ' Violent and gripping story with plenty of unstopped action , shootouts and breathtaking fights\n', 'Review_Url': '/review/rw8945545/?ref_=tt_urv', 'Author': 'ma-cortes', 'Rating': 7, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292338', '_id': '5c16d3bf25b64afdb3e2a3f3c6f1d4cc', '_collection_name': 'JohnWick'}, page_content=": 5\nReview: Ultra-violent first entry with lots of killin ...
# response[response] John Wick goes after Russian mobsters because they attacked him, beat him senseless, destroyed his belongings, killed his dog, and stole his car. This prompted John Wick to seek revenge on the Russian mobsters who wronged him.
# response {'response': AIMessage(content='In the first John Wick movie, John Wick is a retired hitman who comes out of retirement to seek vengeance against the gangsters who killed his dog and took everything from him, including his beloved wife. He is driven by a deep sense of loss and betrayal, which fuels his intense anger and desire for revenge.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 64, 'prompt_tokens': 3618, 'total_tokens': 3682, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-f44a34b6-2566-4a13-8bce-285af8c356d4-0', usage_metadata={'input_tokens': 3618, 'output_tokens': 64, 'total_tokens': 3682, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_1.csv', 'row': 5, 'Review_Date': '23 March 2023', 'Review_Title': ' Violent and gripping story with plenty of unstopped action , shootouts and breathtaking fights\n', 'Review_Url': '/review/rw8945545/?ref_=tt_urv', 'Author': 'ma-cortes', 'Rating': 7, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292338', '_id': '5c16d3bf25b64afdb3e2a3f3c6f1d4cc', '_collection_name': 'JohnWick'}, page_content=": 5\nReview: Ultra-violent first entry with lots of killings, thrills , noisy action , suspense , and crossfire . In this original John Wick (2014) , an ex-hit-man comes out of retirement to track down the gangsters that killed his dog and took everything from him . With the untimely death of his beloved wife still bitter in his mouth he seeks for vengeance . But when an arrogant Russian mob prince and hoodlums steal his car and kill his dog , they are fully aware of his lethal capacity. The Bogeyman will find himself dragged into an impossible task as every killer in the business dreams of cornering the legendary Wick who now has an enormous price on his head . In this first installment John Wick , blind with revenge, and for his salvation John will immediately unleash a carefully orchestrated maelstrom of destruction against those attempt to chase him and with a price tag on his head, as he is the target of hit men : an army of bounty-hunting killers on his trail and a murderer woman everywhere . The legendary hitman will be forced to unearth his meticulously concealed identity and to carry out a relentless vendetta . Now, only blood can quench the boogeyman's thirst for retribution . Don't Set Him Off! . John Wick isn't the Boogeyman... He's the guy you send to kill the doomed Boogeyman. Revenge is all he has left. You want peace, prepare for war . Don't Hunt What You Can't Kill. Tick Tock, Mr. Wick. Everyone Is Waiting. For John Wick . Every Action Has Consequences. This Friday, Wick is Back . Its the World Vs. Wick. Every Action Has Consequences."), Document(metadata={'source': 'john_wick_2.csv', 'row': 19, 'Review_Date': '29 November 2020', 'Review_Title': ' John Wick Kills A Lot Of People\n', 'Review_Url': '/review/rw6320115/?ref_=tt_urv', 'Author': 'boblipton', 'Rating': 5, 'Movie_Title': 'John Wick 2', 'last_accessed_at': '2025-02-26T11:40:31.292549', '_id': 'c6a990d6fb27499096a867702c0bdfaf', '_collection_name': 'JohnWick'}, page_content=": 19\nReview: If you've seen the first John Wick movie, you know that Keanu Reeves is John Wick, a retired assassin who comes out of retirement when someone kills his dog. In this one, which begins a week later, matters are still reverberating, and some one has stolen his car, which calls for a lot of carnage. That settled, John is called on to pay off an old debt by helping Ian McShane take over the Assassin's Guild by flying around to Italy, Canada and Manhattan and killing what seems lik ...
# response[response] In the first John Wick movie, John Wick is a retired hitman who comes out of retirement to seek vengeance against the gangsters who killed his dog and took everything from him, including his beloved wife. He is driven by a deep sense of loss and betrayal, which fuels his intense anger and desire for revenge.
# response {'response': AIMessage(content="According to reviews, 'John Wick: Chapter 2' stands out among American action films due to its high bar in action, set design, camera work, and pure escapist entertainment. The film is noted for its artistic value, fluid action sequences, and practical stunt work, which sets it apart from other action movies. The director's expertise in action, the smooth flow of sequences, and the natural performance by Keanu Reeves contribute to the film's unique appeal.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 96, 'prompt_tokens': 3507, 'total_tokens': 3603, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-b8b77485-255f-41ab-b3d4-2e2f1ce3ab17-0', usage_metadata={'input_tokens': 3507, 'output_tokens': 96, 'total_tokens': 3603, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_2.csv', 'row': 16, 'Review_Date': '9 February 2017', 'Review_Title': ' Kick-ass, entertaining and relentless throughout. This is what every sequel should aspire to be.\n', 'Review_Url': '/review/rw3636884/?ref_=tt_urv', 'Author': 'trublu215', 'Rating': 5, 'Movie_Title': 'John Wick 2', 'last_accessed_at': '2025-02-26T11:40:31.292546', '_id': '3b935f6ed310465b801954cade3ce370', '_collection_name': 'JohnWick'}, page_content=": 16\nReview: John Wick Chapter 2 pits Keanu Reeves' titular character against the mean and nefarious of the criminal underworld. Once again, Reeves proves that he is a force to be reckoned with in this ridiculous, over-the-top sequel that is every bit as fun as the original. These types of films are rarely known for their artistic value but John Wick: Chapter 2 sets the bar pretty high, not only in its action, but in it's set design and camera work. This is pure escapist entertainment and couldn't have come at a better time. Those wanting to take a break from watching the Oscar nominees, this film is exactly what you're looking for."), Document(metadata={'source': 'john_wick_2.csv', 'row': 22, 'Review_Date': '12 February 2017', 'Review_Title': ' This is how you film an action movie !\n', 'Review_Url': '/review/rw3638970/?ref_=tt_urv', 'Author': 'destroyerwod', 'Rating': 9, 'Movie_Title': 'John Wick 2', 'last_accessed_at': '2025-02-26T11:40:31.292551', '_id': '2d03dbb06ab24d28a0ae856452b7de66', '_collection_name': 'JohnWick'}, page_content=': 22\nReview: John Wick is one of my favourite recent years action movie and the second one pick up right where the first one left. The action is sharp, well filmed, no bad shaky cams and jump cuts like a certain bad action movie i saw recently. Its so refreshing to see everything and admire the practical stunt work.'), Document(metadata={'source': 'john_wick_1.csv', 'row': 20, 'Review_Date': '22 October 2014', 'Review_Title': ' Smoothest action film to come around in a long time\n', 'Review_Url': '/review/rw3109271/?ref_=tt_urv', 'Author': 'IceSkateUpHill', 'Rating': 10, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292350', '_id': 'abf04bb7a461407a8de2219f2fc53b49', '_collection_name': 'JohnWick'}, page_content=": 20\nReview: John Wick is something special. It takes as much time setting up elaborate action sequences as it does the world with which it all takes place in. And what a world it is. It reminds me of Millers Crossing and it is cooler than any other recent attempt at noir. We are shown a criminal underworld where, if you are connected, many powerful people know who you are and show you respect. John Wick was connected but he got out. He is the rare killer who has found peace, and he is grateful for that peace. ...
# response[response] According to reviews, 'John Wick: Chapter 2' stands out among American action films due to its high bar in action, set design, camera work, and pure escapist entertainment. The film is noted for its artistic value, fluid action sequences, and practical stunt work, which sets it apart from other action movies. The director's expertise in action, the smooth flow of sequences, and the natural performance by Keanu Reeves contribute to the film's unique appeal.
# response {'response': AIMessage(content='According to reviews, John Wick: Chapter 4 improves upon John Wick: Chapter 3 - Parabellum by delivering expertly choreographed, shot, and edited action sequences and infusing creativity like never seen before in the franchise. The pacing, plotting, and action sequences in John Wick: Chapter 4 are highly praised, solidifying Keanu Reeves as the greatest martial arts action star of all time alongside Director Chad Stahelski as the greatest martial arts action pairing of modern times.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 102, 'prompt_tokens': 2944, 'total_tokens': 3046, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-74f08f5b-f6a7-4cc8-b29d-12173af47a03-0', usage_metadata={'input_tokens': 2944, 'output_tokens': 102, 'total_tokens': 3046, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_4.csv', 'row': 19, 'Review_Date': '17 March 2023', 'Review_Title': ' The Best John Wick Sequel\n', 'Review_Url': '/review/rw8935117/?ref_=tt_urv', 'Author': 'tkdlifemagazine', 'Rating': 9, 'Movie_Title': 'John Wick 4', 'last_accessed_at': '2025-02-28T11:40:31.292930', '_id': '9d49fc87e57645e0b304d3f1bb6446bf', '_collection_name': 'JohnWick'}, page_content=": 19\nReview: John Wick: Chapter 4 picks up where Chapter 3: Parabellum left off. As has been the tradition in the sequels to this beloved martial arts action franchise the action starts from the very inception of the film's opening, and lasts until the curtain falls. JW4 is no exception to that rule. What it does do is improve on the prior installment, and solidify Keanu Reeves as the greatest martial arts action star of all time. If you don't accept that notion, then you must accept the fact that it solidifies Reeves and Director, Chad Stahelski, as the greatest martial arts action pairing of modern times."), Document(metadata={'source': 'john_wick_3.csv', 'row': 24, 'Review_Date': '17 May 2019', 'Review_Title': ' Makes John Wick a superb trilogy\n', 'Review_Url': '/review/rw4860603/?ref_=tt_urv', 'Author': 'masonsaul', 'Rating': 10, 'Movie_Title': 'John Wick 3', 'last_accessed_at': '2025-02-27T11:40:31.292750', '_id': '6daad8494ac4440a9b12f739582a5326', '_collection_name': 'JohnWick'}, page_content=": 24\nReview: John Wick: Chapter 3 - Parabellum is quite literally about consequences, dealing with the fallout of John's actions at the end of the previous film and sending him on an even bigger odyssey of violence that continues to explore this world of assassination and deliver beautifully clean action sequences."), Document(metadata={'source': 'john_wick_3.csv', 'row': 13, 'Review_Date': '15 May 2019', 'Review_Title': ' Pure, delirious joy in the form of yet another exhilarating thriller\n', 'Review_Url': '/review/rw4855261/?ref_=tt_urv', 'Author': 'themadmovieman', 'Rating': 8, 'Movie_Title': 'John Wick 3', 'last_accessed_at': '2025-02-27T11:40:31.292740', '_id': 'f7a59724573a437d9a0a50eae0487a6b', '_collection_name': 'JohnWick'}, page_content=": 13\nReview: Following on from two deliriously entertaining, visually gorgeous and blissfully simplistic thrillers, John Wick: Chapter 3 - Parabellum keeps up the franchise's unique appeal in stunning fashion. Complete with electrifying action, beautiful cinematography, a pulsating score and a great sense of humour, the film is pretty much as purely joyful as action thrillers get, and proves two hours of brilliant entertainment."), Document(metadata={'source': 'john_wick_3.csv', 'row': 0, 'Review_Date': '22 September 2019', 'Review_Title': ' Enjoyably choreographed, but the  ...
# response[response] According to reviews, John Wick: Chapter 4 improves upon John Wick: Chapter 3 - Parabellum by delivering expertly choreographed, shot, and edited action sequences and infusing creativity like never seen before in the franchise. The pacing, plotting, and action sequences in John Wick: Chapter 4 are highly praised, solidifying Keanu Reeves as the greatest martial arts action star of all time alongside Director Chad Stahelski as the greatest martial arts action pairing of modern times.
# response {'response': AIMessage(content='The John Wick franchise has set a standard for Hollywood action films by delivering expertly choreographed, shot, and edited action sequences in a way that few other American action flicks do. The screenplay quality of the John Wick movies stands out as it focuses on a simple yet effective revenge story with clear motives for the characters involved. In terms of CGI usage, the John Wick franchise is known for its practical effects and minimal reliance on computer-generated imagery, setting it apart from many modern action films that overuse CGI.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 103, 'prompt_tokens': 3539, 'total_tokens': 3642, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-fc5249c6-2064-4a33-b483-74100b1b2fc9-0', usage_metadata={'input_tokens': 3539, 'output_tokens': 103, 'total_tokens': 3642, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_4.csv', 'row': 10, 'Review_Date': '22 March 2023', 'Review_Title': ' How Can Anyone Choose to Watch Marvel Over This?\n', 'Review_Url': '/review/rw8944843/?ref_=tt_urv', 'Author': 'lovemichaeljordan', 'Rating': 8, 'Movie_Title': 'John Wick 4', 'last_accessed_at': '2025-02-28T11:40:31.292923', '_id': 'b66f76b8e43648f59089c83623a0c5c1', '_collection_name': 'JohnWick'}, page_content=": 10\nReview: Most American action flicks released these days have poor screenplays and overuse computer-generated imagery. The John Wick franchise is one of the few exceptions, along with Mission Impossible. These franchises keep getting better with every entry. Hollywood can make action masterpieces, but Marvel has greater demand, so that's what we get most of. It's a shame."), Document(metadata={'source': 'john_wick_4.csv', 'row': 18, 'Review_Date': '17 March 2023', 'Review_Title': ' Not Just The Best John Wick, But Possibly One Of The Best Action Movies Ever\n', 'Review_Url': '/review/rw8935367/?ref_=tt_urv', 'Author': 'cadillac20', 'Rating': 10, 'Movie_Title': 'John Wick 4', 'last_accessed_at': '2025-02-28T11:40:31.292929', '_id': 'fb6da2a08531428d890d90e797894e1f', '_collection_name': 'JohnWick'}, page_content=": 18\nReview: Ever since the original John Wick, the franchise has set a standard of what action in Hollywood should be. Thanks to Chad Stahelski and Keanu Reeve's knowledge of the technical aspects of shooting action, they've been able to deliver expertly choreographed, shot, and edited action films that are now the go to as examples of great action filmmaking. And so, the expectations for the fourth film were fairly high, especially as it became more apparent this was not only the culmination of everything before it, but a whopping 169 minutes long. Rest assured, however, that it delivers in spades. Everything we have come to know and love is here, but with an infusion of creativity like we haven't seen from the franchise yet."), Document(metadata={'source': 'john_wick_3.csv', 'row': 5, 'Review_Date': '17 July 2019', 'Review_Title': ' The magic is gone\n', 'Review_Url': '/review/rw4999970/?ref_=tt_urv', 'Author': 'soundoflight', 'Rating': 5, 'Movie_Title': 'John Wick 3', 'last_accessed_at': '2025-02-27T11:40:31.292734', '_id': 'c6cdfe27a2d54fd8b1d997018572469b', '_collection_name': 'JohnWick'}, page_content=': 5\nReview: The first John Wick film was special because it broke a mold of sorts. It went against certain action film conventions - the hero was not a muscle bound hulk like a Schwarzenegger or Stallone, the action was super fast paced, the plot was basic and straighforward, but introduced some unique elements, ...
# response[response] The John Wick franchise has set a standard for Hollywood action films by delivering expertly choreographed, shot, and edited action sequences in a way that few other American action flicks do. The screenplay quality of the John Wick movies stands out as it focuses on a simple yet effective revenge story with clear motives for the characters involved. In terms of CGI usage, the John Wick franchise is known for its practical effects and minimal reliance on computer-generated imagery, setting it apart from many modern action films that overuse CGI.
# response {'response': AIMessage(content="The reviews reflect that Keanu Reeves' portrayal in the John Wick franchise, particularly in terms of action choreography, has been highly praised. Reviewers have mentioned that Keanu's performance is slick, smooth, and natural in action sequences, showcasing his expertise in delivering thrilling and stylish fight scenes. They appreciate the kinetic chaos, fluidity, and natural movement he brings to the action choreography, making the movie highly enjoyable for action fans. In terms of character depth, the focus seems to be more on the action and narrative setup rather than delving deeply into character development. Overall, Keanu Reeves' portrayal in the John Wick franchise has been positively received for his action skills and performance.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 142, 'prompt_tokens': 3515, 'total_tokens': 3657, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-cf6a056a-195e-42ae-88ba-392f2c9d5fc2-0', usage_metadata={'input_tokens': 3515, 'output_tokens': 142, 'total_tokens': 3657, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_1.csv', 'row': 3, 'Review_Date': '28 September 2018', 'Review_Title': ' Keanu gets pissed and shoots people in the face for 101 minutes*\n', 'Review_Url': '/review/rw4366368/?ref_=tt_urv', 'Author': 'Kitsfi', 'Rating': 8, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292336', '_id': 'bbef47586c9142cb9757e322fc560993', '_collection_name': 'JohnWick'}, page_content=': 3\nReview: John wick has a very simple revenge story. It can be summarized as "Keanu gets angry and shoots bad guys" but what makes it special? Directed by Chad Stahelski who\'s a stunt specialist boy does it show because the main selling point in the film are some real virtuoso action sequences, well made choreographies. Unlike today\'s action movies, it doesn\'t use quick-cuts or shaky cameras actually see what\'s going on.'), Document(metadata={'source': 'john_wick_1.csv', 'row': 20, 'Review_Date': '22 October 2014', 'Review_Title': ' Smoothest action film to come around in a long time\n', 'Review_Url': '/review/rw3109271/?ref_=tt_urv', 'Author': 'IceSkateUpHill', 'Rating': 10, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292350', '_id': 'abf04bb7a461407a8de2219f2fc53b49', '_collection_name': 'JohnWick'}, page_content=": 20\nReview: John Wick is something special. It takes as much time setting up elaborate action sequences as it does the world with which it all takes place in. And what a world it is. It reminds me of Millers Crossing and it is cooler than any other recent attempt at noir. We are shown a criminal underworld where, if you are connected, many powerful people know who you are and show you respect. John Wick was connected but he got out. He is the rare killer who has found peace, and he is grateful for that peace. Some young kids steal that from him and he does what he does best, he wages a one man war against the Russian Mafia. It might sound like the film takes quite a leap but it all makes sense. The motives of John and the people who get in the way of his bullets are all very clear, even if it does come across as rather simple. That's the plot at it's most basic. Then there's the action. The film is directed by Reeve's stuntman from The Matrix, so this guy knows action. There are sequences that flow so smoothly it puts other action films and their quick cuts to shame. Keaunu moves so fluidly throughout the film and comes across as such a natural that the only disappointment is that ...
# response[response] The reviews reflect that Keanu Reeves' portrayal in the John Wick franchise, particularly in terms of action choreography, has been highly praised. Reviewers have mentioned that Keanu's performance is slick, smooth, and natural in action sequences, showcasing his expertise in delivering thrilling and stylish fight scenes. They appreciate the kinetic chaos, fluidity, and natural movement he brings to the action choreography, making the movie highly enjoyable for action fans. In terms of character depth, the focus seems to be more on the action and narrative setup rather than delving deeply into character development. Overall, Keanu Reeves' portrayal in the John Wick franchise has been positively received for his action skills and performance.
# response {'response': AIMessage(content="Ian McShane is important in the John Wick movie because of his portrayal of Winston, the owner of the Continental hotel in New York City. His character adds depth to the criminal underworld in which the story takes place. McShane's presence along with his charismatic performance makes the movie more interesting by creating a sense of mystery and sophistication around his character.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 72, 'prompt_tokens': 3767, 'total_tokens': 3839, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-7c6fda0e-9f0d-401e-adec-c632462e4d8d-0', usage_metadata={'input_tokens': 3767, 'output_tokens': 72, 'total_tokens': 3839, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_1.csv', 'row': 20, 'Review_Date': '22 October 2014', 'Review_Title': ' Smoothest action film to come around in a long time\n', 'Review_Url': '/review/rw3109271/?ref_=tt_urv', 'Author': 'IceSkateUpHill', 'Rating': 10, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292350', '_id': 'abf04bb7a461407a8de2219f2fc53b49', '_collection_name': 'JohnWick'}, page_content=": 20\nReview: John Wick is something special. It takes as much time setting up elaborate action sequences as it does the world with which it all takes place in. And what a world it is. It reminds me of Millers Crossing and it is cooler than any other recent attempt at noir. We are shown a criminal underworld where, if you are connected, many powerful people know who you are and show you respect. John Wick was connected but he got out. He is the rare killer who has found peace, and he is grateful for that peace. Some young kids steal that from him and he does what he does best, he wages a one man war against the Russian Mafia. It might sound like the film takes quite a leap but it all makes sense. The motives of John and the people who get in the way of his bullets are all very clear, even if it does come across as rather simple. That's the plot at it's most basic. Then there's the action. The film is directed by Reeve's stuntman from The Matrix, so this guy knows action. There are sequences that flow so smoothly it puts other action films and their quick cuts to shame. Keaunu moves so fluidly throughout the film and comes across as such a natural that the only disappointment is that we have not seen him like this before. Along the way are plenty of character actors, fans of The Matrix and The Wire will recognize a few people then there are more obvious ones like Ian McShane and Willem Dafoe. Everyone seems to be having a good time. That is another plus for this movie. It get's dark at times but overall it is quite fun, not very chipper, but fun. I cannot recommend this movie enough. I believe it is a must see for action fans and for anyone looking for something a bit different from the usual fare."), Document(metadata={'source': 'john_wick_1.csv', 'row': 9, 'Review_Date': '20 October 2014', 'Review_Title': " The coolest action film you'll see all year\n", 'Review_Url': '/review/rw3107759/?ref_=tt_urv', 'Author': 'trublu215', 'Rating': 9, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292341', '_id': '2d6f65f3952a485588a13c19fdf9fdf0', '_collection_name': 'JohnWick'}, page_content=": 9\nReview: At first glance, John Wick sounds like a terrible film on paper but with the slickness of Keanu Reeves' performance as the titular character and the sheer brilliance in its action sequences, this marks the best action film of the year and one of the absolute best in the past decade ...
# response[response] Ian McShane is important in the John Wick movie because of his portrayal of Winston, the owner of the Continental hotel in New York City. His character adds depth to the criminal underworld in which the story takes place. McShane's presence along with his charismatic performance makes the movie more interesting by creating a sense of mystery and sophistication around his character.
# Evaluating:   0%|          | 0/60 [00:00<?, ?it/s]
# Exception raised in Job[17]: TimeoutError()
# Exception raised in Job[35]: TimeoutError()
# Exception raised in Job[47]: TimeoutError()
# naive_retrieval_chain 414.61089033301687

# %%
result_bm25_retrieval = evaluate_one_chain(dataset, bm25_retrieval_chain)
# Out:
# response {'response': AIMessage(content='Liam Neeson is an actor known for his role in the movie Taken. In the context of John Wick, he is mentioned as an actor who could have played a similar role to Keanu Reeves in the film.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 46, 'prompt_tokens': 1210, 'total_tokens': 1256, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-e8911f3c-57fe-4e77-81f5-38358b414538-0', usage_metadata={'input_tokens': 1210, 'output_tokens': 46, 'total_tokens': 1256, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_4.csv', 'row': 11, 'Review_Date': '26 April 2023', 'Review_Title': ' NOPE\n', 'Review_Url': '/review/rw9017658/?ref_=tt_urv', 'Author': 'kskmah', 'Rating': 1, 'Movie_Title': 'John Wick 4', 'last_accessed_at': datetime.datetime(2025, 2, 28, 11, 40, 31, 292924)}, page_content=": 11\nReview: Who needs a 2hr and 40 min action movie? No one. Yes the action was good, but repeats so many times that it becomes so boring. How can hundreds of assassins not kill one man? Answer, not possible, only in this movie and series. How many times could the dog man have killed Wick? Many. So no other assassin could? Why would the table head get Caine to kill Wick when he knows he won't. You can challenge the head to a duel as a rule, but they only assigned a head for the first time ever in this movie? WTF? And then the head can select a replacement? And he selects a blind man. All Wick had to do was to stand on the side or drop down and he wouldn't get shot. I think everyone knew Wick didn't shoot in the last round, except for the stupid head bad guy. This is not an action movie, it's a fantasy."), Document(metadata={'source': 'john_wick_1.csv', 'row': 0, 'Review_Date': '6 May 2015', 'Review_Title': ' Kinetic, concise, and stylish; John Wick kicks ass.\n', 'Review_Url': '/review/rw3233896/?ref_=tt_urv', 'Author': 'lnvicta', 'Rating': 8, 'Movie_Title': 'John Wick 1', 'last_accessed_at': datetime.datetime(2025, 2, 25, 11, 40, 31, 292319)}, page_content=": 0\nReview: The best way I can describe John Wick is to picture Taken but instead of Liam Neeson it's Keanu Reeves and instead of his daughter it's his dog. That's essentially the plot of the movie. John Wick (Reeves) is out to seek revenge on the people who took something he loved from him. It's a beautifully simple premise for an action movie - when action movies get convoluted, they get bad i.e. A Good Day to Die Hard. John Wick gives the viewers what they want: Awesome action, stylish stunts, kinetic chaos, and a relatable hero to tie it all together. John Wick succeeds in its simplicity."), Document(metadata={'source': 'john_wick_1.csv', 'row': 11, 'Review_Date': '25 September 2015', 'Review_Title': ' Action as it should be\n', 'Review_Url': '/review/rw3323198/?ref_=tt_urv', 'Author': 'Leofwine_draca', 'Rating': 8, 'Movie_Title': 'John Wick 1', 'last_accessed_at': datetime.datetime(2025, 2, 25, 11, 40, 31, 292343)}, page_content=": 11\nReview: JOHN WICK is a rare example of Hollywood getting things spot-on when it comes to creating the near-perfect action film. JOHN WICK is a relentless, pulse-pounding thriller that has plenty of similarity to the Liam Neeson classic TAKEN, albeit with a more simplistic (and also more emotionally intense) plot line. This is the kind of lean, pared-down film-making that's all about intensity and momentum. It sits well with classic international fare like POINT BLANK, SLEEPLESS NIGHT, MEA CULPA, THE MAN FROM NOWHERE, and THE RAID films."), Document(metadata={'source': 'john_wick_2.csv', 'row': 21, 'Review ...
# response[response] Liam Neeson is an actor known for his role in the movie Taken. In the context of John Wick, he is mentioned as an actor who could have played a similar role to Keanu Reeves in the film.
# response {'response': AIMessage(content="The reception of the John Wick franchise, particularly with the release of the fourth installment, has been highly positive. Critics and viewers have praised the action sequences, Keanu Reeves' performance, and the overall improvement compared to previous installments. Reviewers have called it the best John Wick sequel, possibly one of the best action movies ever, and have highlighted the expertly choreographed and shot action scenes.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 82, 'prompt_tokens': 1105, 'total_tokens': 1187, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-341a704a-9be7-414c-9574-2080e7083091-0', usage_metadata={'input_tokens': 1105, 'output_tokens': 82, 'total_tokens': 1187, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_4.csv', 'row': 6, 'Review_Date': '24 March 2023', 'Review_Title': ' "Yeah."\n', 'Review_Url': '/review/rw8947952/?ref_=tt_urv', 'Author': 'IMDbKeepsDeletingMyReviews', 'Rating': 5, 'Movie_Title': 'John Wick 4', 'last_accessed_at': datetime.datetime(2025, 2, 28, 11, 40, 31, 292920)}, page_content=": 6\nReview: In this fourth installment of 8711's successful franchise, Keanu Reeves wearily drags himself from setpiece to setpiece, saying little, surviving the most ridiculous setups and finally achieves nothing."), Document(metadata={'source': 'john_wick_2.csv', 'row': 21, 'Review_Date': '8 February 2017', 'Review_Title': ' Great Action Movie!\n', 'Review_Url': '/review/rw3635784/?ref_=tt_urv', 'Author': 'MichaelNontonMulu', 'Rating': 9, 'Movie_Title': 'John Wick 2', 'last_accessed_at': datetime.datetime(2025, 2, 26, 11, 40, 31, 292550)}, page_content=': 21\nReview: Wow, this is one of the best action movies that I have seen in quite some time. It is really what I was hoping for in a good old fashion action movie that was done entirely on hand to hand combat and gun shootings. This is a wonderful kick-ass movie where the killings were done so brutally with lots of bloody scenes. It also kind of remind me of the various one man army movies in the 80s played by Sylvester Stallone or Arnold Schwarzenegger. If you have seen John Wick the original (which I hope you have seen it before you see this one), then you will be amazed with this sequel. It was bloodier, more fighting, more assassins trying to kill John and longer running time. What I can say is this is an even better version than the original movie. Although in term of story, there is a bit of a more complexity in the sequel as opposed to the simplicity of the original movie.'), Document(metadata={'source': 'john_wick_4.csv', 'row': 19, 'Review_Date': '17 March 2023', 'Review_Title': ' The Best John Wick Sequel\n', 'Review_Url': '/review/rw8935117/?ref_=tt_urv', 'Author': 'tkdlifemagazine', 'Rating': 9, 'Movie_Title': 'John Wick 4', 'last_accessed_at': datetime.datetime(2025, 2, 28, 11, 40, 31, 292930)}, page_content=": 19\nReview: John Wick: Chapter 4 picks up where Chapter 3: Parabellum left off. As has been the tradition in the sequels to this beloved martial arts action franchise the action starts from the very inception of the film's opening, and lasts until the curtain falls. JW4 is no exception to that rule. What it does do is improve on the prior installment, and solidify Keanu Reeves as the greatest martial arts action star of all time. If you don't accept that notion, then you must accept the fact that it solidifies Reeves and Director, Chad Stahelski, as the greatest martial arts action pairing of modern times."), Document(metadata={'source': 'john_wick_4.csv', ...
# response[response] The reception of the John Wick franchise, particularly with the release of the fourth installment, has been highly positive. Critics and viewers have praised the action sequences, Keanu Reeves' performance, and the overall improvement compared to previous installments. Reviewers have called it the best John Wick sequel, possibly one of the best action movies ever, and have highlighted the expertly choreographed and shot action scenes.
# response {'response': AIMessage(content="Chad Stahelski's direction in the John Wick films contributes to their uniqueness by delivering expertly choreographed, shot, and edited action sequences. Stahelski's understanding of the technical aspects of shooting action has helped the franchise set a standard for action in Hollywood. Additionally, his collaboration with Keanu Reeves has solidified them as one of the greatest martial arts action pairings of modern times.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 84, 'prompt_tokens': 1183, 'total_tokens': 1267, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-cd990037-0e43-4068-a669-9d1a25d997be-0', usage_metadata={'input_tokens': 1183, 'output_tokens': 84, 'total_tokens': 1267, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_4.csv', 'row': 19, 'Review_Date': '17 March 2023', 'Review_Title': ' The Best John Wick Sequel\n', 'Review_Url': '/review/rw8935117/?ref_=tt_urv', 'Author': 'tkdlifemagazine', 'Rating': 9, 'Movie_Title': 'John Wick 4', 'last_accessed_at': datetime.datetime(2025, 2, 28, 11, 40, 31, 292930)}, page_content=": 19\nReview: John Wick: Chapter 4 picks up where Chapter 3: Parabellum left off. As has been the tradition in the sequels to this beloved martial arts action franchise the action starts from the very inception of the film's opening, and lasts until the curtain falls. JW4 is no exception to that rule. What it does do is improve on the prior installment, and solidify Keanu Reeves as the greatest martial arts action star of all time. If you don't accept that notion, then you must accept the fact that it solidifies Reeves and Director, Chad Stahelski, as the greatest martial arts action pairing of modern times."), Document(metadata={'source': 'john_wick_2.csv', 'row': 23, 'Review_Date': '4 February 2020', 'Review_Title': ' Keanu kills everyone. Again.\n', 'Review_Url': '/review/rw5459627/?ref_=tt_urv', 'Author': 'BA_Harrison', 'Rating': 5, 'Movie_Title': 'John Wick 2', 'last_accessed_at': datetime.datetime(2025, 2, 26, 11, 40, 31, 292552)}, page_content=": 23\nReview: I love me a bit of the old ultra-violence, but I also like a plot of some kind to go with all of the gunfire, blood and broken bones. Failing that, the gory mayhem had better be something special - something that breaks new ground in terms of action cinema. John Wick Chapter 2 is relentlessly violent, Keanu Reeves' eponymous hitman laying waste to almost everyone he crosses paths with, once again finishing most victims with a shot to the head, but the action is simply more of the same, director Chad Stahelski bringing nothing new to the table."), Document(metadata={'source': 'john_wick_4.csv', 'row': 11, 'Review_Date': '26 April 2023', 'Review_Title': ' NOPE\n', 'Review_Url': '/review/rw9017658/?ref_=tt_urv', 'Author': 'kskmah', 'Rating': 1, 'Movie_Title': 'John Wick 4', 'last_accessed_at': datetime.datetime(2025, 2, 28, 11, 40, 31, 292924)}, page_content=": 11\nReview: Who needs a 2hr and 40 min action movie? No one. Yes the action was good, but repeats so many times that it becomes so boring. How can hundreds of assassins not kill one man? Answer, not possible, only in this movie and series. How many times could the dog man have killed Wick? Many. So no other assassin could? Why would the table head get Caine to kill Wick when he knows he won't. You can challenge the head to a duel as a rule, but they only assigned a head for the first time ever in this movie? WTF? And then the head can select a replacement? And he selects a blind man. All Wick had to do was to stand  ...
# response[response] Chad Stahelski's direction in the John Wick films contributes to their uniqueness by delivering expertly choreographed, shot, and edited action sequences. Stahelski's understanding of the technical aspects of shooting action has helped the franchise set a standard for action in Hollywood. Additionally, his collaboration with Keanu Reeves has solidified them as one of the greatest martial arts action pairings of modern times.
# response {'response': AIMessage(content="John Wick goes after the Russian mobsters because they broke into his house, beat him up, took his car, and killed the puppy his wife had left him. They did this without realizing who he was, just for the sake of the car. This event triggered John Wick's quest for revenge.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 61, 'prompt_tokens': 1218, 'total_tokens': 1279, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-566df561-361b-4095-aa06-5ab8c8ec1b8a-0', usage_metadata={'input_tokens': 1218, 'output_tokens': 61, 'total_tokens': 1279, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_1.csv', 'row': 10, 'Review_Date': '22 November 2014', 'Review_Title': ' Most Excellent\n', 'Review_Url': '/review/rw3128980/?ref_=tt_urv', 'Author': 'utgard14', 'Rating': 7, 'Movie_Title': 'John Wick 1', 'last_accessed_at': datetime.datetime(2025, 2, 25, 11, 40, 31, 292342)}, page_content=": 10\nReview: Wow what a great surprise this was. I was told by a friend this was good but it's been awhile since I liked a Keanu movie so I was hesitant to try it. Retired hit-man John Wick (Keanu Reeves) loses his wife to cancer. After her funeral he receives a puppy she left him. A few days later some thugs, led by the son of a Russian gangster John used to work for, break into John's house. They beat him up, take the keys to his beloved car, and kill the puppy. They did this not knowing who he was; they just wanted the car. Now John Wick is out for revenge and the Russian gangster is trying to save his son's life by sending killers after John."), Document(metadata={'source': 'john_wick_1.csv', 'row': 13, 'Review_Date': '26 March 2023', 'Review_Title': ' Hello, my name is Inigo Montoya, you killed my dog, prepare to die...\n', 'Review_Url': '/review/rw8951947/?ref_=tt_urv', 'Author': 'AlsExGal', 'Rating': 4, 'Movie_Title': 'John Wick 1', 'last_accessed_at': datetime.datetime(2025, 2, 25, 11, 40, 31, 292344)}, page_content=': 13\nReview: ... slaughtering a line from the superior "Princess Bride". It\'s a shame that Keanu Reeves is supposed to be one of the nicest guys to work\nwith in Hollywood, because this film is a mess. We should stop asking Hollywood to come up with original ideas, because when they do, this is the result. 101 minutes of cliched action that checks all of the boxes - retired hit-man coming out of retirement, a boy and his dog, the perfect wife who is conveniently dead, stolen cars, Russian mobsters, a spoiled son who doesn\'t have half the restraint and judgment of dad precisely because dad spoiled him, and lots of blood.'), Document(metadata={'source': 'john_wick_3.csv', 'row': 16, 'Review_Date': '16 May 2019', 'Review_Title': " Finally an action franchise than doesn't lose its touch!\n", 'Review_Url': '/review/rw4858493/?ref_=tt_urv', 'Author': 'Dannyboi94', 'Rating': 8, 'Movie_Title': 'John Wick 3', 'last_accessed_at': datetime.datetime(2025, 2, 27, 11, 40, 31, 292744)}, page_content=": 16\nReview: John Wick 3 is without a doubt the best action movie to have come out in a few years. And its so surprising and refreshing to see that movies like this still exist. Most action movies you see is filled with ridiculous amounts of shaky-cam, fast edits and way over-the-top fights. This is perfect. You can see all action clear as day, and by god the stuns in this film are extraordinary. Why the Academy Awards don't award talent like this is beyond me. There were times that I wondered if they had used CGI, because someone nuts must be willing to throw themselves from motorbikes and ...
# response[response] John Wick goes after the Russian mobsters because they broke into his house, beat him up, took his car, and killed the puppy his wife had left him. They did this without realizing who he was, just for the sake of the car. This event triggered John Wick's quest for revenge.
# response {'response': AIMessage(content='In the first John Wick movie, he is mad because his beloved dog was killed and his car was stolen by gangsters. This act of cruelty led him to seek vengeance and unleash a wave of destruction against those responsible.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 45, 'prompt_tokens': 1388, 'total_tokens': 1433, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-fbdd4513-6226-4567-b420-44bd88b9f693-0', usage_metadata={'input_tokens': 1388, 'output_tokens': 45, 'total_tokens': 1433, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_4.csv', 'row': 11, 'Review_Date': '26 April 2023', 'Review_Title': ' NOPE\n', 'Review_Url': '/review/rw9017658/?ref_=tt_urv', 'Author': 'kskmah', 'Rating': 1, 'Movie_Title': 'John Wick 4', 'last_accessed_at': datetime.datetime(2025, 2, 28, 11, 40, 31, 292924)}, page_content=": 11\nReview: Who needs a 2hr and 40 min action movie? No one. Yes the action was good, but repeats so many times that it becomes so boring. How can hundreds of assassins not kill one man? Answer, not possible, only in this movie and series. How many times could the dog man have killed Wick? Many. So no other assassin could? Why would the table head get Caine to kill Wick when he knows he won't. You can challenge the head to a duel as a rule, but they only assigned a head for the first time ever in this movie? WTF? And then the head can select a replacement? And he selects a blind man. All Wick had to do was to stand on the side or drop down and he wouldn't get shot. I think everyone knew Wick didn't shoot in the last round, except for the stupid head bad guy. This is not an action movie, it's a fantasy."), Document(metadata={'source': 'john_wick_1.csv', 'row': 5, 'Review_Date': '23 March 2023', 'Review_Title': ' Violent and gripping story with plenty of unstopped action , shootouts and breathtaking fights\n', 'Review_Url': '/review/rw8945545/?ref_=tt_urv', 'Author': 'ma-cortes', 'Rating': 7, 'Movie_Title': 'John Wick 1', 'last_accessed_at': datetime.datetime(2025, 2, 25, 11, 40, 31, 292338)}, page_content=": 5\nReview: Ultra-violent first entry with lots of killings, thrills , noisy action , suspense , and crossfire . In this original John Wick (2014) , an ex-hit-man comes out of retirement to track down the gangsters that killed his dog and took everything from him . With the untimely death of his beloved wife still bitter in his mouth he seeks for vengeance . But when an arrogant Russian mob prince and hoodlums steal his car and kill his dog , they are fully aware of his lethal capacity. The Bogeyman will find himself dragged into an impossible task as every killer in the business dreams of cornering the legendary Wick who now has an enormous price on his head . In this first installment John Wick , blind with revenge, and for his salvation John will immediately unleash a carefully orchestrated maelstrom of destruction against those attempt to chase him and with a price tag on his head, as he is the target of hit men : an army of bounty-hunting killers on his trail and a murderer woman everywhere . The legendary hitman will be forced to unearth his meticulously concealed identity and to carry out a relentless vendetta . Now, only blood can quench the boogeyman's thirst for retribution . Don't Set Him Off! . John Wick isn't the Boogeyman... He's the guy you send to kill the doomed Boogeyman. Revenge is all he has left. You want peace, prepare for war . Don't Hunt What You Can't Kill. Tick Tock, Mr. Wick. Everyone Is Waiting. For John Wick . Every Action Has Conseq ...
# response[response] In the first John Wick movie, he is mad because his beloved dog was killed and his car was stolen by gangsters. This act of cruelty led him to seek vengeance and unleash a wave of destruction against those responsible.
# response {'response': AIMessage(content="'John Wick: Chapter 2' stands out among American action films for its consistency in maintaining a high level of quality throughout the series. Critics have praised the film for its intense action sequences and stylish visuals, making it one of the best-looking action films.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 53, 'prompt_tokens': 1095, 'total_tokens': 1148, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-45a6b338-9ccf-4b51-82ed-9fd5495fe695-0', usage_metadata={'input_tokens': 1095, 'output_tokens': 53, 'total_tokens': 1148, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_4.csv', 'row': 20, 'Review_Date': '23 March 2023', 'Review_Title': ' THIS is how you justify a 3 hour runtime\n', 'Review_Url': '/review/rw8946038/?ref_=tt_urv', 'Author': 'jtindahouse', 'Rating': 9, 'Movie_Title': 'John Wick 4', 'last_accessed_at': datetime.datetime(2025, 2, 28, 11, 40, 31, 292931)}, page_content=": 20\nReview: In a world where movie sequels seem to be loathed even before they are released, the 'John Wick' series has remained remarkably consistent and well received. In fact all three of the first films have the same IMDb rating of 7.4/10 and I noticed recently that I gave them all the same rating of 8/10. Incredibly, I think 'John Wick: Chapter 4' is the best the series has to offer. This movie was a wild ride."), Document(metadata={'source': 'john_wick_3.csv', 'row': 8, 'Review_Date': '15 May 2019', 'Review_Title': ' A brutal non-stop ride\n', 'Review_Url': '/review/rw4854687/?ref_=tt_urv', 'Author': 'jtindahouse', 'Rating': 8, 'Movie_Title': 'John Wick 3', 'last_accessed_at': datetime.datetime(2025, 2, 27, 11, 40, 31, 292736)}, page_content=": 8\nReview: About 6 months ago I saw a picture of the set of 'John Wick: Chapter 3 - Parabellum' featuring Keanu Reeves on horseback shooting at motorcyclists. It was such a great looking shot that I have been waiting eagerly to see how it looked in the actual film ever since. It did not let me down. The style this film possesses is insane. It is one of the best looking action films I have ever seen."), Document(metadata={'source': 'john_wick_4.csv', 'row': 11, 'Review_Date': '26 April 2023', 'Review_Title': ' NOPE\n', 'Review_Url': '/review/rw9017658/?ref_=tt_urv', 'Author': 'kskmah', 'Rating': 1, 'Movie_Title': 'John Wick 4', 'last_accessed_at': datetime.datetime(2025, 2, 28, 11, 40, 31, 292924)}, page_content=": 11\nReview: Who needs a 2hr and 40 min action movie? No one. Yes the action was good, but repeats so many times that it becomes so boring. How can hundreds of assassins not kill one man? Answer, not possible, only in this movie and series. How many times could the dog man have killed Wick? Many. So no other assassin could? Why would the table head get Caine to kill Wick when he knows he won't. You can challenge the head to a duel as a rule, but they only assigned a head for the first time ever in this movie? WTF? And then the head can select a replacement? And he selects a blind man. All Wick had to do was to stand on the side or drop down and he wouldn't get shot. I think everyone knew Wick didn't shoot in the last round, except for the stupid head bad guy. This is not an action movie, it's a fantasy."), Document(metadata={'source': 'john_wick_4.csv', 'row': 19, 'Review_Date': '17 March 2023', 'Review_Title': ' The Best John Wick Sequel\n', 'Review_Url': '/review/rw8935117/?ref_=tt_urv', 'Author': 'tkdlifemagazine', 'Rating': 9, 'Movie_Title': 'John Wick 4', 'last_accessed_at': datetime.datetime(2025, 2, 28, 11 ...
# response[response] 'John Wick: Chapter 2' stands out among American action films for its consistency in maintaining a high level of quality throughout the series. Critics have praised the film for its intense action sequences and stylish visuals, making it one of the best-looking action films.
# response {'response': AIMessage(content='According to the review, John Wick: Chapter 4 improves upon John Wick: Chapter 3 - Parabellum by solidifying Keanu Reeves as the greatest martial arts action star of all time and establishing Reeves and Director, Chad Stahelski, as the greatest martial arts action pairing of modern times.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 65, 'prompt_tokens': 922, 'total_tokens': 987, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-030d9385-cd0e-4216-8420-ba2537b78dcf-0', usage_metadata={'input_tokens': 922, 'output_tokens': 65, 'total_tokens': 987, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_4.csv', 'row': 19, 'Review_Date': '17 March 2023', 'Review_Title': ' The Best John Wick Sequel\n', 'Review_Url': '/review/rw8935117/?ref_=tt_urv', 'Author': 'tkdlifemagazine', 'Rating': 9, 'Movie_Title': 'John Wick 4', 'last_accessed_at': datetime.datetime(2025, 2, 28, 11, 40, 31, 292930)}, page_content=": 19\nReview: John Wick: Chapter 4 picks up where Chapter 3: Parabellum left off. As has been the tradition in the sequels to this beloved martial arts action franchise the action starts from the very inception of the film's opening, and lasts until the curtain falls. JW4 is no exception to that rule. What it does do is improve on the prior installment, and solidify Keanu Reeves as the greatest martial arts action star of all time. If you don't accept that notion, then you must accept the fact that it solidifies Reeves and Director, Chad Stahelski, as the greatest martial arts action pairing of modern times."), Document(metadata={'source': 'john_wick_3.csv', 'row': 24, 'Review_Date': '17 May 2019', 'Review_Title': ' Makes John Wick a superb trilogy\n', 'Review_Url': '/review/rw4860603/?ref_=tt_urv', 'Author': 'masonsaul', 'Rating': 10, 'Movie_Title': 'John Wick 3', 'last_accessed_at': datetime.datetime(2025, 2, 27, 11, 40, 31, 292750)}, page_content=": 24\nReview: John Wick: Chapter 3 - Parabellum is quite literally about consequences, dealing with the fallout of John's actions at the end of the previous film and sending him on an even bigger odyssey of violence that continues to explore this world of assassination and deliver beautifully clean action sequences."), Document(metadata={'source': 'john_wick_3.csv', 'row': 13, 'Review_Date': '15 May 2019', 'Review_Title': ' Pure, delirious joy in the form of yet another exhilarating thriller\n', 'Review_Url': '/review/rw4855261/?ref_=tt_urv', 'Author': 'themadmovieman', 'Rating': 8, 'Movie_Title': 'John Wick 3', 'last_accessed_at': datetime.datetime(2025, 2, 27, 11, 40, 31, 292740)}, page_content=": 13\nReview: Following on from two deliriously entertaining, visually gorgeous and blissfully simplistic thrillers, John Wick: Chapter 3 - Parabellum keeps up the franchise's unique appeal in stunning fashion. Complete with electrifying action, beautiful cinematography, a pulsating score and a great sense of humour, the film is pretty much as purely joyful as action thrillers get, and proves two hours of brilliant entertainment."), Document(metadata={'source': 'john_wick_2.csv', 'row': 11, 'Review_Date': '25 February 2017', 'Review_Title': ' Generic, repetitive and forgettable\n', 'Review_Url': '/review/rw3647634/?ref_=tt_urv', 'Author': 'DVR_Brale', 'Rating': 5, 'Movie_Title': 'John Wick 2', 'last_accessed_at': datetime.datetime(2025, 2, 26, 11, 40, 31, 292542)}, page_content=": 11\nReview: Don't believe the hype. John Wick: Chapter 2 is not as nearly as good as almost everyone is portraying it to be. It's a generic movie with a  ...
# response[response] According to the review, John Wick: Chapter 4 improves upon John Wick: Chapter 3 - Parabellum by solidifying Keanu Reeves as the greatest martial arts action star of all time and establishing Reeves and Director, Chad Stahelski, as the greatest martial arts action pairing of modern times.
# response {'response': AIMessage(content='The John Wick franchise has set a standard for Hollywood action films by delivering expertly choreographed, shot, and edited action sequences that are considered examples of great action filmmaking. The screenplay quality is praised for its creativity and infusion of new ideas compared to other American action flicks that often have poor screenplays. The John Wick franchise is noted for its excellent use of CGI sparingly, unlike many other American action films that tend to overuse computer-generated imagery. Overall, the franchise is seen as a standout in terms of screenplay quality, action choreography, and CGI usage.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 116, 'prompt_tokens': 1121, 'total_tokens': 1237, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-8dbfc470-209d-41a9-8e77-09b52869d127-0', usage_metadata={'input_tokens': 1121, 'output_tokens': 116, 'total_tokens': 1237, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_4.csv', 'row': 18, 'Review_Date': '17 March 2023', 'Review_Title': ' Not Just The Best John Wick, But Possibly One Of The Best Action Movies Ever\n', 'Review_Url': '/review/rw8935367/?ref_=tt_urv', 'Author': 'cadillac20', 'Rating': 10, 'Movie_Title': 'John Wick 4', 'last_accessed_at': datetime.datetime(2025, 2, 28, 11, 40, 31, 292929)}, page_content=": 18\nReview: Ever since the original John Wick, the franchise has set a standard of what action in Hollywood should be. Thanks to Chad Stahelski and Keanu Reeve's knowledge of the technical aspects of shooting action, they've been able to deliver expertly choreographed, shot, and edited action films that are now the go to as examples of great action filmmaking. And so, the expectations for the fourth film were fairly high, especially as it became more apparent this was not only the culmination of everything before it, but a whopping 169 minutes long. Rest assured, however, that it delivers in spades. Everything we have come to know and love is here, but with an infusion of creativity like we haven't seen from the franchise yet."), Document(metadata={'source': 'john_wick_4.csv', 'row': 10, 'Review_Date': '22 March 2023', 'Review_Title': ' How Can Anyone Choose to Watch Marvel Over This?\n', 'Review_Url': '/review/rw8944843/?ref_=tt_urv', 'Author': 'lovemichaeljordan', 'Rating': 8, 'Movie_Title': 'John Wick 4', 'last_accessed_at': datetime.datetime(2025, 2, 28, 11, 40, 31, 292923)}, page_content=": 10\nReview: Most American action flicks released these days have poor screenplays and overuse computer-generated imagery. The John Wick franchise is one of the few exceptions, along with Mission Impossible. These franchises keep getting better with every entry. Hollywood can make action masterpieces, but Marvel has greater demand, so that's what we get most of. It's a shame."), Document(metadata={'source': 'john_wick_3.csv', 'row': 19, 'Review_Date': '22 September 2019', 'Review_Title': ' Sheer enjoyment\n', 'Review_Url': '/review/rw5135863/?ref_=tt_urv', 'Author': 'Leofwine_draca', 'Rating': 9, 'Movie_Title': 'John Wick 3', 'last_accessed_at': datetime.datetime(2025, 2, 27, 11, 40, 31, 292746)}, page_content=': 19\nReview: The inevitable third chapter of the JOHN WICK franchise continues on a high with the same quality as the last. In fact, this may just pip that one to the post to be the best JOHN WICK yet. The pacing is spot on and the plotting is measured by a huge amount of action sequences, all of which fizz and crackle with skill and energy. The movie hits the ground running as Keanu fac ...
# response[response] The John Wick franchise has set a standard for Hollywood action films by delivering expertly choreographed, shot, and edited action sequences that are considered examples of great action filmmaking. The screenplay quality is praised for its creativity and infusion of new ideas compared to other American action flicks that often have poor screenplays. The John Wick franchise is noted for its excellent use of CGI sparingly, unlike many other American action films that tend to overuse computer-generated imagery. Overall, the franchise is seen as a standout in terms of screenplay quality, action choreography, and CGI usage.
# response {'response': AIMessage(content="The reviews reflect that Keanu Reeves' portrayal in the John Wick franchise is generally praised for his action choreography skills and the character depth he brings to the role. Reviewers appreciate the relentless action sequences and the inventiveness in the choreography, especially in the hand-to-hand combat scenes. Keanu Reeves is seen as a driving force in making the films enjoyable and engaging.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 78, 'prompt_tokens': 1586, 'total_tokens': 1664, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-9762377b-4d12-4297-a709-93855979f437-0', usage_metadata={'input_tokens': 1586, 'output_tokens': 78, 'total_tokens': 1664, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_2.csv', 'row': 23, 'Review_Date': '4 February 2020', 'Review_Title': ' Keanu kills everyone. Again.\n', 'Review_Url': '/review/rw5459627/?ref_=tt_urv', 'Author': 'BA_Harrison', 'Rating': 5, 'Movie_Title': 'John Wick 2', 'last_accessed_at': datetime.datetime(2025, 2, 26, 11, 40, 31, 292552)}, page_content=": 23\nReview: I love me a bit of the old ultra-violence, but I also like a plot of some kind to go with all of the gunfire, blood and broken bones. Failing that, the gory mayhem had better be something special - something that breaks new ground in terms of action cinema. John Wick Chapter 2 is relentlessly violent, Keanu Reeves' eponymous hitman laying waste to almost everyone he crosses paths with, once again finishing most victims with a shot to the head, but the action is simply more of the same, director Chad Stahelski bringing nothing new to the table."), Document(metadata={'source': 'john_wick_3.csv', 'row': 19, 'Review_Date': '22 September 2019', 'Review_Title': ' Sheer enjoyment\n', 'Review_Url': '/review/rw5135863/?ref_=tt_urv', 'Author': 'Leofwine_draca', 'Rating': 9, 'Movie_Title': 'John Wick 3', 'last_accessed_at': datetime.datetime(2025, 2, 27, 11, 40, 31, 292746)}, page_content=': 19\nReview: The inevitable third chapter of the JOHN WICK franchise continues on a high with the same quality as the last. In fact, this may just pip that one to the post to be the best JOHN WICK yet. The pacing is spot on and the plotting is measured by a huge amount of action sequences, all of which fizz and crackle with skill and energy. The movie hits the ground running as Keanu faces off with a hulking character in a library and then Triads in a weapon shop, but what really amazes here is the sheer inventiveness of the non-repetitive action. There are horse and motorbike chases, a Moroccan brawl with fighting dogs, alongside the massive action of the climax. There also seems to be a greater emphasis on hand-to-hand combat, featuring the likes of RAID actors and old-timer Mark Dacascos, which is a real pleasure as the choreography is top-notch. In terms of sheer enjoyment, this is a film hard to beat, and to criticise it at all is unnecessary. Bring on the fourth!'), Document(metadata={'source': 'john_wick_1.csv', 'row': 9, 'Review_Date': '20 October 2014', 'Review_Title': " The coolest action film you'll see all year\n", 'Review_Url': '/review/rw3107759/?ref_=tt_urv', 'Author': 'trublu215', 'Rating': 9, 'Movie_Title': 'John Wick 1', 'last_accessed_at': datetime.datetime(2025, 2, 25, 11, 40, 31, 292341)}, page_content=": 9\nReview: At first glance, John Wick sounds like a terrible film on paper but with the slickness of Keanu Reeves' performance as the titular character and the sheer brilliance in its action sequences, this marks the best action film of the y ...
# response[response] The reviews reflect that Keanu Reeves' portrayal in the John Wick franchise is generally praised for his action choreography skills and the character depth he brings to the role. Reviewers appreciate the relentless action sequences and the inventiveness in the choreography, especially in the hand-to-hand combat scenes. Keanu Reeves is seen as a driving force in making the films enjoyable and engaging.
# response {'response': AIMessage(content='Ian McShane is important in the John Wick movies because he plays a key role as Winston, the owner of the Continental Hotel, a safe haven for assassins. His character adds depth to the story by providing a sense of organization and power within the criminal underworld depicted in the movies. Additionally, his charismatic performance as Winston makes the character more intriguing and helps to elevate the overall film.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 79, 'prompt_tokens': 1656, 'total_tokens': 1735, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-77a8d823-ebff-43ec-bea5-ff65f5cf9042-0', usage_metadata={'input_tokens': 1656, 'output_tokens': 79, 'total_tokens': 1735, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_2.csv', 'row': 19, 'Review_Date': '29 November 2020', 'Review_Title': ' John Wick Kills A Lot Of People\n', 'Review_Url': '/review/rw6320115/?ref_=tt_urv', 'Author': 'boblipton', 'Rating': 5, 'Movie_Title': 'John Wick 2', 'last_accessed_at': datetime.datetime(2025, 2, 26, 11, 40, 31, 292549)}, page_content=": 19\nReview: If you've seen the first John Wick movie, you know that Keanu Reeves is John Wick, a retired assassin who comes out of retirement when someone kills his dog. In this one, which begins a week later, matters are still reverberating, and some one has stolen his car, which calls for a lot of carnage. That settled, John is called on to pay off an old debt by helping Ian McShane take over the Assassin's Guild by flying around to Italy, Canada and Manhattan and killing what seems like hundreds of assassins."), Document(metadata={'source': 'john_wick_1.csv', 'row': 9, 'Review_Date': '20 October 2014', 'Review_Title': " The coolest action film you'll see all year\n", 'Review_Url': '/review/rw3107759/?ref_=tt_urv', 'Author': 'trublu215', 'Rating': 9, 'Movie_Title': 'John Wick 1', 'last_accessed_at': datetime.datetime(2025, 2, 25, 11, 40, 31, 292341)}, page_content=": 9\nReview: At first glance, John Wick sounds like a terrible film on paper but with the slickness of Keanu Reeves' performance as the titular character and the sheer brilliance in its action sequences, this marks the best action film of the year and one of the absolute best in the past decade. Following a brutal home invasion that leaves his beloved dog murdered by thugs from his past, John Wick vows revenge on the ones who have taken what he loves most. Like I said, on paper, this seems like a direct-to-DVD slopfest starring John Cena but as a film with Keanu Reeves as the lead, it marks the very welcomed return for Reeves to the genre. John Wick is insanely fun, violently brutal and an overall romp especially for those disappointed by The Expendables 3. John Wick is propelled by Tarantino-esque dialog mixed with the swagger of action stars from the 70s. Reeves literally emulates cool in this film and does it with such confidence, that we don't even doubt the character...even when he kills countless bad guys with extreme force in some utterly ridiculous and implausible situations. We don't doubt it for a minute. This is EXACTLY what you want out of an action film. It is briskly paced, brilliantly shot and meticulously choreographed and keeps you wanting more and more. The supporting cast filled with the likes of John Legiuzamo, Ian McShane, and Willen Dafoe also keeps this film very interesting. These guys don't play good guys, hell, John Wick by traditional standards would be a bad guy in any other film. Every character is more ruthless than the next and pushes John  ...
# response[response] Ian McShane is important in the John Wick movies because he plays a key role as Winston, the owner of the Continental Hotel, a safe haven for assassins. His character adds depth to the story by providing a sense of organization and power within the criminal underworld depicted in the movies. Additionally, his charismatic performance as Winston makes the character more intriguing and helps to elevate the overall film.
# Evaluating:   0%|          | 0/60 [00:00<?, ?it/s]
# bm25_retrieval_chain 262.4028498750122

# %%
result_ecompression_retrieval = evaluate_one_chain(dataset, contextual_compression_retrieval_chain)
# Out:
# response {'response': AIMessage(content='Liem Neeson is not a character in John Wick; Liam Neeson is mentioned in the context comparing him to Keanu Reeves in terms of the type of role they play in their respective movies.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 42, 'prompt_tokens': 931, 'total_tokens': 973, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-cbe39dc7-9036-417b-b181-b793ba9c038c-0', usage_metadata={'input_tokens': 931, 'output_tokens': 42, 'total_tokens': 973, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_1.csv', 'row': 0, 'Review_Date': '6 May 2015', 'Review_Title': ' Kinetic, concise, and stylish; John Wick kicks ass.\n', 'Review_Url': '/review/rw3233896/?ref_=tt_urv', 'Author': 'lnvicta', 'Rating': 8, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292319', '_id': 'e1a0f158b67f4d4681b444e63f512cb9', '_collection_name': 'JohnWick', 'relevance_score': 0.57660156}, page_content=": 0\nReview: The best way I can describe John Wick is to picture Taken but instead of Liam Neeson it's Keanu Reeves and instead of his daughter it's his dog. That's essentially the plot of the movie. John Wick (Reeves) is out to seek revenge on the people who took something he loved from him. It's a beautifully simple premise for an action movie - when action movies get convoluted, they get bad i.e. A Good Day to Die Hard. John Wick gives the viewers what they want: Awesome action, stylish stunts, kinetic chaos, and a relatable hero to tie it all together. John Wick succeeds in its simplicity."), Document(metadata={'source': 'john_wick_1.csv', 'row': 11, 'Review_Date': '25 September 2015', 'Review_Title': ' Action as it should be\n', 'Review_Url': '/review/rw3323198/?ref_=tt_urv', 'Author': 'Leofwine_draca', 'Rating': 8, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292343', '_id': '2e20bf44b0454d86acfb2fd0d1ee74a5', '_collection_name': 'JohnWick', 'relevance_score': 0.33698532}, page_content=": 11\nReview: JOHN WICK is a rare example of Hollywood getting things spot-on when it comes to creating the near-perfect action film. JOHN WICK is a relentless, pulse-pounding thriller that has plenty of similarity to the Liam Neeson classic TAKEN, albeit with a more simplistic (and also more emotionally intense) plot line. This is the kind of lean, pared-down film-making that's all about intensity and momentum. It sits well with classic international fare like POINT BLANK, SLEEPLESS NIGHT, MEA CULPA, THE MAN FROM NOWHERE, and THE RAID films."), Document(metadata={'source': 'john_wick_2.csv', 'row': 19, 'Review_Date': '29 November 2020', 'Review_Title': ' John Wick Kills A Lot Of People\n', 'Review_Url': '/review/rw6320115/?ref_=tt_urv', 'Author': 'boblipton', 'Rating': 5, 'Movie_Title': 'John Wick 2', 'last_accessed_at': '2025-02-26T11:40:31.292549', '_id': 'c6a990d6fb27499096a867702c0bdfaf', '_collection_name': 'JohnWick', 'relevance_score': 0.0029121784}, page_content=": 19\nReview: If you've seen the first John Wick movie, you know that Keanu Reeves is John Wick, a retired assassin who comes out of retirement when someone kills his dog. In this one, which begins a week later, matters are still reverberating, and some one has stolen his car, which calls for a lot of carnage. That settled, John is called on to pay off an old debt by helping Ian McShane take over the Assassin's Guild by flying around to Italy, Canada and Manhattan and killing what seems like hundreds of assassins.")]}
# response[response] Liem Neeson is not a character in John Wick; Liam Neeson is mentioned in the context comparing him to Keanu Reeves in terms of the type of role they play in their respective movies.
# response {'response': AIMessage(content='The reception of the John Wick franchise, particularly with the release of the fourth installment, has been extremely positive. Critics and audiences have praised the film for its action sequences, choreography, and overall quality, with some even calling it one of the best action movies ever.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 55, 'prompt_tokens': 960, 'total_tokens': 1015, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-7980a6e9-d15e-4f92-974c-9ba89e5f2fc6-0', usage_metadata={'input_tokens': 960, 'output_tokens': 55, 'total_tokens': 1015, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_4.csv', 'row': 20, 'Review_Date': '23 March 2023', 'Review_Title': ' THIS is how you justify a 3 hour runtime\n', 'Review_Url': '/review/rw8946038/?ref_=tt_urv', 'Author': 'jtindahouse', 'Rating': 9, 'Movie_Title': 'John Wick 4', 'last_accessed_at': '2025-02-28T11:40:31.292931', '_id': '2b2772db123f4ba4bff10cc8c5e610a2', '_collection_name': 'JohnWick', 'relevance_score': 0.99972624}, page_content=": 20\nReview: In a world where movie sequels seem to be loathed even before they are released, the 'John Wick' series has remained remarkably consistent and well received. In fact all three of the first films have the same IMDb rating of 7.4/10 and I noticed recently that I gave them all the same rating of 8/10. Incredibly, I think 'John Wick: Chapter 4' is the best the series has to offer. This movie was a wild ride."), Document(metadata={'source': 'john_wick_4.csv', 'row': 18, 'Review_Date': '17 March 2023', 'Review_Title': ' Not Just The Best John Wick, But Possibly One Of The Best Action Movies Ever\n', 'Review_Url': '/review/rw8935367/?ref_=tt_urv', 'Author': 'cadillac20', 'Rating': 10, 'Movie_Title': 'John Wick 4', 'last_accessed_at': '2025-02-28T11:40:31.292929', '_id': 'fb6da2a08531428d890d90e797894e1f', '_collection_name': 'JohnWick', 'relevance_score': 0.9935369}, page_content=": 18\nReview: Ever since the original John Wick, the franchise has set a standard of what action in Hollywood should be. Thanks to Chad Stahelski and Keanu Reeve's knowledge of the technical aspects of shooting action, they've been able to deliver expertly choreographed, shot, and edited action films that are now the go to as examples of great action filmmaking. And so, the expectations for the fourth film were fairly high, especially as it became more apparent this was not only the culmination of everything before it, but a whopping 169 minutes long. Rest assured, however, that it delivers in spades. Everything we have come to know and love is here, but with an infusion of creativity like we haven't seen from the franchise yet."), Document(metadata={'source': 'john_wick_4.csv', 'row': 19, 'Review_Date': '17 March 2023', 'Review_Title': ' The Best John Wick Sequel\n', 'Review_Url': '/review/rw8935117/?ref_=tt_urv', 'Author': 'tkdlifemagazine', 'Rating': 9, 'Movie_Title': 'John Wick 4', 'last_accessed_at': '2025-02-28T11:40:31.292930', '_id': '9d49fc87e57645e0b304d3f1bb6446bf', '_collection_name': 'JohnWick', 'relevance_score': 0.9882676}, page_content=": 19\nReview: John Wick: Chapter 4 picks up where Chapter 3: Parabellum left off. As has been the tradition in the sequels to this beloved martial arts action franchise the action starts from the very inception of the film's opening, and lasts until the curtain falls. JW4 is no exception to that rule. What it does do is improve on the prior installment, and solidify Keanu Reeves as the greatest martial arts action star of all time. If you  ...
# response[response] The reception of the John Wick franchise, particularly with the release of the fourth installment, has been extremely positive. Critics and audiences have praised the film for its action sequences, choreography, and overall quality, with some even calling it one of the best action movies ever.
# response {'response': AIMessage(content="Chad Stahelski's direction in the John Wick film contributes to its uniqueness by showcasing real virtuoso action sequences with well-made choreographies. Unlike many action movies today, Stahelski's direction avoids quick-cuts and shaky cameras, allowing the audience to clearly see what's going on during the action scenes.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 67, 'prompt_tokens': 916, 'total_tokens': 983, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-231a5f32-635a-4786-9aef-c8deb0535870-0', usage_metadata={'input_tokens': 916, 'output_tokens': 67, 'total_tokens': 983, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_1.csv', 'row': 3, 'Review_Date': '28 September 2018', 'Review_Title': ' Keanu gets pissed and shoots people in the face for 101 minutes*\n', 'Review_Url': '/review/rw4366368/?ref_=tt_urv', 'Author': 'Kitsfi', 'Rating': 8, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292336', '_id': 'bbef47586c9142cb9757e322fc560993', '_collection_name': 'JohnWick', 'relevance_score': 0.99293363}, page_content=': 3\nReview: John wick has a very simple revenge story. It can be summarized as "Keanu gets angry and shoots bad guys" but what makes it special? Directed by Chad Stahelski who\'s a stunt specialist boy does it show because the main selling point in the film are some real virtuoso action sequences, well made choreographies. Unlike today\'s action movies, it doesn\'t use quick-cuts or shaky cameras actually see what\'s going on.'), Document(metadata={'source': 'john_wick_4.csv', 'row': 17, 'Review_Date': '16 March 2023', 'Review_Title': ' While the Wick franchise has already solidified itself one of the best in the action genre, this massive film is the most spectacular entry of the genre in 30 years.\n', 'Review_Url': '/review/rw8932278/?ref_=tt_urv', 'Author': 'tresm87', 'Rating': 9, 'Movie_Title': 'John Wick 4', 'last_accessed_at': '2025-02-28T11:40:31.292928', '_id': '60771792fe4e48b2ae81fec8ca50ec31', '_collection_name': 'JohnWick', 'relevance_score': 0.9497627}, page_content=": 17\nReview: Stuntman turned writer/director Chad Stahelski struck gold with his 2014 surprise hit John Wick. It was somewhat of a comeback for the legendary Keanu Reeves and reinvigorated the action genre. Since then it's become THE action juggernaut franchise. Now we are on number 4 and while usually things get redone with that amount of sequels, this film innovates and thrills to new heights in an absolute epic."), Document(metadata={'source': 'john_wick_4.csv', 'row': 19, 'Review_Date': '17 March 2023', 'Review_Title': ' The Best John Wick Sequel\n', 'Review_Url': '/review/rw8935117/?ref_=tt_urv', 'Author': 'tkdlifemagazine', 'Rating': 9, 'Movie_Title': 'John Wick 4', 'last_accessed_at': '2025-02-28T11:40:31.292930', '_id': '9d49fc87e57645e0b304d3f1bb6446bf', '_collection_name': 'JohnWick', 'relevance_score': 0.6658453}, page_content=": 19\nReview: John Wick: Chapter 4 picks up where Chapter 3: Parabellum left off. As has been the tradition in the sequels to this beloved martial arts action franchise the action starts from the very inception of the film's opening, and lasts until the curtain falls. JW4 is no exception to that rule. What it does do is improve on the prior installment, and solidify Keanu Reeves as the greatest martial arts action star of all time. If you don't accept that notion, then you must accept the fact that it solidifies Reeves and Director, Chad Stahelski, as the greatest martial arts action pairing of modern times." ...
# response[response] Chad Stahelski's direction in the John Wick film contributes to its uniqueness by showcasing real virtuoso action sequences with well-made choreographies. Unlike many action movies today, Stahelski's direction avoids quick-cuts and shaky cameras, allowing the audience to clearly see what's going on during the action scenes.
# response {'response': AIMessage(content="John Wick goes after Russian mobsters because he is asked by mobster Santino D'Antonio to kill his sister Gianna D'Antonio in Rome in order for Santino to sit on the High Table of the criminal organizations. When John completes this task, Santino puts a seven-million dollar contract on him, attracting professional killers from everywhere.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 72, 'prompt_tokens': 1484, 'total_tokens': 1556, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-3b53271c-fbce-4a61-9052-6d3f1e22ea06-0', usage_metadata={'input_tokens': 1484, 'output_tokens': 72, 'total_tokens': 1556, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_2.csv', 'row': 20, 'Review_Date': '28 May 2017', 'Review_Title': ' A New Franchise is Born\n', 'Review_Url': '/review/rw3718180/?ref_=tt_urv', 'Author': 'claudio_carvalho', 'Rating': 8, 'Movie_Title': 'John Wick 2', 'last_accessed_at': '2025-02-26T11:40:31.292549', '_id': '14e4e01f095c4b559b49399bfd92e08f', '_collection_name': 'JohnWick', 'relevance_score': 0.9738444}, page_content=": 20\nReview: After resolving his issues with the Russian mafia, John Wick (Keanu Reeves) returns home. But soon the mobster Santino D'Antonio (Riccardo Scamarcio) visits him to show Wick's marker and tells that he needs to help. John Wicks refuses since he is retired and Santino blows-up his house. John Wick meets the owner of the Continental hotel in New York City, Winston (Ian McShane), and he tells that Wick cannot violate the Mafia rules and shall honor the marker. Santino asks John Wick to kill his sister Gianna D'Antonio (Claudia Gerini) in Rome so that he can sit on the High Table of the criminal organizations. When John Wicks accomplishes his assignment, Santino puts a seven-million dollar contract on him attracting professional killers from everywhere. But Wick promises to kill Santino that is not protected by his marker anymore."), Document(metadata={'source': 'john_wick_1.csv', 'row': 20, 'Review_Date': '22 October 2014', 'Review_Title': ' Smoothest action film to come around in a long time\n', 'Review_Url': '/review/rw3109271/?ref_=tt_urv', 'Author': 'IceSkateUpHill', 'Rating': 10, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292350', '_id': 'abf04bb7a461407a8de2219f2fc53b49', '_collection_name': 'JohnWick', 'relevance_score': 0.8498466}, page_content=": 20\nReview: John Wick is something special. It takes as much time setting up elaborate action sequences as it does the world with which it all takes place in. And what a world it is. It reminds me of Millers Crossing and it is cooler than any other recent attempt at noir. We are shown a criminal underworld where, if you are connected, many powerful people know who you are and show you respect. John Wick was connected but he got out. He is the rare killer who has found peace, and he is grateful for that peace. Some young kids steal that from him and he does what he does best, he wages a one man war against the Russian Mafia. It might sound like the film takes quite a leap but it all makes sense. The motives of John and the people who get in the way of his bullets are all very clear, even if it does come across as rather simple. That's the plot at it's most basic. Then there's the action. The film is directed by Reeve's stuntman from The Matrix, so this guy knows action. There are sequences that flow so smoothly it puts other action films and their quick cuts to shame. Keaunu moves so fluidly throughout the film and comes across as such a natural that  ...
# response[response] John Wick goes after Russian mobsters because he is asked by mobster Santino D'Antonio to kill his sister Gianna D'Antonio in Rome in order for Santino to sit on the High Table of the criminal organizations. When John completes this task, Santino puts a seven-million dollar contract on him, attracting professional killers from everywhere.
# response {'response': AIMessage(content='In the first John Wick movie, John Wick is mad because gangsters killed his dog and took everything from him, including his beloved wife. He seeks vengeance against those responsible for the loss he has experienced.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 42, 'prompt_tokens': 1107, 'total_tokens': 1149, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-e6c78f13-d417-4f86-a177-a9dfdbf76044-0', usage_metadata={'input_tokens': 1107, 'output_tokens': 42, 'total_tokens': 1149, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_1.csv', 'row': 5, 'Review_Date': '23 March 2023', 'Review_Title': ' Violent and gripping story with plenty of unstopped action , shootouts and breathtaking fights\n', 'Review_Url': '/review/rw8945545/?ref_=tt_urv', 'Author': 'ma-cortes', 'Rating': 7, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292338', '_id': '5c16d3bf25b64afdb3e2a3f3c6f1d4cc', '_collection_name': 'JohnWick', 'relevance_score': 0.6171666}, page_content=": 5\nReview: Ultra-violent first entry with lots of killings, thrills , noisy action , suspense , and crossfire . In this original John Wick (2014) , an ex-hit-man comes out of retirement to track down the gangsters that killed his dog and took everything from him . With the untimely death of his beloved wife still bitter in his mouth he seeks for vengeance . But when an arrogant Russian mob prince and hoodlums steal his car and kill his dog , they are fully aware of his lethal capacity. The Bogeyman will find himself dragged into an impossible task as every killer in the business dreams of cornering the legendary Wick who now has an enormous price on his head . In this first installment John Wick , blind with revenge, and for his salvation John will immediately unleash a carefully orchestrated maelstrom of destruction against those attempt to chase him and with a price tag on his head, as he is the target of hit men : an army of bounty-hunting killers on his trail and a murderer woman everywhere . The legendary hitman will be forced to unearth his meticulously concealed identity and to carry out a relentless vendetta . Now, only blood can quench the boogeyman's thirst for retribution . Don't Set Him Off! . John Wick isn't the Boogeyman... He's the guy you send to kill the doomed Boogeyman. Revenge is all he has left. You want peace, prepare for war . Don't Hunt What You Can't Kill. Tick Tock, Mr. Wick. Everyone Is Waiting. For John Wick . Every Action Has Consequences. This Friday, Wick is Back . Its the World Vs. Wick. Every Action Has Consequences."), Document(metadata={'source': 'john_wick_2.csv', 'row': 19, 'Review_Date': '29 November 2020', 'Review_Title': ' John Wick Kills A Lot Of People\n', 'Review_Url': '/review/rw6320115/?ref_=tt_urv', 'Author': 'boblipton', 'Rating': 5, 'Movie_Title': 'John Wick 2', 'last_accessed_at': '2025-02-26T11:40:31.292549', '_id': 'c6a990d6fb27499096a867702c0bdfaf', '_collection_name': 'JohnWick', 'relevance_score': 0.40450746}, page_content=": 19\nReview: If you've seen the first John Wick movie, you know that Keanu Reeves is John Wick, a retired assassin who comes out of retirement when someone kills his dog. In this one, which begins a week later, matters are still reverberating, and some one has stolen his car, which calls for a lot of carnage. That settled, John is called on to pay off an old debt by helping Ian McShane take over the Assassin's Guild by flying around to Italy, Canada and Manhattan and killing what seems like hundreds of assassins."), Docum ...
# response[response] In the first John Wick movie, John Wick is mad because gangsters killed his dog and took everything from him, including his beloved wife. He seeks vengeance against those responsible for the loss he has experienced.
# response {'response': AIMessage(content="'John Wick: Chapter 2' stands out among American action films according to reviews due to its relentless action, entertaining storyline, and impressive set design and camera work. This sequel is praised for delivering pure escapist entertainment and setting the bar high in the action genre.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 55, 'prompt_tokens': 1102, 'total_tokens': 1157, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-d9de81f8-0ca1-4ed3-b3b5-b32ddb738212-0', usage_metadata={'input_tokens': 1102, 'output_tokens': 55, 'total_tokens': 1157, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_2.csv', 'row': 9, 'Review_Date': '22 July 2017', 'Review_Title': ' A disappointing sequel for the most part\n', 'Review_Url': '/review/rw3760991/?ref_=tt_urv', 'Author': 'Horst_In_Translation', 'Rating': 4, 'Movie_Title': 'John Wick 2', 'last_accessed_at': '2025-02-26T11:40:31.292541', '_id': '5ea64efd95dd415d88fb72960a633636', '_collection_name': 'JohnWick', 'relevance_score': 0.9998945}, page_content=': 9\nReview: "John Wick: Chapter 2" is an American movie from this year (2017). Experienced visual effects artist Stahelski and Kolstad returned from the very first Wick film to work on the script/direction here too, so the premise with regard to people working behind the camera is there. And in front of the camera we see familiar faces again, people that survived the film, like most of all Keanu Reeves playing the central character. This is a really long film at over 2 hours and at this runtime, it is considerably longer than the first. And there is a lot other stuff different compared to the original. Most has to do with the fun component. I think the first film was a great fun watch from start to finish while offering emotion nonetheless and also delivering in the crime and drama genres. And action too, but I don\'t care too much about that. This genre is also basically the only one where this new movie delivers as the first 30 minutes are truly packed with action. It gets less afterward, but there is no denying that it was still all about the action and nothing else.'), Document(metadata={'source': 'john_wick_2.csv', 'row': 16, 'Review_Date': '9 February 2017', 'Review_Title': ' Kick-ass, entertaining and relentless throughout. This is what every sequel should aspire to be.\n', 'Review_Url': '/review/rw3636884/?ref_=tt_urv', 'Author': 'trublu215', 'Rating': 5, 'Movie_Title': 'John Wick 2', 'last_accessed_at': '2025-02-26T11:40:31.292546', '_id': '3b935f6ed310465b801954cade3ce370', '_collection_name': 'JohnWick', 'relevance_score': 0.9996049}, page_content=": 16\nReview: John Wick Chapter 2 pits Keanu Reeves' titular character against the mean and nefarious of the criminal underworld. Once again, Reeves proves that he is a force to be reckoned with in this ridiculous, over-the-top sequel that is every bit as fun as the original. These types of films are rarely known for their artistic value but John Wick: Chapter 2 sets the bar pretty high, not only in its action, but in it's set design and camera work. This is pure escapist entertainment and couldn't have come at a better time. Those wanting to take a break from watching the Oscar nominees, this film is exactly what you're looking for."), Document(metadata={'source': 'john_wick_2.csv', 'row': 0, 'Review_Date': '14 September 2018', 'Review_Title': ' "No one gets out and comes back without repercussions."\n', 'Review_Url': '/review/rw4338449/?ref_=tt_urv', 'Author': 'classicsoncall', 'Rating': 7, 'Movie_Title': 'J ...
# response[response] 'John Wick: Chapter 2' stands out among American action films according to reviews due to its relentless action, entertaining storyline, and impressive set design and camera work. This sequel is praised for delivering pure escapist entertainment and setting the bar high in the action genre.
# response {'response': AIMessage(content='According to reviews, John Wick: Chapter 4 improves upon John Wick: Chapter 3 - Parabellum by solidifying Keanu Reeves as the greatest martial arts action star of all time and by strengthening the partnership between Reeves and Director Chad Stahelski. It is also praised for its action sequences and maintaining the high standard set by the previous films in the series.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 78, 'prompt_tokens': 862, 'total_tokens': 940, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-27e4edfb-2092-4f51-b343-1f8f5923313b-0', usage_metadata={'input_tokens': 862, 'output_tokens': 78, 'total_tokens': 940, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_4.csv', 'row': 19, 'Review_Date': '17 March 2023', 'Review_Title': ' The Best John Wick Sequel\n', 'Review_Url': '/review/rw8935117/?ref_=tt_urv', 'Author': 'tkdlifemagazine', 'Rating': 9, 'Movie_Title': 'John Wick 4', 'last_accessed_at': '2025-02-28T11:40:31.292930', '_id': '9d49fc87e57645e0b304d3f1bb6446bf', '_collection_name': 'JohnWick', 'relevance_score': 0.99999857}, page_content=": 19\nReview: John Wick: Chapter 4 picks up where Chapter 3: Parabellum left off. As has been the tradition in the sequels to this beloved martial arts action franchise the action starts from the very inception of the film's opening, and lasts until the curtain falls. JW4 is no exception to that rule. What it does do is improve on the prior installment, and solidify Keanu Reeves as the greatest martial arts action star of all time. If you don't accept that notion, then you must accept the fact that it solidifies Reeves and Director, Chad Stahelski, as the greatest martial arts action pairing of modern times."), Document(metadata={'source': 'john_wick_3.csv', 'row': 24, 'Review_Date': '17 May 2019', 'Review_Title': ' Makes John Wick a superb trilogy\n', 'Review_Url': '/review/rw4860603/?ref_=tt_urv', 'Author': 'masonsaul', 'Rating': 10, 'Movie_Title': 'John Wick 3', 'last_accessed_at': '2025-02-27T11:40:31.292750', '_id': '6daad8494ac4440a9b12f739582a5326', '_collection_name': 'JohnWick', 'relevance_score': 0.9923638}, page_content=": 24\nReview: John Wick: Chapter 3 - Parabellum is quite literally about consequences, dealing with the fallout of John's actions at the end of the previous film and sending him on an even bigger odyssey of violence that continues to explore this world of assassination and deliver beautifully clean action sequences."), Document(metadata={'source': 'john_wick_4.csv', 'row': 20, 'Review_Date': '23 March 2023', 'Review_Title': ' THIS is how you justify a 3 hour runtime\n', 'Review_Url': '/review/rw8946038/?ref_=tt_urv', 'Author': 'jtindahouse', 'Rating': 9, 'Movie_Title': 'John Wick 4', 'last_accessed_at': '2025-02-28T11:40:31.292931', '_id': '2b2772db123f4ba4bff10cc8c5e610a2', '_collection_name': 'JohnWick', 'relevance_score': 0.98975134}, page_content=": 20\nReview: In a world where movie sequels seem to be loathed even before they are released, the 'John Wick' series has remained remarkably consistent and well received. In fact all three of the first films have the same IMDb rating of 7.4/10 and I noticed recently that I gave them all the same rating of 8/10. Incredibly, I think 'John Wick: Chapter 4' is the best the series has to offer. This movie was a wild ride.")]}
# response[response] According to reviews, John Wick: Chapter 4 improves upon John Wick: Chapter 3 - Parabellum by solidifying Keanu Reeves as the greatest martial arts action star of all time and by strengthening the partnership between Reeves and Director Chad Stahelski. It is also praised for its action sequences and maintaining the high standard set by the previous films in the series.
# response {'response': AIMessage(content='The John Wick franchise has set a standard for Hollywood action films by delivering expertly choreographed, shot, and edited action sequences that are considered examples of great action filmmaking. In terms of screenplay quality and use of CGI, the John Wick franchise is praised for having a strong screenplay and minimal use of CGI compared to other American action flicks. The franchise is seen as an exception to the trend of poor screenplays and overuse of computer-generated imagery in many American action movies.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 97, 'prompt_tokens': 995, 'total_tokens': 1092, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-6d71109e-9b88-49d7-bc56-02064401db64-0', usage_metadata={'input_tokens': 995, 'output_tokens': 97, 'total_tokens': 1092, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_4.csv', 'row': 18, 'Review_Date': '17 March 2023', 'Review_Title': ' Not Just The Best John Wick, But Possibly One Of The Best Action Movies Ever\n', 'Review_Url': '/review/rw8935367/?ref_=tt_urv', 'Author': 'cadillac20', 'Rating': 10, 'Movie_Title': 'John Wick 4', 'last_accessed_at': '2025-02-28T11:40:31.292929', '_id': 'fb6da2a08531428d890d90e797894e1f', '_collection_name': 'JohnWick', 'relevance_score': 0.99998665}, page_content=": 18\nReview: Ever since the original John Wick, the franchise has set a standard of what action in Hollywood should be. Thanks to Chad Stahelski and Keanu Reeve's knowledge of the technical aspects of shooting action, they've been able to deliver expertly choreographed, shot, and edited action films that are now the go to as examples of great action filmmaking. And so, the expectations for the fourth film were fairly high, especially as it became more apparent this was not only the culmination of everything before it, but a whopping 169 minutes long. Rest assured, however, that it delivers in spades. Everything we have come to know and love is here, but with an infusion of creativity like we haven't seen from the franchise yet."), Document(metadata={'source': 'john_wick_4.csv', 'row': 10, 'Review_Date': '22 March 2023', 'Review_Title': ' How Can Anyone Choose to Watch Marvel Over This?\n', 'Review_Url': '/review/rw8944843/?ref_=tt_urv', 'Author': 'lovemichaeljordan', 'Rating': 8, 'Movie_Title': 'John Wick 4', 'last_accessed_at': '2025-02-28T11:40:31.292923', '_id': 'b66f76b8e43648f59089c83623a0c5c1', '_collection_name': 'JohnWick', 'relevance_score': 0.9999118}, page_content=": 10\nReview: Most American action flicks released these days have poor screenplays and overuse computer-generated imagery. The John Wick franchise is one of the few exceptions, along with Mission Impossible. These franchises keep getting better with every entry. Hollywood can make action masterpieces, but Marvel has greater demand, so that's what we get most of. It's a shame."), Document(metadata={'source': 'john_wick_4.csv', 'row': 14, 'Review_Date': '23 March 2023', 'Review_Title': ' Yeah\n', 'Review_Url': '/review/rw8946621/?ref_=tt_urv', 'Author': 'markvanwasbeek', 'Rating': 9, 'Movie_Title': 'John Wick 4', 'last_accessed_at': '2025-02-28T11:40:31.292926', '_id': 'c2d2e39924d545de90c3f15d98827535', '_collection_name': 'JohnWick', 'relevance_score': 0.9946774}, page_content=": 14\nReview: By now you know what to expect from a John Wick movie. I thought the franchise was losing a little momentum in chapter 3 so I was worried this could be disappointing. It's not. It's even more on steroids than any Wick before! Even close to 3 hours it d ...
# response[response] The John Wick franchise has set a standard for Hollywood action films by delivering expertly choreographed, shot, and edited action sequences that are considered examples of great action filmmaking. In terms of screenplay quality and use of CGI, the John Wick franchise is praised for having a strong screenplay and minimal use of CGI compared to other American action flicks. The franchise is seen as an exception to the trend of poor screenplays and overuse of computer-generated imagery in many American action movies.
# response {'response': AIMessage(content="The reviews reflect very positively on Keanu Reeves' portrayal in the John Wick franchise. They praise his performance in terms of action choreography and character depth. Reviewers highlight how Reeves brings a slickness and coolness to the character of John Wick, making the action sequences truly impressive and entertaining. Overall, Keanu Reeves' portrayal is highly regarded in the reviews provided.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 77, 'prompt_tokens': 1210, 'total_tokens': 1287, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-a94dee5a-1c81-4373-b095-c0a0f594c1e1-0', usage_metadata={'input_tokens': 1210, 'output_tokens': 77, 'total_tokens': 1287, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_1.csv', 'row': 14, 'Review_Date': '25 October 2014', 'Review_Title': " Yeah I'm Thinking He's Back\n", 'Review_Url': '/review/rw3111220/?ref_=tt_urv', 'Author': 'Palidan400', 'Rating': 8, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292345', '_id': '332d633c129c4bfe8cebc5b696a19000', '_collection_name': 'JohnWick', 'relevance_score': 0.9985104}, page_content=': 14\nReview: Keanu Reeve is John Wick. He\'s a deadly and unstoppable hit-man, and it shows. "John Wick" is short and to the point, but so much fun. At 1 hour and 36 minutes running time, there is never a dull moment in what may be one of the best action films of the year.'), Document(metadata={'source': 'john_wick_1.csv', 'row': 9, 'Review_Date': '20 October 2014', 'Review_Title': " The coolest action film you'll see all year\n", 'Review_Url': '/review/rw3107759/?ref_=tt_urv', 'Author': 'trublu215', 'Rating': 9, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292341', '_id': '2d6f65f3952a485588a13c19fdf9fdf0', '_collection_name': 'JohnWick', 'relevance_score': 0.998103}, page_content=": 9\nReview: At first glance, John Wick sounds like a terrible film on paper but with the slickness of Keanu Reeves' performance as the titular character and the sheer brilliance in its action sequences, this marks the best action film of the year and one of the absolute best in the past decade. Following a brutal home invasion that leaves his beloved dog murdered by thugs from his past, John Wick vows revenge on the ones who have taken what he loves most. Like I said, on paper, this seems like a direct-to-DVD slopfest starring John Cena but as a film with Keanu Reeves as the lead, it marks the very welcomed return for Reeves to the genre. John Wick is insanely fun, violently brutal and an overall romp especially for those disappointed by The Expendables 3. John Wick is propelled by Tarantino-esque dialog mixed with the swagger of action stars from the 70s. Reeves literally emulates cool in this film and does it with such confidence, that we don't even doubt the character...even when he kills countless bad guys with extreme force in some utterly ridiculous and implausible situations. We don't doubt it for a minute. This is EXACTLY what you want out of an action film. It is briskly paced, brilliantly shot and meticulously choreographed and keeps you wanting more and more. The supporting cast filled with the likes of John Legiuzamo, Ian McShane, and Willen Dafoe also keeps this film very interesting. These guys don't play good guys, hell, John Wick by traditional standards would be a bad guy in any other film. Every character is more ruthless than the next and pushes John Wick to be more ruthless than they are, creating a very cool dynamic between the character and the  ...
# response[response] The reviews reflect very positively on Keanu Reeves' portrayal in the John Wick franchise. They praise his performance in terms of action choreography and character depth. Reviewers highlight how Reeves brings a slickness and coolness to the character of John Wick, making the action sequences truly impressive and entertaining. Overall, Keanu Reeves' portrayal is highly regarded in the reviews provided.
# response {'response': AIMessage(content="Ian McShane is important in the John Wick movie because he plays the character Winston, the owner of the Continental hotel in New York City. McShane's character enforces the rules of the criminal underworld and adds depth to the plot by guiding John Wick and enforcing consequences for his actions. His presence in the film adds another layer of intrigue and complexity to the story, making it more interesting for viewers.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 83, 'prompt_tokens': 1641, 'total_tokens': 1724, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-77934143-7a7c-4319-a8cf-f3b6a3e4f669-0', usage_metadata={'input_tokens': 1641, 'output_tokens': 83, 'total_tokens': 1724, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_1.csv', 'row': 9, 'Review_Date': '20 October 2014', 'Review_Title': " The coolest action film you'll see all year\n", 'Review_Url': '/review/rw3107759/?ref_=tt_urv', 'Author': 'trublu215', 'Rating': 9, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292341', '_id': '2d6f65f3952a485588a13c19fdf9fdf0', '_collection_name': 'JohnWick', 'relevance_score': 0.87536144}, page_content=": 9\nReview: At first glance, John Wick sounds like a terrible film on paper but with the slickness of Keanu Reeves' performance as the titular character and the sheer brilliance in its action sequences, this marks the best action film of the year and one of the absolute best in the past decade. Following a brutal home invasion that leaves his beloved dog murdered by thugs from his past, John Wick vows revenge on the ones who have taken what he loves most. Like I said, on paper, this seems like a direct-to-DVD slopfest starring John Cena but as a film with Keanu Reeves as the lead, it marks the very welcomed return for Reeves to the genre. John Wick is insanely fun, violently brutal and an overall romp especially for those disappointed by The Expendables 3. John Wick is propelled by Tarantino-esque dialog mixed with the swagger of action stars from the 70s. Reeves literally emulates cool in this film and does it with such confidence, that we don't even doubt the character...even when he kills countless bad guys with extreme force in some utterly ridiculous and implausible situations. We don't doubt it for a minute. This is EXACTLY what you want out of an action film. It is briskly paced, brilliantly shot and meticulously choreographed and keeps you wanting more and more. The supporting cast filled with the likes of John Legiuzamo, Ian McShane, and Willen Dafoe also keeps this film very interesting. These guys don't play good guys, hell, John Wick by traditional standards would be a bad guy in any other film. Every character is more ruthless than the next and pushes John Wick to be more ruthless than they are, creating a very cool dynamic between the character and the plot regarding the idea of how far is too far? However, don't expect some revelation from John Wick regarding the morality of bad and evil. This film wants you entertained and does so with brute force, it never lets up, not even for a second. One scene in particular that will have your blood pumping is a showdown between thugs and Wick in a nightclub. This action sequence remains the best in the film and will have you grasping your theater seat because of the sheer intensity of it. Overall, John Wick is slick, violent fun that turns into a remarkable, surprising film that will catch you off guard. It is THAT good. I highly recommend this film to action buffs especially but I'm  ...
# response[response] Ian McShane is important in the John Wick movie because he plays the character Winston, the owner of the Continental hotel in New York City. McShane's character enforces the rules of the criminal underworld and adds depth to the plot by guiding John Wick and enforcing consequences for his actions. His presence in the film adds another layer of intrigue and complexity to the story, making it more interesting for viewers.
# Evaluating:   0%|          | 0/60 [00:00<?, ?it/s]
# contextual_compression_retrieval_chain 195.4534698750067

# %%
result_document_retriever = evaluate_one_chain(dataset, parent_document_retrieval_chain)
# Out:
# response {'response': AIMessage(content="I'm sorry, but I don't know who Liem Neeson is in the context of John Wick.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 330, 'total_tokens': 353, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-f3047296-29a6-4f97-935f-6a1f54fbf148-0', usage_metadata={'input_tokens': 330, 'output_tokens': 23, 'total_tokens': 353, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_1.csv', 'row': 0, 'Review_Date': '6 May 2015', 'Review_Title': ' Kinetic, concise, and stylish; John Wick kicks ass.\n', 'Review_Url': '/review/rw3233896/?ref_=tt_urv', 'Author': 'lnvicta', 'Rating': 8, 'Movie_Title': 'John Wick 1', 'last_accessed_at': datetime.datetime(2025, 2, 25, 11, 40, 31, 292319)}, page_content=": 0\nReview: The best way I can describe John Wick is to picture Taken but instead of Liam Neeson it's Keanu Reeves and instead of his daughter it's his dog. That's essentially the plot of the movie. John Wick (Reeves) is out to seek revenge on the people who took something he loved from him. It's a beautifully simple premise for an action movie - when action movies get convoluted, they get bad i.e. A Good Day to Die Hard. John Wick gives the viewers what they want: Awesome action, stylish stunts, kinetic chaos, and a relatable hero to tie it all together. John Wick succeeds in its simplicity.")]}
# response[response] I'm sorry, but I don't know who Liem Neeson is in the context of John Wick.
# response {'response': AIMessage(content='The reception of the John Wick franchise, particularly with the release of the fourth installment, seems to be very positive. Reviewers praise the action sequences, improvement from the previous installment, and the performances of Keanu Reeves and director Chad Stahelski. Overall, it appears that the reception is quite favorable based on the reviews provided.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 69, 'prompt_tokens': 807, 'total_tokens': 876, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-e720c8e2-e887-44f6-b723-11be6ef14c1f-0', usage_metadata={'input_tokens': 807, 'output_tokens': 69, 'total_tokens': 876, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_4.csv', 'row': 19, 'Review_Date': '17 March 2023', 'Review_Title': ' The Best John Wick Sequel\n', 'Review_Url': '/review/rw8935117/?ref_=tt_urv', 'Author': 'tkdlifemagazine', 'Rating': 9, 'Movie_Title': 'John Wick 4', 'last_accessed_at': datetime.datetime(2025, 2, 28, 11, 40, 31, 292930)}, page_content=": 19\nReview: John Wick: Chapter 4 picks up where Chapter 3: Parabellum left off. As has been the tradition in the sequels to this beloved martial arts action franchise the action starts from the very inception of the film's opening, and lasts until the curtain falls. JW4 is no exception to that rule. What it does do is improve on the prior installment, and solidify Keanu Reeves as the greatest martial arts action star of all time. If you don't accept that notion, then you must accept the fact that it solidifies Reeves and Director, Chad Stahelski, as the greatest martial arts action pairing of modern times."), Document(metadata={'source': 'john_wick_4.csv', 'row': 17, 'Review_Date': '16 March 2023', 'Review_Title': ' While the Wick franchise has already solidified itself one of the best in the action genre, this massive film is the most spectacular entry of the genre in 30 years.\n', 'Review_Url': '/review/rw8932278/?ref_=tt_urv', 'Author': 'tresm87', 'Rating': 9, 'Movie_Title': 'John Wick 4', 'last_accessed_at': datetime.datetime(2025, 2, 28, 11, 40, 31, 292928)}, page_content=": 17\nReview: Stuntman turned writer/director Chad Stahelski struck gold with his 2014 surprise hit John Wick. It was somewhat of a comeback for the legendary Keanu Reeves and reinvigorated the action genre. Since then it's become THE action juggernaut franchise. Now we are on number 4 and while usually things get redone with that amount of sequels, this film innovates and thrills to new heights in an absolute epic."), Document(metadata={'source': 'john_wick_4.csv', 'row': 20, 'Review_Date': '23 March 2023', 'Review_Title': ' THIS is how you justify a 3 hour runtime\n', 'Review_Url': '/review/rw8946038/?ref_=tt_urv', 'Author': 'jtindahouse', 'Rating': 9, 'Movie_Title': 'John Wick 4', 'last_accessed_at': datetime.datetime(2025, 2, 28, 11, 40, 31, 292931)}, page_content=": 20\nReview: In a world where movie sequels seem to be loathed even before they are released, the 'John Wick' series has remained remarkably consistent and well received. In fact all three of the first films have the same IMDb rating of 7.4/10 and I noticed recently that I gave them all the same rating of 8/10. Incredibly, I think 'John Wick: Chapter 4' is the best the series has to offer. This movie was a wild ride.")]}
# response[response] The reception of the John Wick franchise, particularly with the release of the fourth installment, seems to be very positive. Reviewers praise the action sequences, improvement from the previous installment, and the performances of Keanu Reeves and director Chad Stahelski. Overall, it appears that the reception is quite favorable based on the reviews provided.
# response {'response': AIMessage(content="Chad Stahelski's direction in the John Wick films contributes to their uniqueness by showcasing expertly choreographed, shot, and edited action sequences. Stahelski's background as a stunt specialist allows him to create intricate and visually stunning fight scenes that stand out from other action movies. The absence of quick-cuts or shaky camera work in his direction also allows audiences to fully appreciate the action on screen.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 84, 'prompt_tokens': 589, 'total_tokens': 673, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-5357f67e-2a73-4c66-9b8d-aaa2fe1b399e-0', usage_metadata={'input_tokens': 589, 'output_tokens': 84, 'total_tokens': 673, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_4.csv', 'row': 18, 'Review_Date': '17 March 2023', 'Review_Title': ' Not Just The Best John Wick, But Possibly One Of The Best Action Movies Ever\n', 'Review_Url': '/review/rw8935367/?ref_=tt_urv', 'Author': 'cadillac20', 'Rating': 10, 'Movie_Title': 'John Wick 4', 'last_accessed_at': datetime.datetime(2025, 2, 28, 11, 40, 31, 292929)}, page_content=": 18\nReview: Ever since the original John Wick, the franchise has set a standard of what action in Hollywood should be. Thanks to Chad Stahelski and Keanu Reeve's knowledge of the technical aspects of shooting action, they've been able to deliver expertly choreographed, shot, and edited action films that are now the go to as examples of great action filmmaking. And so, the expectations for the fourth film were fairly high, especially as it became more apparent this was not only the culmination of everything before it, but a whopping 169 minutes long. Rest assured, however, that it delivers in spades. Everything we have come to know and love is here, but with an infusion of creativity like we haven't seen from the franchise yet."), Document(metadata={'source': 'john_wick_1.csv', 'row': 3, 'Review_Date': '28 September 2018', 'Review_Title': ' Keanu gets pissed and shoots people in the face for 101 minutes*\n', 'Review_Url': '/review/rw4366368/?ref_=tt_urv', 'Author': 'Kitsfi', 'Rating': 8, 'Movie_Title': 'John Wick 1', 'last_accessed_at': datetime.datetime(2025, 2, 25, 11, 40, 31, 292336)}, page_content=': 3\nReview: John wick has a very simple revenge story. It can be summarized as "Keanu gets angry and shoots bad guys" but what makes it special? Directed by Chad Stahelski who\'s a stunt specialist boy does it show because the main selling point in the film are some real virtuoso action sequences, well made choreographies. Unlike today\'s action movies, it doesn\'t use quick-cuts or shaky cameras actually see what\'s going on.')]}
# response[response] Chad Stahelski's direction in the John Wick films contributes to their uniqueness by showcasing expertly choreographed, shot, and edited action sequences. Stahelski's background as a stunt specialist allows him to create intricate and visually stunning fight scenes that stand out from other action movies. The absence of quick-cuts or shaky camera work in his direction also allows audiences to fully appreciate the action on screen.
# response {'response': AIMessage(content='John Wick goes after Russian mobsters because they killed his dog, destroyed his belongings, and stole his car. This act of aggression led John Wick, who is a super-assassin, to seek revenge on the Russian mobster and his gang who were behind the attack.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 55, 'prompt_tokens': 698, 'total_tokens': 753, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-e64d92c5-5809-4d00-ad76-18e8cdb7d481-0', usage_metadata={'input_tokens': 698, 'output_tokens': 55, 'total_tokens': 753, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_2.csv', 'row': 20, 'Review_Date': '28 May 2017', 'Review_Title': ' A New Franchise is Born\n', 'Review_Url': '/review/rw3718180/?ref_=tt_urv', 'Author': 'claudio_carvalho', 'Rating': 8, 'Movie_Title': 'John Wick 2', 'last_accessed_at': datetime.datetime(2025, 2, 26, 11, 40, 31, 292549)}, page_content=": 20\nReview: After resolving his issues with the Russian mafia, John Wick (Keanu Reeves) returns home. But soon the mobster Santino D'Antonio (Riccardo Scamarcio) visits him to show Wick's marker and tells that he needs to help. John Wicks refuses since he is retired and Santino blows-up his house. John Wick meets the owner of the Continental hotel in New York City, Winston (Ian McShane), and he tells that Wick cannot violate the Mafia rules and shall honor the marker. Santino asks John Wick to kill his sister Gianna D'Antonio (Claudia Gerini) in Rome so that he can sit on the High Table of the criminal organizations. When John Wicks accomplishes his assignment, Santino puts a seven-million dollar contract on him attracting professional killers from everywhere. But Wick promises to kill Santino that is not protected by his marker anymore."), Document(metadata={'source': 'john_wick_1.csv', 'row': 18, 'Review_Date': '10 September 2019', 'Review_Title': ' Probably NOT a film to watch with your kids or mother.\n', 'Review_Url': '/review/rw5112990/?ref_=tt_urv', 'Author': 'planktonrules', 'Rating': 7, 'Movie_Title': 'John Wick 1', 'last_accessed_at': datetime.datetime(2025, 2, 25, 11, 40, 31, 292348)}, page_content=": 18\nReview: When the story begins, John (Keanu Reeves) has just lost his wife. After her death, he's a bit lost but tries to rebuild his life. One day, he's getting gas and a young Russian-American punk notices Wick's classic car...and tries to buy it off him. But Wick isn't interested and declines. Soon, the punk arrives at Wick's home with some goons where they surprise him--beating him senseless, destroying his stuff, killing his dog and stealing his car! This is when you then learn that Wick is a super-assassin....and the punk chose the wrong guy to attack. The jerk's father is a big-time Russian mobster....and it's a contest to see who will win...the mobster and his gang or Wick on his own. Considering there are (so far) two MORE John Wick films, it pretty much seems certain who will win this battle.")]}
# response[response] John Wick goes after Russian mobsters because they killed his dog, destroyed his belongings, and stole his car. This act of aggression led John Wick, who is a super-assassin, to seek revenge on the Russian mobster and his gang who were behind the attack.
# response {'response': AIMessage(content='In the first John Wick movie, he is mad because gangsters killed his dog and took everything from him, including the untimely death of his beloved wife still fresh in his mind. This drives him to seek vengeance and unleash a maelstrom of destruction against those who wronged him.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 60, 'prompt_tokens': 717, 'total_tokens': 777, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-119429c2-a259-4dfb-84a3-5312cf0c5d55-0', usage_metadata={'input_tokens': 717, 'output_tokens': 60, 'total_tokens': 777, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_1.csv', 'row': 5, 'Review_Date': '23 March 2023', 'Review_Title': ' Violent and gripping story with plenty of unstopped action , shootouts and breathtaking fights\n', 'Review_Url': '/review/rw8945545/?ref_=tt_urv', 'Author': 'ma-cortes', 'Rating': 7, 'Movie_Title': 'John Wick 1', 'last_accessed_at': datetime.datetime(2025, 2, 25, 11, 40, 31, 292338)}, page_content=": 5\nReview: Ultra-violent first entry with lots of killings, thrills , noisy action , suspense , and crossfire . In this original John Wick (2014) , an ex-hit-man comes out of retirement to track down the gangsters that killed his dog and took everything from him . With the untimely death of his beloved wife still bitter in his mouth he seeks for vengeance . But when an arrogant Russian mob prince and hoodlums steal his car and kill his dog , they are fully aware of his lethal capacity. The Bogeyman will find himself dragged into an impossible task as every killer in the business dreams of cornering the legendary Wick who now has an enormous price on his head . In this first installment John Wick , blind with revenge, and for his salvation John will immediately unleash a carefully orchestrated maelstrom of destruction against those attempt to chase him and with a price tag on his head, as he is the target of hit men : an army of bounty-hunting killers on his trail and a murderer woman everywhere . The legendary hitman will be forced to unearth his meticulously concealed identity and to carry out a relentless vendetta . Now, only blood can quench the boogeyman's thirst for retribution . Don't Set Him Off! . John Wick isn't the Boogeyman... He's the guy you send to kill the doomed Boogeyman. Revenge is all he has left. You want peace, prepare for war . Don't Hunt What You Can't Kill. Tick Tock, Mr. Wick. Everyone Is Waiting. For John Wick . Every Action Has Consequences. This Friday, Wick is Back . Its the World Vs. Wick. Every Action Has Consequences."), Document(metadata={'source': 'john_wick_2.csv', 'row': 17, 'Review_Date': '18 March 2018', 'Review_Title': ' Even worse than the first movie\n', 'Review_Url': '/review/rw4095490/?ref_=tt_urv', 'Author': 'grantss', 'Rating': 2, 'Movie_Title': 'John Wick 2', 'last_accessed_at': datetime.datetime(2025, 2, 26, 11, 40, 31, 292547)}, page_content=': 17\nReview: Picking up where the first movie left off, John Wick still wants his car back. Also, he now discovers that there is a bounty on his head. Rejoining his former profession, he heads to Rome to complete an assassination assignment.')]}
# response[response] In the first John Wick movie, he is mad because gangsters killed his dog and took everything from him, including the untimely death of his beloved wife still fresh in his mind. This drives him to seek vengeance and unleash a maelstrom of destruction against those who wronged him.
# response {'response': AIMessage(content="'John Wick: Chapter 2' stands out among American action films as it is praised for its sharp and well-filmed action sequences without shaky cams or jump cuts. This makes it refreshing and allows viewers to admire the practical stunt work in the film.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 53, 'prompt_tokens': 1005, 'total_tokens': 1058, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-e8f187c8-aa25-4d02-aa6b-155ec9bc798b-0', usage_metadata={'input_tokens': 1005, 'output_tokens': 53, 'total_tokens': 1058, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_2.csv', 'row': 2, 'Review_Date': '14 February 2017', 'Review_Title': ' Professional Courtesy\n', 'Review_Url': '/review/rw3640053/?ref_=tt_urv', 'Author': 'ThomasDrufke', 'Rating': 8, 'Movie_Title': 'John Wick 2', 'last_accessed_at': datetime.datetime(2025, 2, 26, 11, 40, 31, 292535)}, page_content=": 2\nReview: A film with more head-shots than words spoken, John Wick: Chapter 2 is just about the most violent film I've seen in quite some time. But it knows exactly what it wants to do, and succeeds immensely."), Document(metadata={'source': 'john_wick_2.csv', 'row': 0, 'Review_Date': '14 September 2018', 'Review_Title': ' "No one gets out and comes back without repercussions."\n', 'Review_Url': '/review/rw4338449/?ref_=tt_urv', 'Author': 'classicsoncall', 'Rating': 7, 'Movie_Title': 'John Wick 2', 'last_accessed_at': datetime.datetime(2025, 2, 26, 11, 40, 31, 292533)}, page_content=': 0\nReview: No doubt about it, "John Wick: Chapter 2" is a slick action thriller, but man, oh man, how can any one person absorb that kind of punishment? John (Keanu Reeves) gets shot, stabbed and hit by cars multiple times and postures a limp now and then to indicate he might have gotten just a little bit hurt. Besides that, he almost never makes a wrong move when hunted by dozens of assassins all at the same time. Okay, I get it, Reeves is the star of the picture and has to come out on top, but I\'d like a little more credibility put into these kinds of stories. But I guess that\'s the whole point, suspend your disbelief for a couple of hours and just go with all of the over the top action the film makers can put together.'), Document(metadata={'source': 'john_wick_2.csv', 'row': 22, 'Review_Date': '12 February 2017', 'Review_Title': ' This is how you film an action movie !\n', 'Review_Url': '/review/rw3638970/?ref_=tt_urv', 'Author': 'destroyerwod', 'Rating': 9, 'Movie_Title': 'John Wick 2', 'last_accessed_at': datetime.datetime(2025, 2, 26, 11, 40, 31, 292551)}, page_content=': 22\nReview: John Wick is one of my favourite recent years action movie and the second one pick up right where the first one left. The action is sharp, well filmed, no bad shaky cams and jump cuts like a certain bad action movie i saw recently. Its so refreshing to see everything and admire the practical stunt work.'), Document(metadata={'source': 'john_wick_2.csv', 'row': 8, 'Review_Date': '23 February 2020', 'Review_Title': ' Great\n', 'Review_Url': '/review/rw5503709/?ref_=tt_urv', 'Author': 'MrHeraclius', 'Rating': 0, 'Movie_Title': 'John Wick 2', 'last_accessed_at': datetime.datetime(2025, 2, 26, 11, 40, 31, 292540)}, page_content=": 8\nReview: In this 2nd installment of John Wick, the stylish visual and hard core action returns twice the level of the first film. So prepare for another suspenseful and cliffhanging sequences flow from this action movie when you watch this. The story goes deeper and the action scenes were incredibly entertaining!  ...
# response[response] 'John Wick: Chapter 2' stands out among American action films as it is praised for its sharp and well-filmed action sequences without shaky cams or jump cuts. This makes it refreshing and allows viewers to admire the practical stunt work in the film.
# response {'response': AIMessage(content='According to the review by tkdlifemagazine, John Wick: Chapter 4 improves upon John Wick: Chapter 3 - Parabellum by solidifying Keanu Reeves as the greatest martial arts action star of all time and solidifying Reeves and Director, Chad Stahelski, as the greatest martial arts action pairing of modern times.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 73, 'prompt_tokens': 965, 'total_tokens': 1038, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-a56f151d-db60-4dab-aa9c-9c20c323ab77-0', usage_metadata={'input_tokens': 965, 'output_tokens': 73, 'total_tokens': 1038, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_4.csv', 'row': 19, 'Review_Date': '17 March 2023', 'Review_Title': ' The Best John Wick Sequel\n', 'Review_Url': '/review/rw8935117/?ref_=tt_urv', 'Author': 'tkdlifemagazine', 'Rating': 9, 'Movie_Title': 'John Wick 4', 'last_accessed_at': datetime.datetime(2025, 2, 28, 11, 40, 31, 292930)}, page_content=": 19\nReview: John Wick: Chapter 4 picks up where Chapter 3: Parabellum left off. As has been the tradition in the sequels to this beloved martial arts action franchise the action starts from the very inception of the film's opening, and lasts until the curtain falls. JW4 is no exception to that rule. What it does do is improve on the prior installment, and solidify Keanu Reeves as the greatest martial arts action star of all time. If you don't accept that notion, then you must accept the fact that it solidifies Reeves and Director, Chad Stahelski, as the greatest martial arts action pairing of modern times."), Document(metadata={'source': 'john_wick_3.csv', 'row': 24, 'Review_Date': '17 May 2019', 'Review_Title': ' Makes John Wick a superb trilogy\n', 'Review_Url': '/review/rw4860603/?ref_=tt_urv', 'Author': 'masonsaul', 'Rating': 10, 'Movie_Title': 'John Wick 3', 'last_accessed_at': datetime.datetime(2025, 2, 27, 11, 40, 31, 292750)}, page_content=": 24\nReview: John Wick: Chapter 3 - Parabellum is quite literally about consequences, dealing with the fallout of John's actions at the end of the previous film and sending him on an even bigger odyssey of violence that continues to explore this world of assassination and deliver beautifully clean action sequences."), Document(metadata={'source': 'john_wick_3.csv', 'row': 13, 'Review_Date': '15 May 2019', 'Review_Title': ' Pure, delirious joy in the form of yet another exhilarating thriller\n', 'Review_Url': '/review/rw4855261/?ref_=tt_urv', 'Author': 'themadmovieman', 'Rating': 8, 'Movie_Title': 'John Wick 3', 'last_accessed_at': datetime.datetime(2025, 2, 27, 11, 40, 31, 292740)}, page_content=": 13\nReview: Following on from two deliriously entertaining, visually gorgeous and blissfully simplistic thrillers, John Wick: Chapter 3 - Parabellum keeps up the franchise's unique appeal in stunning fashion. Complete with electrifying action, beautiful cinematography, a pulsating score and a great sense of humour, the film is pretty much as purely joyful as action thrillers get, and proves two hours of brilliant entertainment."), Document(metadata={'source': 'john_wick_4.csv', 'row': 24, 'Review_Date': '3 June 2023', 'Review_Title': ' Almost 3 hours of nothing\n', 'Review_Url': '/review/rw9097584/?ref_=tt_urv', 'Author': 'Phil_H', 'Rating': 4, 'Movie_Title': 'John Wick 4', 'last_accessed_at': datetime.datetime(2025, 2, 28, 11, 40, 31, 292934)}, page_content=': 24\nReview: John Wick: Chapter 4 is almost three hours of Keanu Reeves engaged in a gunfight, bookended with meaningless dialog-in-place-of-plot, and a ...
# response[response] According to the review by tkdlifemagazine, John Wick: Chapter 4 improves upon John Wick: Chapter 3 - Parabellum by solidifying Keanu Reeves as the greatest martial arts action star of all time and solidifying Reeves and Director, Chad Stahelski, as the greatest martial arts action pairing of modern times.
# response {'response': AIMessage(content="The John Wick franchise has set a standard for Hollywood action films by delivering expertly choreographed, shot, and edited action sequences. The use of practical effects and Keanu Reeves' knowledge of technical aspects have contributed to the success of the franchise. In terms of screenplay quality, John Wick movies are known for their revenge-driven plots with strong character development. As for the use of CGI, the franchise tends to rely more on practical effects and stunts rather than heavy CGI, which sets it apart from some other American action films that heavily use computer-generated imagery. Overall, John Wick movies have been praised for their action sequences, screenplay quality, and practical effects.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 133, 'prompt_tokens': 371, 'total_tokens': 504, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-58a5d486-f599-4030-b857-f268fce08244-0', usage_metadata={'input_tokens': 371, 'output_tokens': 133, 'total_tokens': 504, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_4.csv', 'row': 18, 'Review_Date': '17 March 2023', 'Review_Title': ' Not Just The Best John Wick, But Possibly One Of The Best Action Movies Ever\n', 'Review_Url': '/review/rw8935367/?ref_=tt_urv', 'Author': 'cadillac20', 'Rating': 10, 'Movie_Title': 'John Wick 4', 'last_accessed_at': datetime.datetime(2025, 2, 28, 11, 40, 31, 292929)}, page_content=": 18\nReview: Ever since the original John Wick, the franchise has set a standard of what action in Hollywood should be. Thanks to Chad Stahelski and Keanu Reeve's knowledge of the technical aspects of shooting action, they've been able to deliver expertly choreographed, shot, and edited action films that are now the go to as examples of great action filmmaking. And so, the expectations for the fourth film were fairly high, especially as it became more apparent this was not only the culmination of everything before it, but a whopping 169 minutes long. Rest assured, however, that it delivers in spades. Everything we have come to know and love is here, but with an infusion of creativity like we haven't seen from the franchise yet.")]}
# response[response] The John Wick franchise has set a standard for Hollywood action films by delivering expertly choreographed, shot, and edited action sequences. The use of practical effects and Keanu Reeves' knowledge of technical aspects have contributed to the success of the franchise. In terms of screenplay quality, John Wick movies are known for their revenge-driven plots with strong character development. As for the use of CGI, the franchise tends to rely more on practical effects and stunts rather than heavy CGI, which sets it apart from some other American action films that heavily use computer-generated imagery. Overall, John Wick movies have been praised for their action sequences, screenplay quality, and practical effects.
# response {'response': AIMessage(content="Based on the reviews provided, Keanu Reeves' portrayal in the John Wick franchise, especially in terms of action choreography and character depth, is highly praised. Reviewers mention that the action is beautifully choreographed, with excellent fighting scenes and cool gun shooting scenes. Keanu Reeves' acting performance as John Wick is also highlighted as excellent. Overall, the reviews reflect positively on Keanu Reeves' portrayal in the John Wick franchise in terms of action choreography and character depth.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 99, 'prompt_tokens': 824, 'total_tokens': 923, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-d2c44af5-f601-4ed2-aa49-202132326e17-0', usage_metadata={'input_tokens': 824, 'output_tokens': 99, 'total_tokens': 923, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_1.csv', 'row': 8, 'Review_Date': '23 February 2020', 'Review_Title': ' love this movie highly recommend\n', 'Review_Url': '/review/rw5503708/?ref_=tt_urv', 'Author': 'MrHeraclius', 'Rating': 0, 'Movie_Title': 'John Wick 1', 'last_accessed_at': datetime.datetime(2025, 2, 25, 11, 40, 31, 292340)}, page_content=": 8\nReview: It's hard to find anything bad to say about John Wick. The action is beautifully choreographed, the setup is surprisingly emotional for an action flick, and Keanu.... What more is there to say? If you love action or even just like it you will be in for the ride of your life."), Document(metadata={'source': 'john_wick_3.csv', 'row': 23, 'Review_Date': '15 May 2019', 'Review_Title': ' A Masterpiece & Brilliant Sequel\n', 'Review_Url': '/review/rw4854296/?ref_=tt_urv', 'Author': 'ymyuseda', 'Rating': 10, 'Movie_Title': 'John Wick 3', 'last_accessed_at': datetime.datetime(2025, 2, 27, 11, 40, 31, 292750)}, page_content=": 23\nReview: Rating 10/10\nI was able to catch an advanced screening of this movie on 13th of may 2019. One words i can say here is 'amazing' yes ... this movie so amazing !! One of the best action movie i ever seen. All the fighting scenes were choreographed wonderfully according to my opinion. Excellent acting performance by Keanu Reeves a.k.a John Wick. The guns shooting scenes were entirely cool. I would recommend this movie to any fans of action movie. You won't find a better movie of this type in the theatre right now and for the fans out there who appreciate this material, it will provide a memorable experience. Go see it you wont regret it."), Document(metadata={'source': 'john_wick_4.csv', 'row': 18, 'Review_Date': '17 March 2023', 'Review_Title': ' Not Just The Best John Wick, But Possibly One Of The Best Action Movies Ever\n', 'Review_Url': '/review/rw8935367/?ref_=tt_urv', 'Author': 'cadillac20', 'Rating': 10, 'Movie_Title': 'John Wick 4', 'last_accessed_at': datetime.datetime(2025, 2, 28, 11, 40, 31, 292929)}, page_content=": 18\nReview: Ever since the original John Wick, the franchise has set a standard of what action in Hollywood should be. Thanks to Chad Stahelski and Keanu Reeve's knowledge of the technical aspects of shooting action, they've been able to deliver expertly choreographed, shot, and edited action films that are now the go to as examples of great action filmmaking. And so, the expectations for the fourth film were fairly high, especially as it became more apparent this was not only the culmination of everything before it, but a whopping 169 minutes long. Rest assured, however, that it delivers in spades. Everything we have come to know and love is here, but with an infusion of creativity ...
# response[response] Based on the reviews provided, Keanu Reeves' portrayal in the John Wick franchise, especially in terms of action choreography and character depth, is highly praised. Reviewers mention that the action is beautifully choreographed, with excellent fighting scenes and cool gun shooting scenes. Keanu Reeves' acting performance as John Wick is also highlighted as excellent. Overall, the reviews reflect positively on Keanu Reeves' portrayal in the John Wick franchise in terms of action choreography and character depth.
# response {'response': AIMessage(content="Ian McShane is important in the John Wick movie because he is part of the supporting cast that helps make the film very interesting. His portrayal of his character adds depth and complexity to the storyline, creating a cool dynamic between the characters and the plot. McShane's presence, alongside other talented actors like John Leguizamo and Willem Dafoe, contributes to the overall appeal of the film and keeps the audience engaged. His performance and interactions with the main character, John Wick, play a significant role in making the movie more entertaining and engaging for the viewers.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 117, 'prompt_tokens': 706, 'total_tokens': 823, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-036d04e4-a35d-40e3-bba9-df4ae6efd985-0', usage_metadata={'input_tokens': 706, 'output_tokens': 117, 'total_tokens': 823, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_1.csv', 'row': 9, 'Review_Date': '20 October 2014', 'Review_Title': " The coolest action film you'll see all year\n", 'Review_Url': '/review/rw3107759/?ref_=tt_urv', 'Author': 'trublu215', 'Rating': 9, 'Movie_Title': 'John Wick 1', 'last_accessed_at': datetime.datetime(2025, 2, 25, 11, 40, 31, 292341)}, page_content=": 9\nReview: At first glance, John Wick sounds like a terrible film on paper but with the slickness of Keanu Reeves' performance as the titular character and the sheer brilliance in its action sequences, this marks the best action film of the year and one of the absolute best in the past decade. Following a brutal home invasion that leaves his beloved dog murdered by thugs from his past, John Wick vows revenge on the ones who have taken what he loves most. Like I said, on paper, this seems like a direct-to-DVD slopfest starring John Cena but as a film with Keanu Reeves as the lead, it marks the very welcomed return for Reeves to the genre. John Wick is insanely fun, violently brutal and an overall romp especially for those disappointed by The Expendables 3. John Wick is propelled by Tarantino-esque dialog mixed with the swagger of action stars from the 70s. Reeves literally emulates cool in this film and does it with such confidence, that we don't even doubt the character...even when he kills countless bad guys with extreme force in some utterly ridiculous and implausible situations. We don't doubt it for a minute. This is EXACTLY what you want out of an action film. It is briskly paced, brilliantly shot and meticulously choreographed and keeps you wanting more and more. The supporting cast filled with the likes of John Legiuzamo, Ian McShane, and Willen Dafoe also keeps this film very interesting. These guys don't play good guys, hell, John Wick by traditional standards would be a bad guy in any other film. Every character is more ruthless than the next and pushes John Wick to be more ruthless than they are, creating a very cool dynamic between the character and the plot regarding the idea of how far is too far? However, don't expect some revelation from John Wick regarding the morality of bad and evil. This film wants you entertained and does so with brute force, it never lets up, not even for a second. One scene in particular that will have your blood pumping is a showdown between thugs and Wick in a nightclub. This action sequence remains the best in the film and will have you grasping your theater seat because of the sheer intensity of it. Overall, John Wick is slick, violent fun that turns into a remarkable, surprising film that will catch you off  ...
# response[response] Ian McShane is important in the John Wick movie because he is part of the supporting cast that helps make the film very interesting. His portrayal of his character adds depth and complexity to the storyline, creating a cool dynamic between the characters and the plot. McShane's presence, alongside other talented actors like John Leguizamo and Willem Dafoe, contributes to the overall appeal of the film and keeps the audience engaged. His performance and interactions with the main character, John Wick, play a significant role in making the movie more entertaining and engaging for the viewers.
# Evaluating:   0%|          | 0/60 [00:00<?, ?it/s]
# parent_document_retrieval_chain 172.69446754199453

# %%
result_ensemble_retrieval = evaluate_one_chain(dataset, ensemble_retrieval_chain)
# Out:
# response {'response': AIMessage(content="Liem Neeson is a prominent actor known for films like Taken. In the context of John Wick, Liam Neeson is referenced as the actor who plays the lead character in the film Taken, draw a comparison to Keanu Reeves' character in John Wick.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 54, 'prompt_tokens': 5867, 'total_tokens': 5921, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-bf9be13b-6610-4705-98bf-064d7740b1a4-0', usage_metadata={'input_tokens': 5867, 'output_tokens': 54, 'total_tokens': 5921, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_1.csv', 'row': 0, 'Review_Date': '6 May 2015', 'Review_Title': ' Kinetic, concise, and stylish; John Wick kicks ass.\n', 'Review_Url': '/review/rw3233896/?ref_=tt_urv', 'Author': 'lnvicta', 'Rating': 8, 'Movie_Title': 'John Wick 1', 'last_accessed_at': datetime.datetime(2025, 2, 25, 11, 40, 31, 292319)}, page_content=": 0\nReview: The best way I can describe John Wick is to picture Taken but instead of Liam Neeson it's Keanu Reeves and instead of his daughter it's his dog. That's essentially the plot of the movie. John Wick (Reeves) is out to seek revenge on the people who took something he loved from him. It's a beautifully simple premise for an action movie - when action movies get convoluted, they get bad i.e. A Good Day to Die Hard. John Wick gives the viewers what they want: Awesome action, stylish stunts, kinetic chaos, and a relatable hero to tie it all together. John Wick succeeds in its simplicity."), Document(metadata={'source': 'john_wick_1.csv', 'row': 11, 'Review_Date': '25 September 2015', 'Review_Title': ' Action as it should be\n', 'Review_Url': '/review/rw3323198/?ref_=tt_urv', 'Author': 'Leofwine_draca', 'Rating': 8, 'Movie_Title': 'John Wick 1', 'last_accessed_at': datetime.datetime(2025, 2, 25, 11, 40, 31, 292343)}, page_content=": 11\nReview: JOHN WICK is a rare example of Hollywood getting things spot-on when it comes to creating the near-perfect action film. JOHN WICK is a relentless, pulse-pounding thriller that has plenty of similarity to the Liam Neeson classic TAKEN, albeit with a more simplistic (and also more emotionally intense) plot line. This is the kind of lean, pared-down film-making that's all about intensity and momentum. It sits well with classic international fare like POINT BLANK, SLEEPLESS NIGHT, MEA CULPA, THE MAN FROM NOWHERE, and THE RAID films."), Document(metadata={'source': 'john_wick_2.csv', 'row': 19, 'Review_Date': '29 November 2020', 'Review_Title': ' John Wick Kills A Lot Of People\n', 'Review_Url': '/review/rw6320115/?ref_=tt_urv', 'Author': 'boblipton', 'Rating': 5, 'Movie_Title': 'John Wick 2', 'last_accessed_at': '2025-02-26T11:40:31.292549', '_id': 'c6a990d6fb27499096a867702c0bdfaf', '_collection_name': 'JohnWick'}, page_content=": 19\nReview: If you've seen the first John Wick movie, you know that Keanu Reeves is John Wick, a retired assassin who comes out of retirement when someone kills his dog. In this one, which begins a week later, matters are still reverberating, and some one has stolen his car, which calls for a lot of carnage. That settled, John is called on to pay off an old debt by helping Ian McShane take over the Assassin's Guild by flying around to Italy, Canada and Manhattan and killing what seems like hundreds of assassins."), Document(metadata={'source': 'john_wick_1.csv', 'row': 18, 'Review_Date': '10 September 2019', 'Review_Title': ' Probably NOT a film to watch with your kids or mother.\n', 'Review_Url': '/review/rw5112990/?ref_=tt_urv', 'Autho ...
# response[response] Liem Neeson is a prominent actor known for films like Taken. In the context of John Wick, Liam Neeson is referenced as the actor who plays the lead character in the film Taken, draw a comparison to Keanu Reeves' character in John Wick.
# response {'response': AIMessage(content='The reception of the John Wick franchise, particularly with the release of the fourth installment, seems to be overwhelmingly positive. Reviews for "John Wick 4" highlight it as one of the best in the series, praising Keanu Reeves and Director Chad Stahelski for their outstanding work in martial arts action. Critics have noted the improvement in this installment compared to the previous ones, solidifying its place as a top-tier action film. Overall, the reception appears to be very favorable, with viewers enjoying the film\'s creativity and thrilling action sequences.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 111, 'prompt_tokens': 5458, 'total_tokens': 5569, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-13fdaf3a-cde8-41b5-8084-419b27d6108a-0', usage_metadata={'input_tokens': 5458, 'output_tokens': 111, 'total_tokens': 5569, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_4.csv', 'row': 19, 'Review_Date': '17 March 2023', 'Review_Title': ' The Best John Wick Sequel\n', 'Review_Url': '/review/rw8935117/?ref_=tt_urv', 'Author': 'tkdlifemagazine', 'Rating': 9, 'Movie_Title': 'John Wick 4', 'last_accessed_at': datetime.datetime(2025, 2, 28, 11, 40, 31, 292930)}, page_content=": 19\nReview: John Wick: Chapter 4 picks up where Chapter 3: Parabellum left off. As has been the tradition in the sequels to this beloved martial arts action franchise the action starts from the very inception of the film's opening, and lasts until the curtain falls. JW4 is no exception to that rule. What it does do is improve on the prior installment, and solidify Keanu Reeves as the greatest martial arts action star of all time. If you don't accept that notion, then you must accept the fact that it solidifies Reeves and Director, Chad Stahelski, as the greatest martial arts action pairing of modern times."), Document(metadata={'source': 'john_wick_4.csv', 'row': 18, 'Review_Date': '17 March 2023', 'Review_Title': ' Not Just The Best John Wick, But Possibly One Of The Best Action Movies Ever\n', 'Review_Url': '/review/rw8935367/?ref_=tt_urv', 'Author': 'cadillac20', 'Rating': 10, 'Movie_Title': 'John Wick 4', 'last_accessed_at': datetime.datetime(2025, 2, 28, 11, 40, 31, 292929)}, page_content=": 18\nReview: Ever since the original John Wick, the franchise has set a standard of what action in Hollywood should be. Thanks to Chad Stahelski and Keanu Reeve's knowledge of the technical aspects of shooting action, they've been able to deliver expertly choreographed, shot, and edited action films that are now the go to as examples of great action filmmaking. And so, the expectations for the fourth film were fairly high, especially as it became more apparent this was not only the culmination of everything before it, but a whopping 169 minutes long. Rest assured, however, that it delivers in spades. Everything we have come to know and love is here, but with an infusion of creativity like we haven't seen from the franchise yet."), Document(metadata={'source': 'john_wick_4.csv', 'row': 20, 'Review_Date': '23 March 2023', 'Review_Title': ' THIS is how you justify a 3 hour runtime\n', 'Review_Url': '/review/rw8946038/?ref_=tt_urv', 'Author': 'jtindahouse', 'Rating': 9, 'Movie_Title': 'John Wick 4', 'last_accessed_at': '2025-02-28T11:40:31.292931', '_id': '2b2772db123f4ba4bff10cc8c5e610a2', '_collection_name': 'JohnWick'}, page_content=": 20\nReview: In a world where movie sequels seem to be loathed even before they are released, the 'John Wick' series has remained remarkably consistent and well  ...
# response[response] The reception of the John Wick franchise, particularly with the release of the fourth installment, seems to be overwhelmingly positive. Reviews for "John Wick 4" highlight it as one of the best in the series, praising Keanu Reeves and Director Chad Stahelski for their outstanding work in martial arts action. Critics have noted the improvement in this installment compared to the previous ones, solidifying its place as a top-tier action film. Overall, the reception appears to be very favorable, with viewers enjoying the film's creativity and thrilling action sequences.
# response {'response': AIMessage(content="Chad Stahelski's direction contributes to the uniqueness of the John Wick film by showcasing real virtuoso action sequences with well-made choreographies. Unlike some modern action movies, Stahelski avoids quick-cuts or shaky cameras, allowing the audience to clearly see what's happening in the action sequences. This attention to detail and skillful execution of action sets the John Wick film apart and adds to its distinctiveness.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 87, 'prompt_tokens': 5063, 'total_tokens': 5150, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-41afa492-ffaf-41ee-bf64-0d3b03ad270e-0', usage_metadata={'input_tokens': 5063, 'output_tokens': 87, 'total_tokens': 5150, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_1.csv', 'row': 3, 'Review_Date': '28 September 2018', 'Review_Title': ' Keanu gets pissed and shoots people in the face for 101 minutes*\n', 'Review_Url': '/review/rw4366368/?ref_=tt_urv', 'Author': 'Kitsfi', 'Rating': 8, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292336', '_id': 'bbef47586c9142cb9757e322fc560993', '_collection_name': 'JohnWick'}, page_content=': 3\nReview: John wick has a very simple revenge story. It can be summarized as "Keanu gets angry and shoots bad guys" but what makes it special? Directed by Chad Stahelski who\'s a stunt specialist boy does it show because the main selling point in the film are some real virtuoso action sequences, well made choreographies. Unlike today\'s action movies, it doesn\'t use quick-cuts or shaky cameras actually see what\'s going on.'), Document(metadata={'source': 'john_wick_4.csv', 'row': 18, 'Review_Date': '17 March 2023', 'Review_Title': ' Not Just The Best John Wick, But Possibly One Of The Best Action Movies Ever\n', 'Review_Url': '/review/rw8935367/?ref_=tt_urv', 'Author': 'cadillac20', 'Rating': 10, 'Movie_Title': 'John Wick 4', 'last_accessed_at': datetime.datetime(2025, 2, 28, 11, 40, 31, 292929)}, page_content=": 18\nReview: Ever since the original John Wick, the franchise has set a standard of what action in Hollywood should be. Thanks to Chad Stahelski and Keanu Reeve's knowledge of the technical aspects of shooting action, they've been able to deliver expertly choreographed, shot, and edited action films that are now the go to as examples of great action filmmaking. And so, the expectations for the fourth film were fairly high, especially as it became more apparent this was not only the culmination of everything before it, but a whopping 169 minutes long. Rest assured, however, that it delivers in spades. Everything we have come to know and love is here, but with an infusion of creativity like we haven't seen from the franchise yet."), Document(metadata={'source': 'john_wick_4.csv', 'row': 19, 'Review_Date': '17 March 2023', 'Review_Title': ' The Best John Wick Sequel\n', 'Review_Url': '/review/rw8935117/?ref_=tt_urv', 'Author': 'tkdlifemagazine', 'Rating': 9, 'Movie_Title': 'John Wick 4', 'last_accessed_at': datetime.datetime(2025, 2, 28, 11, 40, 31, 292930)}, page_content=": 19\nReview: John Wick: Chapter 4 picks up where Chapter 3: Parabellum left off. As has been the tradition in the sequels to this beloved martial arts action franchise the action starts from the very inception of the film's opening, and lasts until the curtain falls. JW4 is no exception to that rule. What it does do is improve on the prior installment, and solidify Keanu Reeves as the greatest martial arts action star of all time. If you don't accept that notio ...
# response[response] Chad Stahelski's direction contributes to the uniqueness of the John Wick film by showcasing real virtuoso action sequences with well-made choreographies. Unlike some modern action movies, Stahelski avoids quick-cuts or shaky cameras, allowing the audience to clearly see what's happening in the action sequences. This attention to detail and skillful execution of action sets the John Wick film apart and adds to its distinctiveness.
# response {'response': AIMessage(content='John Wick goes after Russian mobsters because they have killed his dog, destroyed his belongings, and stolen his car. This act triggers him to seek revenge on the mobsters, ultimately leading to a violent confrontation.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 43, 'prompt_tokens': 5858, 'total_tokens': 5901, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-1bb027be-f36f-40ca-8e50-17f621abb380-0', usage_metadata={'input_tokens': 5858, 'output_tokens': 43, 'total_tokens': 5901, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_2.csv', 'row': 20, 'Review_Date': '28 May 2017', 'Review_Title': ' A New Franchise is Born\n', 'Review_Url': '/review/rw3718180/?ref_=tt_urv', 'Author': 'claudio_carvalho', 'Rating': 8, 'Movie_Title': 'John Wick 2', 'last_accessed_at': '2025-02-26T11:40:31.292549', '_id': '14e4e01f095c4b559b49399bfd92e08f', '_collection_name': 'JohnWick'}, page_content=": 20\nReview: After resolving his issues with the Russian mafia, John Wick (Keanu Reeves) returns home. But soon the mobster Santino D'Antonio (Riccardo Scamarcio) visits him to show Wick's marker and tells that he needs to help. John Wicks refuses since he is retired and Santino blows-up his house. John Wick meets the owner of the Continental hotel in New York City, Winston (Ian McShane), and he tells that Wick cannot violate the Mafia rules and shall honor the marker. Santino asks John Wick to kill his sister Gianna D'Antonio (Claudia Gerini) in Rome so that he can sit on the High Table of the criminal organizations. When John Wicks accomplishes his assignment, Santino puts a seven-million dollar contract on him attracting professional killers from everywhere. But Wick promises to kill Santino that is not protected by his marker anymore."), Document(metadata={'source': 'john_wick_1.csv', 'row': 18, 'Review_Date': '10 September 2019', 'Review_Title': ' Probably NOT a film to watch with your kids or mother.\n', 'Review_Url': '/review/rw5112990/?ref_=tt_urv', 'Author': 'planktonrules', 'Rating': 7, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292348', '_id': '1499620ac8b34aa7a289671959c34fd1', '_collection_name': 'JohnWick'}, page_content=": 18\nReview: When the story begins, John (Keanu Reeves) has just lost his wife. After her death, he's a bit lost but tries to rebuild his life. One day, he's getting gas and a young Russian-American punk notices Wick's classic car...and tries to buy it off him. But Wick isn't interested and declines. Soon, the punk arrives at Wick's home with some goons where they surprise him--beating him senseless, destroying his stuff, killing his dog and stealing his car! This is when you then learn that Wick is a super-assassin....and the punk chose the wrong guy to attack. The jerk's father is a big-time Russian mobster....and it's a contest to see who will win...the mobster and his gang or Wick on his own. Considering there are (so far) two MORE John Wick films, it pretty much seems certain who will win this battle."), Document(metadata={'source': 'john_wick_1.csv', 'row': 5, 'Review_Date': '23 March 2023', 'Review_Title': ' Violent and gripping story with plenty of unstopped action , shootouts and breathtaking fights\n', 'Review_Url': '/review/rw8945545/?ref_=tt_urv', 'Author': 'ma-cortes', 'Rating': 7, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292338', '_id': '5c16d3bf25b64afdb3e2a3f3c6f1d4cc', '_collection_name': 'JohnWick'}, page_content=": 5\nReview: Ultra-violent first entry with lots of killings, thr ...
# response[response] John Wick goes after Russian mobsters because they have killed his dog, destroyed his belongings, and stolen his car. This act triggers him to seek revenge on the mobsters, ultimately leading to a violent confrontation.
# response {'response': AIMessage(content='In the first John Wick movie, John Wick is initially mad because the gangsters killed his dog and took everything from him. This act of cruelty and the loss of his beloved wife led him to seek vengeance against those who wronged him. The untimely death of his wife, the theft of his car, and the killing of his dog all served as triggers for his intense anger and thirst for retribution.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 84, 'prompt_tokens': 5706, 'total_tokens': 5790, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-e60b4475-0b8f-44b7-b362-258ec7268b91-0', usage_metadata={'input_tokens': 5706, 'output_tokens': 84, 'total_tokens': 5790, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_1.csv', 'row': 5, 'Review_Date': '23 March 2023', 'Review_Title': ' Violent and gripping story with plenty of unstopped action , shootouts and breathtaking fights\n', 'Review_Url': '/review/rw8945545/?ref_=tt_urv', 'Author': 'ma-cortes', 'Rating': 7, 'Movie_Title': 'John Wick 1', 'last_accessed_at': datetime.datetime(2025, 2, 25, 11, 40, 31, 292338)}, page_content=": 5\nReview: Ultra-violent first entry with lots of killings, thrills , noisy action , suspense , and crossfire . In this original John Wick (2014) , an ex-hit-man comes out of retirement to track down the gangsters that killed his dog and took everything from him . With the untimely death of his beloved wife still bitter in his mouth he seeks for vengeance . But when an arrogant Russian mob prince and hoodlums steal his car and kill his dog , they are fully aware of his lethal capacity. The Bogeyman will find himself dragged into an impossible task as every killer in the business dreams of cornering the legendary Wick who now has an enormous price on his head . In this first installment John Wick , blind with revenge, and for his salvation John will immediately unleash a carefully orchestrated maelstrom of destruction against those attempt to chase him and with a price tag on his head, as he is the target of hit men : an army of bounty-hunting killers on his trail and a murderer woman everywhere . The legendary hitman will be forced to unearth his meticulously concealed identity and to carry out a relentless vendetta . Now, only blood can quench the boogeyman's thirst for retribution . Don't Set Him Off! . John Wick isn't the Boogeyman... He's the guy you send to kill the doomed Boogeyman. Revenge is all he has left. You want peace, prepare for war . Don't Hunt What You Can't Kill. Tick Tock, Mr. Wick. Everyone Is Waiting. For John Wick . Every Action Has Consequences. This Friday, Wick is Back . Its the World Vs. Wick. Every Action Has Consequences."), Document(metadata={'source': 'john_wick_2.csv', 'row': 19, 'Review_Date': '29 November 2020', 'Review_Title': ' John Wick Kills A Lot Of People\n', 'Review_Url': '/review/rw6320115/?ref_=tt_urv', 'Author': 'boblipton', 'Rating': 5, 'Movie_Title': 'John Wick 2', 'last_accessed_at': '2025-02-26T11:40:31.292549', '_id': 'c6a990d6fb27499096a867702c0bdfaf', '_collection_name': 'JohnWick'}, page_content=": 19\nReview: If you've seen the first John Wick movie, you know that Keanu Reeves is John Wick, a retired assassin who comes out of retirement when someone kills his dog. In this one, which begins a week later, matters are still reverberating, and some one has stolen his car, which calls for a lot of carnage. That settled, John is called on to pay off an old debt by helping Ian McShane take over the Assassin's Guild by flying around to Italy, Canada and Manhattan a ...
# response[response] In the first John Wick movie, John Wick is initially mad because the gangsters killed his dog and took everything from him. This act of cruelty and the loss of his beloved wife led him to seek vengeance against those who wronged him. The untimely death of his wife, the theft of his car, and the killing of his dog all served as triggers for his intense anger and thirst for retribution.
# response {'response': AIMessage(content="Based on the reviews provided, 'John Wick: Chapter 2' stands out among American action films due to its slick action sequences, impressive set design, and camera work. The film is praised for its over-the-top yet entertaining action, with viewers enjoying the practical stunt work and the well-filmed fight scenes. Additionally, the movie is commended for being a great sequel that maintains the elements that made the original film successful while expanding its story. The combination of stylish visuals, hardcore action, and a focus on personal backstabbing adds to the appeal of 'John Wick: Chapter 2' in the American action film genre.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 129, 'prompt_tokens': 5595, 'total_tokens': 5724, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-6d0d69fa-2288-438a-9b0e-8ec3ae219ddc-0', usage_metadata={'input_tokens': 5595, 'output_tokens': 129, 'total_tokens': 5724, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_2.csv', 'row': 0, 'Review_Date': '14 September 2018', 'Review_Title': ' "No one gets out and comes back without repercussions."\n', 'Review_Url': '/review/rw4338449/?ref_=tt_urv', 'Author': 'classicsoncall', 'Rating': 7, 'Movie_Title': 'John Wick 2', 'last_accessed_at': '2025-02-26T11:40:31.292533', '_id': 'd2641895b298453080f2f274114b70a9', '_collection_name': 'JohnWick'}, page_content=': 0\nReview: No doubt about it, "John Wick: Chapter 2" is a slick action thriller, but man, oh man, how can any one person absorb that kind of punishment? John (Keanu Reeves) gets shot, stabbed and hit by cars multiple times and postures a limp now and then to indicate he might have gotten just a little bit hurt. Besides that, he almost never makes a wrong move when hunted by dozens of assassins all at the same time. Okay, I get it, Reeves is the star of the picture and has to come out on top, but I\'d like a little more credibility put into these kinds of stories. But I guess that\'s the whole point, suspend your disbelief for a couple of hours and just go with all of the over the top action the film makers can put together.'), Document(metadata={'source': 'john_wick_2.csv', 'row': 16, 'Review_Date': '9 February 2017', 'Review_Title': ' Kick-ass, entertaining and relentless throughout. This is what every sequel should aspire to be.\n', 'Review_Url': '/review/rw3636884/?ref_=tt_urv', 'Author': 'trublu215', 'Rating': 5, 'Movie_Title': 'John Wick 2', 'last_accessed_at': '2025-02-26T11:40:31.292546', '_id': '3b935f6ed310465b801954cade3ce370', '_collection_name': 'JohnWick'}, page_content=": 16\nReview: John Wick Chapter 2 pits Keanu Reeves' titular character against the mean and nefarious of the criminal underworld. Once again, Reeves proves that he is a force to be reckoned with in this ridiculous, over-the-top sequel that is every bit as fun as the original. These types of films are rarely known for their artistic value but John Wick: Chapter 2 sets the bar pretty high, not only in its action, but in it's set design and camera work. This is pure escapist entertainment and couldn't have come at a better time. Those wanting to take a break from watching the Oscar nominees, this film is exactly what you're looking for."), Document(metadata={'source': 'john_wick_2.csv', 'row': 9, 'Review_Date': '22 July 2017', 'Review_Title': ' A disappointing sequel for the most part\n', 'Review_Url': '/review/rw3760991/?ref_=tt_urv', 'Author': 'Horst_In_Translation', 'Rating': 4, 'Movie_Title': 'John Wick 2', 'last_accessed_at': '2025-02-26T11:40:31.292541' ...
# response[response] Based on the reviews provided, 'John Wick: Chapter 2' stands out among American action films due to its slick action sequences, impressive set design, and camera work. The film is praised for its over-the-top yet entertaining action, with viewers enjoying the practical stunt work and the well-filmed fight scenes. Additionally, the movie is commended for being a great sequel that maintains the elements that made the original film successful while expanding its story. The combination of stylish visuals, hardcore action, and a focus on personal backstabbing adds to the appeal of 'John Wick: Chapter 2' in the American action film genre.
# response {'response': AIMessage(content='John Wick: Chapter 4 improves upon John Wick: Chapter 3 - Parabellum by solidifying Keanu Reeves as the greatest martial arts action star of all time, according to reviews. Additionally, the pairing of Keanu Reeves and Director Chad Stahelski is considered the greatest martial arts action pairing of modern times. The film also delivers expertly choreographed, shot, and edited action sequences with an infusion of creativity not seen in the franchise before.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 97, 'prompt_tokens': 3866, 'total_tokens': 3963, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-95972b33-e93d-48ae-b80e-d70a6e0cc67c-0', usage_metadata={'input_tokens': 3866, 'output_tokens': 97, 'total_tokens': 3963, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_4.csv', 'row': 19, 'Review_Date': '17 March 2023', 'Review_Title': ' The Best John Wick Sequel\n', 'Review_Url': '/review/rw8935117/?ref_=tt_urv', 'Author': 'tkdlifemagazine', 'Rating': 9, 'Movie_Title': 'John Wick 4', 'last_accessed_at': datetime.datetime(2025, 2, 28, 11, 40, 31, 292930)}, page_content=": 19\nReview: John Wick: Chapter 4 picks up where Chapter 3: Parabellum left off. As has been the tradition in the sequels to this beloved martial arts action franchise the action starts from the very inception of the film's opening, and lasts until the curtain falls. JW4 is no exception to that rule. What it does do is improve on the prior installment, and solidify Keanu Reeves as the greatest martial arts action star of all time. If you don't accept that notion, then you must accept the fact that it solidifies Reeves and Director, Chad Stahelski, as the greatest martial arts action pairing of modern times."), Document(metadata={'source': 'john_wick_3.csv', 'row': 24, 'Review_Date': '17 May 2019', 'Review_Title': ' Makes John Wick a superb trilogy\n', 'Review_Url': '/review/rw4860603/?ref_=tt_urv', 'Author': 'masonsaul', 'Rating': 10, 'Movie_Title': 'John Wick 3', 'last_accessed_at': datetime.datetime(2025, 2, 27, 11, 40, 31, 292750)}, page_content=": 24\nReview: John Wick: Chapter 3 - Parabellum is quite literally about consequences, dealing with the fallout of John's actions at the end of the previous film and sending him on an even bigger odyssey of violence that continues to explore this world of assassination and deliver beautifully clean action sequences."), Document(metadata={'source': 'john_wick_3.csv', 'row': 13, 'Review_Date': '15 May 2019', 'Review_Title': ' Pure, delirious joy in the form of yet another exhilarating thriller\n', 'Review_Url': '/review/rw4855261/?ref_=tt_urv', 'Author': 'themadmovieman', 'Rating': 8, 'Movie_Title': 'John Wick 3', 'last_accessed_at': datetime.datetime(2025, 2, 27, 11, 40, 31, 292740)}, page_content=": 13\nReview: Following on from two deliriously entertaining, visually gorgeous and blissfully simplistic thrillers, John Wick: Chapter 3 - Parabellum keeps up the franchise's unique appeal in stunning fashion. Complete with electrifying action, beautiful cinematography, a pulsating score and a great sense of humour, the film is pretty much as purely joyful as action thrillers get, and proves two hours of brilliant entertainment."), Document(metadata={'source': 'john_wick_4.csv', 'row': 24, 'Review_Date': '3 June 2023', 'Review_Title': ' Almost 3 hours of nothing\n', 'Review_Url': '/review/rw9097584/?ref_=tt_urv', 'Author': 'Phil_H', 'Rating': 4, 'Movie_Title': 'John Wick 4', 'last_accessed_at': '2025-02-28T11:40:31.292934', '_id': '7cc1242ab69c43c0b47302ee906 ...
# response[response] John Wick: Chapter 4 improves upon John Wick: Chapter 3 - Parabellum by solidifying Keanu Reeves as the greatest martial arts action star of all time, according to reviews. Additionally, the pairing of Keanu Reeves and Director Chad Stahelski is considered the greatest martial arts action pairing of modern times. The film also delivers expertly choreographed, shot, and edited action sequences with an infusion of creativity not seen in the franchise before.
# response {'response': AIMessage(content='The John Wick franchise has set a high standard for action in Hollywood by delivering expertly choreographed, shot, and edited action films. The franchise is often praised for its creativity and the infusion of unique elements that set it apart from other American action flicks. In terms of screenplay quality, John Wick films are considered exceptions to the norm, along with the Mission Impossible franchise, as they focus on well-crafted stories and character development. As for the use of CGI, the John Wick films are known for their practical effects and real stunts, with minimal reliance on computer-generated imagery. Overall, the franchise has been lauded for its dedication to high-quality action filmmaking that stands out in the industry.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 142, 'prompt_tokens': 4613, 'total_tokens': 4755, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-442cb556-622f-4fa2-b553-778b07d354f9-0', usage_metadata={'input_tokens': 4613, 'output_tokens': 142, 'total_tokens': 4755, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_4.csv', 'row': 18, 'Review_Date': '17 March 2023', 'Review_Title': ' Not Just The Best John Wick, But Possibly One Of The Best Action Movies Ever\n', 'Review_Url': '/review/rw8935367/?ref_=tt_urv', 'Author': 'cadillac20', 'Rating': 10, 'Movie_Title': 'John Wick 4', 'last_accessed_at': datetime.datetime(2025, 2, 28, 11, 40, 31, 292929)}, page_content=": 18\nReview: Ever since the original John Wick, the franchise has set a standard of what action in Hollywood should be. Thanks to Chad Stahelski and Keanu Reeve's knowledge of the technical aspects of shooting action, they've been able to deliver expertly choreographed, shot, and edited action films that are now the go to as examples of great action filmmaking. And so, the expectations for the fourth film were fairly high, especially as it became more apparent this was not only the culmination of everything before it, but a whopping 169 minutes long. Rest assured, however, that it delivers in spades. Everything we have come to know and love is here, but with an infusion of creativity like we haven't seen from the franchise yet."), Document(metadata={'source': 'john_wick_4.csv', 'row': 10, 'Review_Date': '22 March 2023', 'Review_Title': ' How Can Anyone Choose to Watch Marvel Over This?\n', 'Review_Url': '/review/rw8944843/?ref_=tt_urv', 'Author': 'lovemichaeljordan', 'Rating': 8, 'Movie_Title': 'John Wick 4', 'last_accessed_at': datetime.datetime(2025, 2, 28, 11, 40, 31, 292923)}, page_content=": 10\nReview: Most American action flicks released these days have poor screenplays and overuse computer-generated imagery. The John Wick franchise is one of the few exceptions, along with Mission Impossible. These franchises keep getting better with every entry. Hollywood can make action masterpieces, but Marvel has greater demand, so that's what we get most of. It's a shame."), Document(metadata={'source': 'john_wick_3.csv', 'row': 5, 'Review_Date': '17 July 2019', 'Review_Title': ' The magic is gone\n', 'Review_Url': '/review/rw4999970/?ref_=tt_urv', 'Author': 'soundoflight', 'Rating': 5, 'Movie_Title': 'John Wick 3', 'last_accessed_at': '2025-02-27T11:40:31.292734', '_id': 'c6cdfe27a2d54fd8b1d997018572469b', '_collection_name': 'JohnWick'}, page_content=': 5\nReview: The first John Wick film was special because it broke a mold of sorts. It went against certain action film conventions - the hero was not a muscle bound hulk like a Schwarzenegger or Stallone, the action wa ...
# response[response] The John Wick franchise has set a high standard for action in Hollywood by delivering expertly choreographed, shot, and edited action films. The franchise is often praised for its creativity and the infusion of unique elements that set it apart from other American action flicks. In terms of screenplay quality, John Wick films are considered exceptions to the norm, along with the Mission Impossible franchise, as they focus on well-crafted stories and character development. As for the use of CGI, the John Wick films are known for their practical effects and real stunts, with minimal reliance on computer-generated imagery. Overall, the franchise has been lauded for its dedication to high-quality action filmmaking that stands out in the industry.
# response {'response': AIMessage(content="Based on the reviews provided, Keanu Reeves' portrayal in the John Wick franchise is highly praised, particularly in terms of action choreography and character depth. Reviewers have highlighted his slick performance, natural fluidity in action sequences, and the sheer intensity he brings to the portrayal of John Wick. The action choreography is commended for being meticulously crafted and smoothly executed, setting a high standard for action filmmaking. Additionally, the character depth and emotional resonance brought by Keanu Reeves to the role of John Wick add an extra layer of engagement and enjoyment for the audience. Overall, the reviews reflect positively on Keanu Reeves' portrayal in the John Wick franchise in terms of action choreography and character depth.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 145, 'prompt_tokens': 5486, 'total_tokens': 5631, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-c3a53c57-b949-41fe-a88d-09885924b892-0', usage_metadata={'input_tokens': 5486, 'output_tokens': 145, 'total_tokens': 5631, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_1.csv', 'row': 9, 'Review_Date': '20 October 2014', 'Review_Title': " The coolest action film you'll see all year\n", 'Review_Url': '/review/rw3107759/?ref_=tt_urv', 'Author': 'trublu215', 'Rating': 9, 'Movie_Title': 'John Wick 1', 'last_accessed_at': datetime.datetime(2025, 2, 25, 11, 40, 31, 292341)}, page_content=": 9\nReview: At first glance, John Wick sounds like a terrible film on paper but with the slickness of Keanu Reeves' performance as the titular character and the sheer brilliance in its action sequences, this marks the best action film of the year and one of the absolute best in the past decade. Following a brutal home invasion that leaves his beloved dog murdered by thugs from his past, John Wick vows revenge on the ones who have taken what he loves most. Like I said, on paper, this seems like a direct-to-DVD slopfest starring John Cena but as a film with Keanu Reeves as the lead, it marks the very welcomed return for Reeves to the genre. John Wick is insanely fun, violently brutal and an overall romp especially for those disappointed by The Expendables 3. John Wick is propelled by Tarantino-esque dialog mixed with the swagger of action stars from the 70s. Reeves literally emulates cool in this film and does it with such confidence, that we don't even doubt the character...even when he kills countless bad guys with extreme force in some utterly ridiculous and implausible situations. We don't doubt it for a minute. This is EXACTLY what you want out of an action film. It is briskly paced, brilliantly shot and meticulously choreographed and keeps you wanting more and more. The supporting cast filled with the likes of John Legiuzamo, Ian McShane, and Willen Dafoe also keeps this film very interesting. These guys don't play good guys, hell, John Wick by traditional standards would be a bad guy in any other film. Every character is more ruthless than the next and pushes John Wick to be more ruthless than they are, creating a very cool dynamic between the character and the plot regarding the idea of how far is too far? However, don't expect some revelation from John Wick regarding the morality of bad and evil. This film wants you entertained and does so with brute force, it never lets up, not even for a second. One scene in particular that will have your blood pumping is a showdown between thugs and Wick in a nightclub. This action sequence remains the best in the film and will ha ...
# response[response] Based on the reviews provided, Keanu Reeves' portrayal in the John Wick franchise is highly praised, particularly in terms of action choreography and character depth. Reviewers have highlighted his slick performance, natural fluidity in action sequences, and the sheer intensity he brings to the portrayal of John Wick. The action choreography is commended for being meticulously crafted and smoothly executed, setting a high standard for action filmmaking. Additionally, the character depth and emotional resonance brought by Keanu Reeves to the role of John Wick add an extra layer of engagement and enjoyment for the audience. Overall, the reviews reflect positively on Keanu Reeves' portrayal in the John Wick franchise in terms of action choreography and character depth.
# response {'response': AIMessage(content="Ian McShane is important in the John Wick movie because he plays a significant role as Winston, the owner of the Continental hotel in New York City. He adds depth to the storyline by enforcing Mafia rules and adding a cool dynamic between the characters. Ian McShane's presence, along with other supporting actors like Willem Dafoe, contributes to making the movie more interesting by creating a ruthlessly intriguing atmosphere that keeps viewers engaged.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 89, 'prompt_tokens': 5542, 'total_tokens': 5631, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-083ea635-45f6-44f8-8f3a-be80f50da1c4-0', usage_metadata={'input_tokens': 5542, 'output_tokens': 89, 'total_tokens': 5631, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_1.csv', 'row': 9, 'Review_Date': '20 October 2014', 'Review_Title': " The coolest action film you'll see all year\n", 'Review_Url': '/review/rw3107759/?ref_=tt_urv', 'Author': 'trublu215', 'Rating': 9, 'Movie_Title': 'John Wick 1', 'last_accessed_at': datetime.datetime(2025, 2, 25, 11, 40, 31, 292341)}, page_content=": 9\nReview: At first glance, John Wick sounds like a terrible film on paper but with the slickness of Keanu Reeves' performance as the titular character and the sheer brilliance in its action sequences, this marks the best action film of the year and one of the absolute best in the past decade. Following a brutal home invasion that leaves his beloved dog murdered by thugs from his past, John Wick vows revenge on the ones who have taken what he loves most. Like I said, on paper, this seems like a direct-to-DVD slopfest starring John Cena but as a film with Keanu Reeves as the lead, it marks the very welcomed return for Reeves to the genre. John Wick is insanely fun, violently brutal and an overall romp especially for those disappointed by The Expendables 3. John Wick is propelled by Tarantino-esque dialog mixed with the swagger of action stars from the 70s. Reeves literally emulates cool in this film and does it with such confidence, that we don't even doubt the character...even when he kills countless bad guys with extreme force in some utterly ridiculous and implausible situations. We don't doubt it for a minute. This is EXACTLY what you want out of an action film. It is briskly paced, brilliantly shot and meticulously choreographed and keeps you wanting more and more. The supporting cast filled with the likes of John Legiuzamo, Ian McShane, and Willen Dafoe also keeps this film very interesting. These guys don't play good guys, hell, John Wick by traditional standards would be a bad guy in any other film. Every character is more ruthless than the next and pushes John Wick to be more ruthless than they are, creating a very cool dynamic between the character and the plot regarding the idea of how far is too far? However, don't expect some revelation from John Wick regarding the morality of bad and evil. This film wants you entertained and does so with brute force, it never lets up, not even for a second. One scene in particular that will have your blood pumping is a showdown between thugs and Wick in a nightclub. This action sequence remains the best in the film and will have you grasping your theater seat because of the sheer intensity of it. Overall, John Wick is slick, violent fun that turns into a remarkable, surprising film that will catch you off guard. It is THAT good. I highly recommend this film to action buffs especially but I'm sure those who just like a good movie will love it  ...
# response[response] Ian McShane is important in the John Wick movie because he plays a significant role as Winston, the owner of the Continental hotel in New York City. He adds depth to the storyline by enforcing Mafia rules and adding a cool dynamic between the characters. Ian McShane's presence, along with other supporting actors like Willem Dafoe, contributes to making the movie more interesting by creating a ruthlessly intriguing atmosphere that keeps viewers engaged.
# Evaluating:   0%|          | 0/60 [00:00<?, ?it/s]
# Exception raised in Job[11]: TimeoutError()
# Exception raised in Job[17]: TimeoutError()
# Exception raised in Job[29]: TimeoutError()
# Exception raised in Job[35]: TimeoutError()
# Exception raised in Job[47]: TimeoutError()
# Exception raised in Job[53]: TimeoutError()
# Exception raised in Job[59]: TimeoutError()
# ensemble_retrieval_chain 477.89819716700003

# %%
result_semantic_retrieval = evaluate_one_chain(dataset, semantic_retrieval_chain)
# Out:
# response {'response': AIMessage(content="I don't know.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 6, 'prompt_tokens': 2720, 'total_tokens': 2726, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-58467943-e082-4c9b-adbe-79aa3eaceae3-0', usage_metadata={'input_tokens': 2720, 'output_tokens': 6, 'total_tokens': 2726, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_1.csv', 'row': 20, 'Review_Date': '22 October 2014', 'Review_Title': ' Smoothest action film to come around in a long time\n', 'Review_Url': '/review/rw3109271/?ref_=tt_urv', 'Author': 'IceSkateUpHill', 'Rating': 10, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292350', '_id': '4405a6f0e8d6496eb5167306369fcff5', '_collection_name': 'JohnWickSemantic'}, page_content=": 20\nReview: John Wick is something special. It takes as much time setting up elaborate action sequences as it does the world with which it all takes place in. And what a world it is. It reminds me of Millers Crossing and it is cooler than any other recent attempt at noir. We are shown a criminal underworld where, if you are connected, many powerful people know who you are and show you respect. John Wick was connected but he got out. He is the rare killer who has found peace, and he is grateful for that peace. Some young kids steal that from him and he does what he does best, he wages a one man war against the Russian Mafia. It might sound like the film takes quite a leap but it all makes sense. The motives of John and the people who get in the way of his bullets are all very clear, even if it does come across as rather simple. That's the plot at it's most basic. Then there's the action. The film is directed by Reeve's stuntman from The Matrix, so this guy knows action. There are sequences that flow so smoothly it puts other action films and their quick cuts to shame. Keaunu moves so fluidly throughout the film and comes across as such a natural that the only disappointment is that we have not seen him like this before. Along the way are plenty of character actors, fans of The Matrix and The Wire will recognize a few people then there are more obvious ones like Ian McShane and Willem Dafoe. Everyone seems to be having a good time."), Document(metadata={'source': 'john_wick_2.csv', 'row': 19, 'Review_Date': '29 November 2020', 'Review_Title': ' John Wick Kills A Lot Of People\n', 'Review_Url': '/review/rw6320115/?ref_=tt_urv', 'Author': 'boblipton', 'Rating': 5, 'Movie_Title': 'John Wick 2', 'last_accessed_at': '2025-02-26T11:40:31.292549', '_id': '2b05090f74e643a291056dd1c22b95e3', '_collection_name': 'JohnWickSemantic'}, page_content=": 19\nReview: If you've seen the first John Wick movie, you know that Keanu Reeves is John Wick, a retired assassin who comes out of retirement when someone kills his dog. In this one, which begins a week later, matters are still reverberating, and some one has stolen his car, which calls for a lot of carnage."), Document(metadata={'source': 'john_wick_1.csv', 'row': 0, 'Review_Date': '6 May 2015', 'Review_Title': ' Kinetic, concise, and stylish; John Wick kicks ass.\n', 'Review_Url': '/review/rw3233896/?ref_=tt_urv', 'Author': 'lnvicta', 'Rating': 8, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292319', '_id': 'bf6633ee588e4bf88e8de1c7ed9d5ec0', '_collection_name': 'JohnWickSemantic'}, page_content=": 0\nReview: The best way I can describe John Wick is to picture Taken but instead of Liam Neeson it's Keanu Reeves and instead of his daughter it's his dog. That's essentially the plot of the movi ...
# response[response] I don't know.
# response {'response': AIMessage(content='The reception of the John Wick franchise has been generally positive, especially with the release of the fourth installment. Critics and audiences have praised the action sequences, choreography, and overall quality of the films. There is a consensus that the franchise has set new standards for action movies.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 56, 'prompt_tokens': 2804, 'total_tokens': 2860, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-134337fc-c8da-4206-81d0-f9d81ec720b1-0', usage_metadata={'input_tokens': 2804, 'output_tokens': 56, 'total_tokens': 2860, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_1.csv', 'row': 2, 'Review_Date': '5 May 2023', 'Review_Title': " You don't mess with another person's dog. It's as simple as that!\n", 'Review_Url': '/review/rw9033669/?ref_=tt_urv', 'Author': 'Coventry', 'Rating': 5, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292335', '_id': 'f04c7196364f4790b692c302444e6dbf', '_collection_name': 'JohnWickSemantic'}, page_content=': 2\nReview: With the fourth installment scoring immensely at the cinemas as I\'m submitting this review, and after three previous films that are apparently loved by everyone else in the world, I thought perhaps it would be time for me check out "John Wick".'), Document(metadata={'source': 'john_wick_4.csv', 'row': 18, 'Review_Date': '17 March 2023', 'Review_Title': ' Not Just The Best John Wick, But Possibly One Of The Best Action Movies Ever\n', 'Review_Url': '/review/rw8935367/?ref_=tt_urv', 'Author': 'cadillac20', 'Rating': 10, 'Movie_Title': 'John Wick 4', 'last_accessed_at': '2025-02-28T11:40:31.292929', '_id': 'bc33f10ca911475f8dca4db9eded6d5c', '_collection_name': 'JohnWickSemantic'}, page_content=": 18\nReview: Ever since the original John Wick, the franchise has set a standard of what action in Hollywood should be. Thanks to Chad Stahelski and Keanu Reeve's knowledge of the technical aspects of shooting action, they've been able to deliver expertly choreographed, shot, and edited action films that are now the go to as examples of great action filmmaking. And so, the expectations for the fourth film were fairly high, especially as it became more apparent this was not only the culmination of everything before it, but a whopping 169 minutes long. Rest assured, however, that it delivers in spades."), Document(metadata={'source': 'john_wick_4.csv', 'row': 19, 'Review_Date': '17 March 2023', 'Review_Title': ' The Best John Wick Sequel\n', 'Review_Url': '/review/rw8935117/?ref_=tt_urv', 'Author': 'tkdlifemagazine', 'Rating': 9, 'Movie_Title': 'John Wick 4', 'last_accessed_at': '2025-02-28T11:40:31.292930', '_id': '4c6415d080ff4820966d30601885801e', '_collection_name': 'JohnWickSemantic'}, page_content=": 19\nReview: John Wick: Chapter 4 picks up where Chapter 3: Parabellum left off. As has been the tradition in the sequels to this beloved martial arts action franchise the action starts from the very inception of the film's opening, and lasts until the curtain falls."), Document(metadata={'source': 'john_wick_4.csv', 'row': 20, 'Review_Date': '23 March 2023', 'Review_Title': ' THIS is how you justify a 3 hour runtime\n', 'Review_Url': '/review/rw8946038/?ref_=tt_urv', 'Author': 'jtindahouse', 'Rating': 9, 'Movie_Title': 'John Wick 4', 'last_accessed_at': '2025-02-28T11:40:31.292931', '_id': 'd18522b1c75647b8a012da2b8b779daf', '_collection_name': 'JohnWickSemantic'}, page_content=": 20\nReview: In a world where movie sequels seem to be loathed even before t ...
# response[response] The reception of the John Wick franchise has been generally positive, especially with the release of the fourth installment. Critics and audiences have praised the action sequences, choreography, and overall quality of the films. There is a consensus that the franchise has set new standards for action movies.
# response {'response': AIMessage(content="Chad Stahelski's direction in the John Wick film contributes to its uniqueness by showcasing real virtuoso action sequences with well-made choreographies. Unlike many action movies today, Stahelski's direction avoids quick-cuts and shaky cameras, allowing viewers to clearly see what's happening in the intense action scenes.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 2948, 'total_tokens': 3014, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-b403044a-354a-4ee9-b33c-abb077eb4177-0', usage_metadata={'input_tokens': 2948, 'output_tokens': 66, 'total_tokens': 3014, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_1.csv', 'row': 3, 'Review_Date': '28 September 2018', 'Review_Title': ' Keanu gets pissed and shoots people in the face for 101 minutes*\n', 'Review_Url': '/review/rw4366368/?ref_=tt_urv', 'Author': 'Kitsfi', 'Rating': 8, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292336', '_id': '02a915933a674da99f0508a807f696ab', '_collection_name': 'JohnWickSemantic'}, page_content="Directed by Chad Stahelski who's a stunt specialist boy does it show because the main selling point in the film are some real virtuoso action sequences, well made choreographies. Unlike today's action movies, it doesn't use quick-cuts or shaky cameras actually see what's going on."), Document(metadata={'source': 'john_wick_1.csv', 'row': 9, 'Review_Date': '20 October 2014', 'Review_Title': " The coolest action film you'll see all year\n", 'Review_Url': '/review/rw3107759/?ref_=tt_urv', 'Author': 'trublu215', 'Rating': 9, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292341', '_id': '94a1080971474a6fbccb4e1adeaee44a', '_collection_name': 'JohnWickSemantic'}, page_content="This is EXACTLY what you want out of an action film. It is briskly paced, brilliantly shot and meticulously choreographed and keeps you wanting more and more. The supporting cast filled with the likes of John Legiuzamo, Ian McShane, and Willen Dafoe also keeps this film very interesting. These guys don't play good guys, hell, John Wick by traditional standards would be a bad guy in any other film. Every character is more ruthless than the next and pushes John Wick to be more ruthless than they are, creating a very cool dynamic between the character and the plot regarding the idea of how far is too far? However, don't expect some revelation from John Wick regarding the morality of bad and evil. This film wants you entertained and does so with brute force, it never lets up, not even for a second. One scene in particular that will have your blood pumping is a showdown between thugs and Wick in a nightclub. This action sequence remains the best in the film and will have you grasping your theater seat because of the sheer intensity of it. Overall, John Wick is slick, violent fun that turns into a remarkable, surprising film that will catch you off guard. It is THAT good. I highly recommend this film to action buffs especially but I'm sure those who just like a good movie will love it as well."), Document(metadata={'source': 'john_wick_4.csv', 'row': 18, 'Review_Date': '17 March 2023', 'Review_Title': ' Not Just The Best John Wick, But Possibly One Of The Best Action Movies Ever\n', 'Review_Url': '/review/rw8935367/?ref_=tt_urv', 'Author': 'cadillac20', 'Rating': 10, 'Movie_Title': 'John Wick 4', 'last_accessed_at': '2025-02-28T11:40:31.292929', '_id': 'bc33f10ca911475f8dca4db9eded6d5c', '_collection_name': 'JohnWickSemantic'}, page_content=": 18\nReview ...
# response[response] Chad Stahelski's direction in the John Wick film contributes to its uniqueness by showcasing real virtuoso action sequences with well-made choreographies. Unlike many action movies today, Stahelski's direction avoids quick-cuts and shaky cameras, allowing viewers to clearly see what's happening in the intense action scenes.
# response {'response': AIMessage(content='John Wick goes after Russian mobsters because they broke into his house, beat him up, killed his puppy, and stole his car. They did this without knowing who he was, just wanting his car. This led John Wick to seek revenge against the Russian gangster and his associates.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 58, 'prompt_tokens': 3088, 'total_tokens': 3146, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-50cfdddd-f6af-4b8d-9093-10dd6e38646a-0', usage_metadata={'input_tokens': 3088, 'output_tokens': 58, 'total_tokens': 3146, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_1.csv', 'row': 10, 'Review_Date': '22 November 2014', 'Review_Title': ' Most Excellent\n', 'Review_Url': '/review/rw3128980/?ref_=tt_urv', 'Author': 'utgard14', 'Rating': 7, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292342', '_id': '138074d1cdc94df39c681bd53c15ed77', '_collection_name': 'JohnWickSemantic'}, page_content="A few days later some thugs, led by the son of a Russian gangster John used to work for, break into John's house. They beat him up, take the keys to his beloved car, and kill the puppy. They did this not knowing who he was; they just wanted the car. Now John Wick is out for revenge and the Russian gangster is trying to save his son's life by sending killers after John."), Document(metadata={'source': 'john_wick_1.csv', 'row': 18, 'Review_Date': '10 September 2019', 'Review_Title': ' Probably NOT a film to watch with your kids or mother.\n', 'Review_Url': '/review/rw5112990/?ref_=tt_urv', 'Author': 'planktonrules', 'Rating': 7, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292348', '_id': 'dfaddad82c1b4dafb71d2be0c7f7c514', '_collection_name': 'JohnWickSemantic'}, page_content="One day, he's getting gas and a young Russian-American punk notices Wick's classic car...and tries to buy it off him. But Wick isn't interested and declines. Soon, the punk arrives at Wick's home with some goons where they surprise him--beating him senseless, destroying his stuff, killing his dog and stealing his car! This is when you then learn that Wick is a super-assassin....and the punk chose the wrong guy to attack. The jerk's father is a big-time Russian mobster....and it's a contest to see who will win...the mobster and his gang or Wick on his own. Considering there are (so far) two MORE John Wick films, it pretty much seems certain who will win this battle."), Document(metadata={'source': 'john_wick_2.csv', 'row': 20, 'Review_Date': '28 May 2017', 'Review_Title': ' A New Franchise is Born\n', 'Review_Url': '/review/rw3718180/?ref_=tt_urv', 'Author': 'claudio_carvalho', 'Rating': 8, 'Movie_Title': 'John Wick 2', 'last_accessed_at': '2025-02-26T11:40:31.292549', '_id': '9e140adc7fc94514845e562e607785ca', '_collection_name': 'JohnWickSemantic'}, page_content="John Wicks refuses since he is retired and Santino blows-up his house. John Wick meets the owner of the Continental hotel in New York City, Winston (Ian McShane), and he tells that Wick cannot violate the Mafia rules and shall honor the marker. Santino asks John Wick to kill his sister Gianna D'Antonio (Claudia Gerini) in Rome so that he can sit on the High Table of the criminal organizations. When John Wicks accomplishes his assignment, Santino puts a seven-million dollar contract on him attracting professional killers from everywhere. But Wick promises to kill Santino that is not protected by his marker anymore."), Document(metadata={'source': 'john_wick_1.csv', 'row': 5, 'Review_D ...
# response[response] John Wick goes after Russian mobsters because they broke into his house, beat him up, killed his puppy, and stole his car. They did this without knowing who he was, just wanting his car. This led John Wick to seek revenge against the Russian gangster and his associates.
# response {'response': AIMessage(content='In the first John Wick movie, John Wick is extremely mad because gangsters killed his dog and took everything from him, including his car. This act of cruelty and loss drives him to seek vengeance, leading to a violent and action-packed story of revenge.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 52, 'prompt_tokens': 2773, 'total_tokens': 2825, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-dd22ab92-b5a6-4c20-8372-eb0a472402af-0', usage_metadata={'input_tokens': 2773, 'output_tokens': 52, 'total_tokens': 2825, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_1.csv', 'row': 5, 'Review_Date': '23 March 2023', 'Review_Title': ' Violent and gripping story with plenty of unstopped action , shootouts and breathtaking fights\n', 'Review_Url': '/review/rw8945545/?ref_=tt_urv', 'Author': 'ma-cortes', 'Rating': 7, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292338', '_id': '012e573b896b451a93ee18f144bd8f00', '_collection_name': 'JohnWickSemantic'}, page_content=': 5\nReview: Ultra-violent first entry with lots of killings, thrills , noisy action , suspense , and crossfire . In this original John Wick (2014) , an ex-hit-man comes out of retirement to track down the gangsters that killed his dog and took everything from him . With the untimely death of his beloved wife still bitter in his mouth he seeks for vengeance . But when an arrogant Russian mob prince and hoodlums steal his car and kill his dog , they are fully aware of his lethal capacity. The Bogeyman will find himself dragged into an impossible task as every killer in the business dreams of cornering the legendary Wick who now has an enormous price on his head . In this first installment John Wick , blind with revenge, and for his salvation John will immediately unleash a carefully orchestrated maelstrom of destruction against those attempt to chase him and with a price tag on his head, as he is the target of hit men : an army of bounty-hunting killers on his trail and a murderer woman everywhere . The legendary hitman will be forced to unearth his meticulously concealed identity and to carry out a relentless vendetta .'), Document(metadata={'source': 'john_wick_2.csv', 'row': 19, 'Review_Date': '29 November 2020', 'Review_Title': ' John Wick Kills A Lot Of People\n', 'Review_Url': '/review/rw6320115/?ref_=tt_urv', 'Author': 'boblipton', 'Rating': 5, 'Movie_Title': 'John Wick 2', 'last_accessed_at': '2025-02-26T11:40:31.292549', '_id': '2b05090f74e643a291056dd1c22b95e3', '_collection_name': 'JohnWickSemantic'}, page_content=": 19\nReview: If you've seen the first John Wick movie, you know that Keanu Reeves is John Wick, a retired assassin who comes out of retirement when someone kills his dog. In this one, which begins a week later, matters are still reverberating, and some one has stolen his car, which calls for a lot of carnage."), Document(metadata={'source': 'john_wick_1.csv', 'row': 0, 'Review_Date': '6 May 2015', 'Review_Title': ' Kinetic, concise, and stylish; John Wick kicks ass.\n', 'Review_Url': '/review/rw3233896/?ref_=tt_urv', 'Author': 'lnvicta', 'Rating': 8, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292319', '_id': '388618daf3f24d46982a81327d215865', '_collection_name': 'JohnWickSemantic'}, page_content="John Wick (Reeves) is out to seek revenge on the people who took something he loved from him. It's a beautifully simple premise for an action movie - when action movies get convoluted, they get bad i.e. A Good Day to Die Hard. John Wick g ...
# response[response] In the first John Wick movie, John Wick is extremely mad because gangsters killed his dog and took everything from him, including his car. This act of cruelty and loss drives him to seek vengeance, leading to a violent and action-packed story of revenge.
# response {'response': AIMessage(content="According to reviews, 'John Wick: Chapter 2' stands out among American action films for its sharp, well-filmed action sequences with no bad shaky cams or jump cuts. The movie is praised for setting a high bar in terms of action, set design, and camera work, making it a pure escapist entertainment experience.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 68, 'prompt_tokens': 3093, 'total_tokens': 3161, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-a34dea31-e542-45bd-9cfd-db63787fb8bb-0', usage_metadata={'input_tokens': 3093, 'output_tokens': 68, 'total_tokens': 3161, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_2.csv', 'row': 22, 'Review_Date': '12 February 2017', 'Review_Title': ' This is how you film an action movie !\n', 'Review_Url': '/review/rw3638970/?ref_=tt_urv', 'Author': 'destroyerwod', 'Rating': 9, 'Movie_Title': 'John Wick 2', 'last_accessed_at': '2025-02-26T11:40:31.292551', '_id': 'ab88930f3a194c198c37e327d4a3afea', '_collection_name': 'JohnWickSemantic'}, page_content=': 22\nReview: John Wick is one of my favourite recent years action movie and the second one pick up right where the first one left. The action is sharp, well filmed, no bad shaky cams and jump cuts like a certain bad action movie i saw recently.'), Document(metadata={'source': 'john_wick_1.csv', 'row': 20, 'Review_Date': '22 October 2014', 'Review_Title': ' Smoothest action film to come around in a long time\n', 'Review_Url': '/review/rw3109271/?ref_=tt_urv', 'Author': 'IceSkateUpHill', 'Rating': 10, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292350', '_id': '4405a6f0e8d6496eb5167306369fcff5', '_collection_name': 'JohnWickSemantic'}, page_content=": 20\nReview: John Wick is something special. It takes as much time setting up elaborate action sequences as it does the world with which it all takes place in. And what a world it is. It reminds me of Millers Crossing and it is cooler than any other recent attempt at noir. We are shown a criminal underworld where, if you are connected, many powerful people know who you are and show you respect. John Wick was connected but he got out. He is the rare killer who has found peace, and he is grateful for that peace. Some young kids steal that from him and he does what he does best, he wages a one man war against the Russian Mafia. It might sound like the film takes quite a leap but it all makes sense. The motives of John and the people who get in the way of his bullets are all very clear, even if it does come across as rather simple. That's the plot at it's most basic. Then there's the action. The film is directed by Reeve's stuntman from The Matrix, so this guy knows action. There are sequences that flow so smoothly it puts other action films and their quick cuts to shame. Keaunu moves so fluidly throughout the film and comes across as such a natural that the only disappointment is that we have not seen him like this before. Along the way are plenty of character actors, fans of The Matrix and The Wire will recognize a few people then there are more obvious ones like Ian McShane and Willem Dafoe. Everyone seems to be having a good time."), Document(metadata={'source': 'john_wick_2.csv', 'row': 16, 'Review_Date': '9 February 2017', 'Review_Title': ' Kick-ass, entertaining and relentless throughout. This is what every sequel should aspire to be.\n', 'Review_Url': '/review/rw3636884/?ref_=tt_urv', 'Author': 'trublu215', 'Rating': 5, 'Movie_Title': 'John Wick 2', 'last_accessed_at': '2025-02-26T11:40:31.292546',  ...
# response[response] According to reviews, 'John Wick: Chapter 2' stands out among American action films for its sharp, well-filmed action sequences with no bad shaky cams or jump cuts. The movie is praised for setting a high bar in terms of action, set design, and camera work, making it a pure escapist entertainment experience.
# response {'response': AIMessage(content='Based on the reviews of John Wick: Chapter 4, it is said to be more intense and action-packed compared to John Wick: Chapter 3 - Parabellum. According to one review, it is even more on steroids than any Wick before. Additionally, it is noted that the set pieces are really insane in this installment. \n\nTherefore, it seems that John Wick: Chapter 4 improves upon its predecessor by delivering even more intense action and thrilling sequences.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 95, 'prompt_tokens': 2866, 'total_tokens': 2961, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-761f88f1-768b-4b71-a284-57bb5c092b19-0', usage_metadata={'input_tokens': 2866, 'output_tokens': 95, 'total_tokens': 2961, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_4.csv', 'row': 19, 'Review_Date': '17 March 2023', 'Review_Title': ' The Best John Wick Sequel\n', 'Review_Url': '/review/rw8935117/?ref_=tt_urv', 'Author': 'tkdlifemagazine', 'Rating': 9, 'Movie_Title': 'John Wick 4', 'last_accessed_at': '2025-02-28T11:40:31.292930', '_id': '4c6415d080ff4820966d30601885801e', '_collection_name': 'JohnWickSemantic'}, page_content=": 19\nReview: John Wick: Chapter 4 picks up where Chapter 3: Parabellum left off. As has been the tradition in the sequels to this beloved martial arts action franchise the action starts from the very inception of the film's opening, and lasts until the curtain falls."), Document(metadata={'source': 'john_wick_3.csv', 'row': 24, 'Review_Date': '17 May 2019', 'Review_Title': ' Makes John Wick a superb trilogy\n', 'Review_Url': '/review/rw4860603/?ref_=tt_urv', 'Author': 'masonsaul', 'Rating': 10, 'Movie_Title': 'John Wick 3', 'last_accessed_at': '2025-02-27T11:40:31.292750', '_id': 'f70df71af4264dc49b1534384d040b1a', '_collection_name': 'JohnWickSemantic'}, page_content=": 24\nReview: John Wick: Chapter 3 - Parabellum is quite literally about consequences, dealing with the fallout of John's actions at the end of the previous film and sending him on an even bigger odyssey of violence that continues to explore this world of assassination and deliver beautifully clean action sequences."), Document(metadata={'source': 'john_wick_3.csv', 'row': 13, 'Review_Date': '15 May 2019', 'Review_Title': ' Pure, delirious joy in the form of yet another exhilarating thriller\n', 'Review_Url': '/review/rw4855261/?ref_=tt_urv', 'Author': 'themadmovieman', 'Rating': 8, 'Movie_Title': 'John Wick 3', 'last_accessed_at': '2025-02-27T11:40:31.292740', '_id': '08798bb33d1649078cecfd01de869c51', '_collection_name': 'JohnWickSemantic'}, page_content=": 13\nReview: Following on from two deliriously entertaining, visually gorgeous and blissfully simplistic thrillers, John Wick: Chapter 3 - Parabellum keeps up the franchise's unique appeal in stunning fashion. Complete with electrifying action, beautiful cinematography, a pulsating score and a great sense of humour, the film is pretty much as purely joyful as action thrillers get, and proves two hours of brilliant entertainment."), Document(metadata={'source': 'john_wick_3.csv', 'row': 19, 'Review_Date': '22 September 2019', 'Review_Title': ' Sheer enjoyment\n', 'Review_Url': '/review/rw5135863/?ref_=tt_urv', 'Author': 'Leofwine_draca', 'Rating': 9, 'Movie_Title': 'John Wick 3', 'last_accessed_at': '2025-02-27T11:40:31.292746', '_id': 'b2e366016a7f44e3b1e1ca7af59c55f1', '_collection_name': 'JohnWickSemantic'}, page_content=': 19\nReview: The inevitable third chapter of the JOHN WICK franchise continues on a high with the same quality a ...
# response[response] Based on the reviews of John Wick: Chapter 4, it is said to be more intense and action-packed compared to John Wick: Chapter 3 - Parabellum. According to one review, it is even more on steroids than any Wick before. Additionally, it is noted that the set pieces are really insane in this installment.
#
# Therefore, it seems that John Wick: Chapter 4 improves upon its predecessor by delivering even more intense action and thrilling sequences.
# response {'response': AIMessage(content='The John Wick franchise has set a standard for Hollywood action films by delivering expertly choreographed, shot, and edited action sequences. The franchise, led by Chad Stahelski and Keanu Reeves, has raised the bar for great action filmmaking in Hollywood. In terms of screenplay quality and use of CGI, the John Wick franchise stands out from most American action flicks, which often feature poor screenplays and an overuse of CGI. The John Wick movies focus on lean, intense, and emotionally impactful plots, and rely more on practical stunts and choreography rather than heavy CGI effects. Overall, the franchise has set a high standard for action films in terms of both screenplay quality and the use of CGI.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 146, 'prompt_tokens': 3075, 'total_tokens': 3221, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-2e346da4-9f48-4e9b-bcbc-2f35883e9878-0', usage_metadata={'input_tokens': 3075, 'output_tokens': 146, 'total_tokens': 3221, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_4.csv', 'row': 18, 'Review_Date': '17 March 2023', 'Review_Title': ' Not Just The Best John Wick, But Possibly One Of The Best Action Movies Ever\n', 'Review_Url': '/review/rw8935367/?ref_=tt_urv', 'Author': 'cadillac20', 'Rating': 10, 'Movie_Title': 'John Wick 4', 'last_accessed_at': '2025-02-28T11:40:31.292929', '_id': 'bc33f10ca911475f8dca4db9eded6d5c', '_collection_name': 'JohnWickSemantic'}, page_content=": 18\nReview: Ever since the original John Wick, the franchise has set a standard of what action in Hollywood should be. Thanks to Chad Stahelski and Keanu Reeve's knowledge of the technical aspects of shooting action, they've been able to deliver expertly choreographed, shot, and edited action films that are now the go to as examples of great action filmmaking. And so, the expectations for the fourth film were fairly high, especially as it became more apparent this was not only the culmination of everything before it, but a whopping 169 minutes long. Rest assured, however, that it delivers in spades."), Document(metadata={'source': 'john_wick_4.csv', 'row': 10, 'Review_Date': '22 March 2023', 'Review_Title': ' How Can Anyone Choose to Watch Marvel Over This?\n', 'Review_Url': '/review/rw8944843/?ref_=tt_urv', 'Author': 'lovemichaeljordan', 'Rating': 8, 'Movie_Title': 'John Wick 4', 'last_accessed_at': '2025-02-28T11:40:31.292923', '_id': 'fb10a955cf9e4b6ea87883bc692c4fda', '_collection_name': 'JohnWickSemantic'}, page_content=': 10\nReview: Most American action flicks released these days have poor screenplays and overuse computer-generated imagery. The John Wick franchise is one of the few exceptions, along with Mission Impossible.'), Document(metadata={'source': 'john_wick_1.csv', 'row': 20, 'Review_Date': '22 October 2014', 'Review_Title': ' Smoothest action film to come around in a long time\n', 'Review_Url': '/review/rw3109271/?ref_=tt_urv', 'Author': 'IceSkateUpHill', 'Rating': 10, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292350', '_id': '4405a6f0e8d6496eb5167306369fcff5', '_collection_name': 'JohnWickSemantic'}, page_content=": 20\nReview: John Wick is something special. It takes as much time setting up elaborate action sequences as it does the world with which it all takes place in. And what a world it is. It reminds me of Millers Crossing and it is cooler than any other recent attempt at noir. We are shown a criminal underworld where, if you are connected, many powerful people know who you are and show y ...
# response[response] The John Wick franchise has set a standard for Hollywood action films by delivering expertly choreographed, shot, and edited action sequences. The franchise, led by Chad Stahelski and Keanu Reeves, has raised the bar for great action filmmaking in Hollywood. In terms of screenplay quality and use of CGI, the John Wick franchise stands out from most American action flicks, which often feature poor screenplays and an overuse of CGI. The John Wick movies focus on lean, intense, and emotionally impactful plots, and rely more on practical stunts and choreography rather than heavy CGI effects. Overall, the franchise has set a high standard for action films in terms of both screenplay quality and the use of CGI.
# response {'response': AIMessage(content="The reviews reflect Keanu Reeves' portrayal in the John Wick franchise very positively. They highlight his performance as being slick, cool, and natural in action choreography. The reviews also mention the fluidity and smoothness of Reeves' movements in the film, emphasizing his skills and confidence in portraying the character. Additionally, the reviews praise the character depth shown through Reeves' performance. Overall, the reviews appreciate Reeves' portrayal in terms of action choreography and character depth in the John Wick franchise.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 100, 'prompt_tokens': 2899, 'total_tokens': 2999, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-817845ac-68e2-4bb6-8fbf-d90d0d1197bb-0', usage_metadata={'input_tokens': 2899, 'output_tokens': 100, 'total_tokens': 2999, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_1.csv', 'row': 20, 'Review_Date': '22 October 2014', 'Review_Title': ' Smoothest action film to come around in a long time\n', 'Review_Url': '/review/rw3109271/?ref_=tt_urv', 'Author': 'IceSkateUpHill', 'Rating': 10, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292350', '_id': '4405a6f0e8d6496eb5167306369fcff5', '_collection_name': 'JohnWickSemantic'}, page_content=": 20\nReview: John Wick is something special. It takes as much time setting up elaborate action sequences as it does the world with which it all takes place in. And what a world it is. It reminds me of Millers Crossing and it is cooler than any other recent attempt at noir. We are shown a criminal underworld where, if you are connected, many powerful people know who you are and show you respect. John Wick was connected but he got out. He is the rare killer who has found peace, and he is grateful for that peace. Some young kids steal that from him and he does what he does best, he wages a one man war against the Russian Mafia. It might sound like the film takes quite a leap but it all makes sense. The motives of John and the people who get in the way of his bullets are all very clear, even if it does come across as rather simple. That's the plot at it's most basic. Then there's the action. The film is directed by Reeve's stuntman from The Matrix, so this guy knows action. There are sequences that flow so smoothly it puts other action films and their quick cuts to shame. Keaunu moves so fluidly throughout the film and comes across as such a natural that the only disappointment is that we have not seen him like this before. Along the way are plenty of character actors, fans of The Matrix and The Wire will recognize a few people then there are more obvious ones like Ian McShane and Willem Dafoe. Everyone seems to be having a good time."), Document(metadata={'source': 'john_wick_1.csv', 'row': 9, 'Review_Date': '20 October 2014', 'Review_Title': " The coolest action film you'll see all year\n", 'Review_Url': '/review/rw3107759/?ref_=tt_urv', 'Author': 'trublu215', 'Rating': 9, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292341', '_id': '57d10102ca1c484c839e9f1e34021192', '_collection_name': 'JohnWickSemantic'}, page_content=": 9\nReview: At first glance, John Wick sounds like a terrible film on paper but with the slickness of Keanu Reeves' performance as the titular character and the sheer brilliance in its action sequences, this marks the best action film of the year and one of the absolute best in the past decade. Following a brutal home invasion that leaves his beloved dog murdered by thugs from his ...
# response[response] The reviews reflect Keanu Reeves' portrayal in the John Wick franchise very positively. They highlight his performance as being slick, cool, and natural in action choreography. The reviews also mention the fluidity and smoothness of Reeves' movements in the film, emphasizing his skills and confidence in portraying the character. Additionally, the reviews praise the character depth shown through Reeves' performance. Overall, the reviews appreciate Reeves' portrayal in terms of action choreography and character depth in the John Wick franchise.
# response {'response': AIMessage(content='Ian McShane is important in the John Wick movie because he plays the character Winston, the owner of the Continental hotel in New York City. He adds depth to the criminal underworld setting of the film and provides a sense of rules and order in a chaotic environment. His character contributes to the tension and dynamic between various characters, including John Wick, making the storyline more intriguing and engaging.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 78, 'prompt_tokens': 2947, 'total_tokens': 3025, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-228b4990-bfd2-4315-abf9-c610e0687e27-0', usage_metadata={'input_tokens': 2947, 'output_tokens': 78, 'total_tokens': 3025, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'john_wick_1.csv', 'row': 9, 'Review_Date': '20 October 2014', 'Review_Title': " The coolest action film you'll see all year\n", 'Review_Url': '/review/rw3107759/?ref_=tt_urv', 'Author': 'trublu215', 'Rating': 9, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292341', '_id': '94a1080971474a6fbccb4e1adeaee44a', '_collection_name': 'JohnWickSemantic'}, page_content="This is EXACTLY what you want out of an action film. It is briskly paced, brilliantly shot and meticulously choreographed and keeps you wanting more and more. The supporting cast filled with the likes of John Legiuzamo, Ian McShane, and Willen Dafoe also keeps this film very interesting. These guys don't play good guys, hell, John Wick by traditional standards would be a bad guy in any other film. Every character is more ruthless than the next and pushes John Wick to be more ruthless than they are, creating a very cool dynamic between the character and the plot regarding the idea of how far is too far? However, don't expect some revelation from John Wick regarding the morality of bad and evil. This film wants you entertained and does so with brute force, it never lets up, not even for a second. One scene in particular that will have your blood pumping is a showdown between thugs and Wick in a nightclub. This action sequence remains the best in the film and will have you grasping your theater seat because of the sheer intensity of it. Overall, John Wick is slick, violent fun that turns into a remarkable, surprising film that will catch you off guard. It is THAT good. I highly recommend this film to action buffs especially but I'm sure those who just like a good movie will love it as well."), Document(metadata={'source': 'john_wick_1.csv', 'row': 20, 'Review_Date': '22 October 2014', 'Review_Title': ' Smoothest action film to come around in a long time\n', 'Review_Url': '/review/rw3109271/?ref_=tt_urv', 'Author': 'IceSkateUpHill', 'Rating': 10, 'Movie_Title': 'John Wick 1', 'last_accessed_at': '2025-02-25T11:40:31.292350', '_id': '4405a6f0e8d6496eb5167306369fcff5', '_collection_name': 'JohnWickSemantic'}, page_content=": 20\nReview: John Wick is something special. It takes as much time setting up elaborate action sequences as it does the world with which it all takes place in. And what a world it is. It reminds me of Millers Crossing and it is cooler than any other recent attempt at noir. We are shown a criminal underworld where, if you are connected, many powerful people know who you are and show you respect. John Wick was connected but he got out. He is the rare killer who has found peace, and he is grateful for that peace. Some young kids steal that from him and he does what he does best, he wages a one man war against the Russian Mafia. It might sound like the fil ...
# response[response] Ian McShane is important in the John Wick movie because he plays the character Winston, the owner of the Continental hotel in New York City. He adds depth to the criminal underworld setting of the film and provides a sense of rules and order in a chaotic environment. His character contributes to the tension and dynamic between various characters, including John Wick, making the storyline more intriguing and engaging.
# Evaluating:   0%|          | 0/60 [00:00<?, ?it/s]
# Exception raised in Job[2]: TypeError(ufunc 'invert' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe'')
# Exception raised in Job[29]: TimeoutError()
# Exception raised in Job[47]: TimeoutError()
# semantic_retrieval_chain 436.39838075000443

# %%
print("result_multi_query_retrieval", result_multi_query_retrieval)

print("result_naive_retrieval", result_naive_retrieval)

print("result_bm25_retrieval", result_bm25_retrieval)

print("result_ecompression_retrieval", result_ecompression_retrieval)

print("result_document_retriever", result_document_retriever)

print("result_ensemble_retrieval", result_ensemble_retrieval)

print("result_semantic_retrieval", result_semantic_retrieval)
# Out:
# result_multi_query_retrieval {'context_recall': 0.8250, 'faithfulness': 0.8538, 'factual_correctness': 0.4900, 'answer_relevancy': 0.8724, 'context_entity_recall': 0.5650, 'noise_sensitivity_relevant': 0.4556}
# result_naive_retrieval {'context_recall': 0.7750, 'faithfulness': 0.8476, 'factual_correctness': 0.4760, 'answer_relevancy': 0.9593, 'context_entity_recall': 0.5708, 'noise_sensitivity_relevant': 0.2485}
# result_bm25_retrieval {'context_recall': 0.5500, 'faithfulness': 0.6695, 'factual_correctness': 0.3800, 'answer_relevancy': 0.9673, 'context_entity_recall': 0.4792, 'noise_sensitivity_relevant': 0.2273}
# result_ecompression_retrieval {'context_recall': 0.7500, 'faithfulness': 0.7084, 'factual_correctness': 0.5380, 'answer_relevancy': 0.9725, 'context_entity_recall': 0.6183, 'noise_sensitivity_relevant': 0.2026}
# result_document_retriever {'context_recall': 0.5500, 'faithfulness': 0.6988, 'factual_correctness': 0.3950, 'answer_relevancy': 0.8702, 'context_entity_recall': 0.5225, 'noise_sensitivity_relevant': 0.1767}
# result_ensemble_retrieval {'context_recall': 0.8500, 'faithfulness': 0.8191, 'factual_correctness': 0.5020, 'answer_relevancy': 0.9680, 'context_entity_recall': 0.5983, 'noise_sensitivity_relevant': 0.4048}
# result_semantic_retrieval {'context_recall': 0.7750, 'faithfulness': 0.8360, 'factual_correctness': 0.4767, 'answer_relevancy': 0.8739, 'context_entity_recall': 0.5696, 'noise_sensitivity_relevant': 0.4119}

# %% [markdown]
# ## 1. Golden Dataset Creation
#
# To compare different retrieval methods apples-to-apples, we generated a synthetic “golden dataset.” This dataset:
# - Contains questions that vary in complexity, including entities and relationships relevant to our domain.
# - Includes “noise” questions or partial queries to test retrieval robustness.
# - Is large enough to highlight latency differences.
#
# > **How we generated it:**
# > We used a Synthetic Data Generation pipeline (e.g., Ragas) to produce pairs of queries and ground-truth passages. This ensures we can reliably measure *context recall*, *factual correctness*, and other metrics without relying purely on manual labeling.
#
# ---
#
# ## 2. Retriever-Specific RAGAS Metrics
#
# Below are the metrics we collected for each retriever. All values are drawn from runs on the synthetic dataset. (Note: **Lower** `noise_sensitivity_relevant` typically indicates *greater* robustness to noisy queries.)
#
# | Retriever                  | Context Recall | Faithfulness | Factual Correctness | Answer Relevancy | Context Entity Recall | Noise Sensitivity Relevant |
# |----------------------------|---------------:|-------------:|---------------------:|------------------:|-----------------------:|---------------------------:|
# | **Multi-query**           | 0.8250         | 0.8538       | 0.4900              | 0.8724           | 0.5650                | 0.4556                    |
# | **Naive**                 | 0.7750         | 0.8476       | 0.4760              | 0.9593           | 0.5708                | 0.2485                    |
# | **BM25**                  | 0.5500         | 0.6695       | 0.3800              | 0.9673           | 0.4792                | 0.2273                    |
# | **Embedding Compression** | 0.7500         | 0.7084       | **0.5380**          | **0.9725**       | **0.6183**            | 0.2026                    |
# | **Document Retriever**    | 0.5500         | 0.6988       | 0.3950              | 0.8702           | 0.5225                | **0.1767**                |
# | **Ensemble**              | **0.8500**     | 0.8191       | 0.5020              | 0.9680           | 0.5983                | 0.4048                    |
# | **Semantic**              | 0.7750         | 0.8360       | 0.4767              | 0.8739           | 0.5696                | 0.4119                    |
#
# > **Note on “Semantic Chunking”**
# > You could apply semantic chunking to any of these retrieval methods. While we did *not* treat it as a separate “retriever,” some teams might test each approach in a “chunked vs. unchunked” setup to see how splitting documents into meaningful chunks affects these metrics.
#
# ---
#
# ## 3. Summary of Findings
#
# 1. **Context Recall:**
#    - The *Ensemble Retriever* provides the highest coverage (0.85).
#    - *Multi-query* is a close second (0.825).
#    - Lexical-based (BM25, Document Retriever) lag behind in coverage (0.55), indicating they sometimes miss relevant passages.
#
# 2. **Faithfulness & Factual Correctness:**
#    - *Multi-query* has the strongest faithfulness (0.8538), with *Naive* close behind (0.8476).
#    - However, *Embedding Compression* stands out for factual correctness (0.5380), the highest in the table, suggesting it pulls in more *accurate* information for final answers.
#
# 3. **Answer Relevancy & Context Entity Recall:**
#    - *Embedding Compression* also leads on answer relevancy (0.9725) and context entity recall (0.6183). This indicates it surfaces passages that are both on-topic and rich in the correct entities.
#    - BM25 can rank high for “relevancy” on typical keyword-based queries (0.9673), but it lags in other metrics like context entity recall and factual correctness.
#
# 4. **Noise Sensitivity:**
#    - Lower is better here. *Document Retriever* is the most robust (0.1767), meaning it is least likely to degrade when queries contain “noise” (misspellings, extraneous text).
#    - More advanced methods like *Ensemble*, *Multi-query*, and *Semantic* can get tripped up by noisy or partial inputs, judging by higher noise-sensitivity scores.
#
# ### Cost and Latency Considerations
#
# - **Lexical approaches (BM25, Document Retriever)**
#   - **Pros:** Fast, low computational cost, easy to maintain.
#   - **Cons:** Lower coverage and factual correctness, especially in complex or ambiguous queries.
# - **Vector-based approaches (Semantic, Embedding Compression)**
#   - **Pros:** Generally higher semantic coverage, better factual correctness, strong answer relevancy.
#   - **Cons:** Higher up-front embedding cost, can be slower if index is large (depends on the vector database or nearest-neighbor strategy).
# - **Multi-query and Ensemble**
#   - **Pros:** Potentially the best coverage (Ensemble) or highest faithfulness (Multi-query) by combining multiple signals.
#   - **Cons:** Usually the most expensive, as you either run multiple retrieval steps or orchestrate multiple models/indices.
#
# ### Which Retriever is “Best” for This Data?
#
# Given our synthetic dataset—which emphasizes both correctness and coverage—**Embedding Compression Retrieval** emerges as a strong choice. It strikes a balance with:
#
# - **High factual correctness** (top score of 0.5380)
# - **High answer relevancy** (top score of 0.9725)
# - **Strong entity recall** (top score of 0.6183)
#
# However, if *coverage* (context recall) is a priority—even at higher cost—**Ensemble Retrieval** might outperform others (0.85). Meanwhile, if you need to minimize infrastructure cost/latency, a simpler approach like **BM25** or **Naive** could suffice, though with reduced accuracy on more complex queries.
#
# In short, your choice depends on the **trade-off** between:
# - Needing highly *correct, relevant passages* (Embedding Compression or Ensemble),
# - Handling *noisy queries* reliably (Document Retriever),
# - Minimizing *computational cost* (BM25 / Naive).
#
# ---
#
# > **Next Steps:**
# > - Tune each method to see if hyperparameter changes (e.g., chunk size, top-k results) improve specific metrics.
# > - Investigate a two-stage retrieval (e.g., BM25 → Vector-based re-ranker) for a middle ground.
# > - Perform a deeper cost/latency analysis by benchmarking each approach at scale.
